# %%
import pandas as pd
import numpy as np
import os

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.utils import np_utils
from keras.preprocessing import sequence

from sklearn.model_selection import train_test_split
from sklearn import preprocessing

import gensim
from gensim.models import Word2Vec

import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import unicodedata
import spacy

from multiprocessing import Pool

# %%
import matplotlib
from matplotlib import rc
import matplotlib.pyplot as plt

#font = {'family': 'Verdana', 'weight': 'normal'}
#rc('font', **font)
matplotlib.style.use('ggplot')

# %matplotlib inline

pd.set_option('display.max_rows', 15)

# %%
spacy.util.set_data_path('/home/data/spacy/')
nlp = spacy.load('en')

# %% [markdown]
# # Загрузка данных

# %%
train_set = pd.read_csv('/home/data/share/quora/train.csv', index_col=0)
test_set = pd.read_csv('/home/data/share/quora/test.csv', index_col=0)

# %%
train_set.head(10)
# Out:
#     qid1  qid2                                          question1  \
# id
# 0      1     2  What is the step by step guide to invest in sh...
# 1      3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2      5     6  How can I increase the speed of my internet co...
# 3      7     8  Why am I mentally very lonely? How can I solve...
# 4      9    10  Which one dissolve in water quikly sugar, salt...
# 5     11    12  Astrology: I am a Capricorn Sun Cap moon and c...
# 6     13    14                                Should I buy tiago?
# 7     15    16                     How can I be a good geologist?
# 8     17    18                    When do you use シ instead of し?
# 9     19    20  Motorola (company): Can I hack my Charter Moto...
#
#                                             question2  is_duplicate
# id
# 0   What is the step by step guide to invest in sh...             0
# 1   What would happen if the Indian government sto...             0
# 2   How can Internet speed be increased by hacking...             0
# 3   Find the remainder when [math]23^{24}[/math] i...             0
# 4             Which fish would survive in salt water?             0
# 5   I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 6   What keeps childern active and far from phone ...             0
# 7           What should I do to be a great geologist?             1
# 8               When do you use "&" instead of "and"?             0
# 9   How do I hack Motorola DCX3400 for free internet?             0

# %% [markdown]
# ## Пробелы в данных

# %%
test_set[test_set.isnull().any(axis=1)]
# Out:
#                                            question1  \
# test_id
# 379205      How I can learn android app development?
# 817520   How real can learn android app development?
# 943911                          How app development?
# 1046690                                          NaN
# 1270024             How I can learn app development?
# 1461432                                          NaN
#
#                                                question2
# test_id
# 379205                                               NaN
# 817520                                               NaN
# 943911                                               NaN
# 1046690    How I what can learn android app development?
# 1270024                                              NaN
# 1461432  How distinct can learn android app development?

# %%
train_set.fillna('empty_string', inplace=True)
test_set.fillna('empty_string', inplace=True)

# %% [markdown]
# # Tokenization

# %% [markdown]
# ### Text Preparation

# %%
def replace_characters_in_string(s, characters_pairs=[('\n', ' '), ('\t', ' ')]):    
    for old_c, new_c in characters_pairs:
        s = s.replace(old_c, new_c)
        
    return s

def remove_extra_spaces(s):
    return ' '.join( s.split() )

# %% [markdown]
# #### [math]...[/math]

# %%
pairs_to_replace_in_plain_math = [('[math]', ''), ('[/math]', ''), ('{', ''), ('}', ''), 
                                  ('\\left', ''), ('\\right', ''), ('\\displaystyle', ''), ('\\ln', 'log'), ('\\mathrm', ''),
                                  ('_', ''), ('\\', ''), (' ', '')]

def plain_math_replace(matchobj):
    start, end = matchobj.span()
    matching_string = matchobj.string[start:end]
    matching_string = replace_characters_in_string(matching_string, characters_pairs=pairs_to_replace_in_plain_math)
    return matching_string

plain_math_regex = r'\[math\]((?!\[math\]|\[\/math\]).)*\[\/math\]'

def clean_text_from_latex(text):
    clean_text = re.sub(plain_math_regex, plain_math_replace, text)
    return clean_text

# %%
counter = 0
for q1, q2, is_duplicate in train_set[['question1', 'question2', 'is_duplicate']].values:
    if ('[math]' in q1 or '[math]' in q2):
        if  is_duplicate:
            print(q1)
            print(q2, '\n')
            q1_fixed = clean_text_from_latex(q1).lower()
            q2_fixed = clean_text_from_latex(q2).lower()
            print(q1_fixed)
            print(q2_fixed, '\n\n\n')
        
        counter += 1

print('{} latex questions at train_set'.format(counter))
# Out:
# How do I learn [math]\LaTeX[/math]?
# How can I learn latex in the easiest way?
#
# how do i learn latex?
# how can i learn latex in the easiest way?
#
#
#
# Let [math]S_{n} = n^{2} + 20n + 12[/math], where [math]n[/math] is a positive integer. What is the sum of all possible values of n for which [math]S_{n}[/math] is a perfect square?
# Given [math]S_n = n^2 +20n + 12[/math]. What will be the sum of positive integers such that [math]S_n[/math] will be a perfect square?
#
# let sn=n^2+20n+12, where n is a positive integer. what is the sum of all possible values of n for which sn is a perfect square?
# given sn=n^2+20n+12. what will be the sum of positive integers such that sn will be a perfect square?
#
#
#
# If real numbers are in [math]x[/math]-axis and complex numbers in [math]y[/math]-axis, what is in the [math]z[/math]-axis?
# If the real numbers are usually placed on the [math]x[/math]-axis and imaginary numbers placed on the [math]y[/math]-axis, what would be placed on the [math]z[/math]-axis?
#
# if real numbers are in x-axis and complex numbers in y-axis, what is in the z-axis?
# if the real numbers are usually placed on the x-axis and imaginary numbers placed on the y-axis, what would be placed on the z-axis?
#
#
#
# What is value of I^i?
# What is the value of [math]i^i [/math]where [math]i=\sqrt{-1}[/math]?
#
# what is value of i^i?
# what is the value of i^iwhere i=sqrt-1?
#
#
#
# How do I solve the problem: [math] A=\begin{pmatrix} -2 &4 \\   -5& 7 \end{pmatrix}, A^{n}=? [/math]?
# Given [math]A[/math], What is the general formula of [math]A^n[/math]? If [math]A=\begin{pmatrix} -2 &4 \\ -5& 7 \end{pmatrix}[/math], what is the [math]A^n[/math]?
#
# how do i solve the problem: a=beginpmatrix-2&4-5&7endpmatrix,a^n=??
# given a, what is the general formula of a^n? if a=beginpmatrix-2&4-5&7endpmatrix, what is the a^n?
#
#
#
# How can you determine the derivative of [math]\sin x^2[/math]?
# What is the derivative of [math]\sin \left(x^2\right)[/math]?
#
# how can you determine the derivative of sinx^2?
# what is the derivative of sin(x^2)?
#
#
#
# Which primitive could be proper for A^3 = B^3 + C^3?
# Where is the unknown in the Fermat's equation [math]A^3 = B^3 + C^3[/math]?
#
# which primitive could be proper for a^3 = b^3 + c^3?
# where is the unknown in the fermat's equation a^3=b^3+c^3?
#
#
#
# How can I learn how to use LaTeX?
# How do I learn [math]\LaTeX[/math]?
#
# how can i learn how to use latex?
# how do i learn latex?
#
#
#
# Is there any idea, how to prove (no computer) that 253*Sqrt(2) +874*Sqrt(3) +582*Sqrt(5) >3173?
# Is there any idea, how to prove (no computer) the inequality [math]253 \sqrt{2} + 874 \sqrt{3} + 582\sqrt{5} > 3173[/math]?
#
# is there any idea, how to prove (no computer) that 253*sqrt(2) +874*sqrt(3) +582*sqrt(5) >3173?
# is there any idea, how to prove (no computer) the inequality 253sqrt2+874sqrt3+582sqrt5>3173?
#
#
#
# What is the particular solution for [math]\frac{dy}{dx}=\frac{6x^2–2x}{2y-x}[/math] at [math](0,0)[/math]
# What is the general solution for [math]\frac{dy}{dx} = \frac{6x^2-2x}{2y-x}[/math], and the particular solution at [math](0,0)[/math]?
#
# what is the particular solution for fracdydx=frac6x^2–2x2y-x at (0,0)
# what is the general solution for fracdydx=frac6x^2-2x2y-x, and the particular solution at (0,0)?
#
#
#
# How would you simplify [math]i^{100}[/math]?
# How do I simplify i∧100?
#
# how would you simplify i^100?
# how do i simplify i∧100?
#
#
#
# If the integers a,b are coprime, then does it follow that for any positive integers $a^l$ and $b^m$ are coprime as well?
# If the integers a,b are coprime, then does it follow that for any positive integers, [math]a^l[/math] and [math]b^m[/math] are coprime as well?
#
# if the integers a,b are coprime, then does it follow that for any positive integers $a^l$ and $b^m$ are coprime as well?
# if the integers a,b are coprime, then does it follow that for any positive integers, a^l and b^m are coprime as well?
#
#
#
# What is physical significance of euler's number e?
# What is the physical significance of Euler's number [math]e[/math]?
#
# what is physical significance of euler's number e?
# what is the physical significance of euler's number e?
#
#
#
# What's the value of [math]\int^{\pi}_{-\pi} (\sqrt{1 +x^2} ) dx[/math]?
# What's the value of [math]\int^{\pi}_{-\pi} \sqrt{1  +x^2} \, dx[/math]?
#
# what's the value of int^pi-pi(sqrt1+x^2)dx?
# what's the value of int^pi-pisqrt1+x^2,dx?
#
#
#
# How do you solve the following recurrence using substitution method? [math]T(n) =T\left (\left\lfloor\frac {n} {4} \right\rfloor\right) +n [/math]
# How do you solve the following recurrence using the substitution method?
#
# how do you solve the following recurrence using substitution method? t(n)=t(lfloorfracn4rfloor)+n
# how do you solve the following recurrence using the substitution method?
#
#
#
# Why is [math]\pi[/math] such a special number?
# What is so special about π?
#
# why is pi such a special number?
# what is so special about π?
#
#
#
# How do you solve this recurrence [math]T(n)=T\left(\left\lfloor\frac{n}{4}\right\rfloor\right)+n [/math] by substitution method?
# How do you solve the following recurrence using the substitution method?
#
# how do you solve this recurrence t(n)=t(lfloorfracn4rfloor)+n by substitution method?
# how do you solve the following recurrence using the substitution method?
#
#
#
# What is the value of [math]x[/math] in the equation [math]3^{x+2}+3^{-x}=10[/math]?
# What is the value of x in the equation [math]3^{x+2} +3^{-x} =10[/math]?
#
# what is the value of x in the equation 3^x+2+3^-x=10?
# what is the value of x in the equation 3^x+2+3^-x=10?
#
#
#
# How can pie is the ratio of circumference and diameter or equal to C by D because pie is irrational number and circumference by diameter is rational?
# How can [math]\pi[/math] be irrational if [math]\pi[/math] is equal to a circle's circumference over its diameter?
#
# how can pie is the ratio of circumference and diameter or equal to c by d because pie is irrational number and circumference by diameter is rational?
# how can pi be irrational if pi is equal to a circle's circumference over its diameter?
#
#
#
# How is the value of [math]\pi[/math] calculated?
# What is the value of π?
#
# how is the value of pi calculated?
# what is the value of π?
#
#
#
# What is the result of [math]3^ {2^ {1^ {0^{-1^{-2^{-3}}}}}}[/math]?
# What is the result of [math]3^ {2^ {1^ {0^{-1^{-2^-3}}}}}[/math]?
#
# what is the result of 3^2^1^0^-1^-2^-3?
# what is the result of 3^2^1^0^-1^-2^-3?
#
#
#
# How is the value of π (Pi) actually calculated?
# How is the value of [math]\pi[/math] calculated?
#
# how is the value of π (pi) actually calculated?
# how is the value of pi calculated?
#
#
#
# What are some differences between the proton and the Δ+ particle?
# What are some differences between the proton and the [math]\Delta^+[/math] particle?
#
# what are some differences between the proton and the δ+ particle?
# what are some differences between the proton and the delta^+ particle?
#
#
#
# Given m and n are positive integers such that for some positive integer, x, [math]\sqrt {x+43} =m[/math] and [math]\sqrt {x+16} =n[/math], what is the value of the product mn as a positive integer?
# Given m and n are positive integers such that for some positive integer x, [math]\sqrt{x+43}=m[/math] and [math]\sqrt{x+16}=n[/math], what is the value of the product mn as a positive integer?
#
# given m and n are positive integers such that for some positive integer, x, sqrtx+43=m and sqrtx+16=n, what is the value of the product mn as a positive integer?
# given m and n are positive integers such that for some positive integer x, sqrtx+43=m and sqrtx+16=n, what is the value of the product mn as a positive integer?
#
#
#
# How many grams of glucose (C[math]_6[/math]H[math]_12[/math]O[math]_6[/math]) are needed to make 250mL of an 0.360 solution?
# How many grams of glucose (c6H12O6) are needed to make 250mL of an 0.360 solution?
#
# how many grams of glucose (c6h12o6) are needed to make 250ml of an 0.360 solution?
# how many grams of glucose (c6h12o6) are needed to make 250ml of an 0.360 solution?
#
#
#
# What is the difference between H+ ion and proton?
# Is there no possible difference between positively charged hydrogen ([math]H^{+}[/math]) and proton?
#
# what is the difference between h+ ion and proton?
# is there no possible difference between positively charged hydrogen (h^+) and proton?
#
#
#
# How many polynomial [math]p(x)[/math] are there such that [math]p(q(x))=q(p(x))[/math] for all polynomial [math]q(x) [/math]?
# What are all polynomials [math]p(x)[/math] such that [math]p(q(x))=q(p(x))[/math] for every polynomial [math]q(x)[/math]?
#
# how many polynomial p(x) are there such that p(q(x))=q(p(x)) for all polynomial q(x)?
# what are all polynomials p(x) such that p(q(x))=q(p(x)) for every polynomial q(x)?
#
#
#
# In a right-angle triangle, perpendicular is 3^1/2 times the base. What is ratio of their opposite angles?
# In a right-angle triangle, perpendicular is [math]\sqrt{3}[/math] times the base. What is ratio of their opposite angles?
#
# in a right-angle triangle, perpendicular is 3^1/2 times the base. what is ratio of their opposite angles?
# in a right-angle triangle, perpendicular is sqrt3 times the base. what is ratio of their opposite angles?
#
#
#
# What is the derivative of x! (X factorial)?
# What is the derivative of [math]x![/math]?
#
# what is the derivative of x! (x factorial)?
# what is the derivative of x!?
#
#
#
# Let's consider S[math]_{n}[/math]= n[math]^{2}[/math] + 20n +12. So can you find the sum of all possible n for which S[math]_{n}[/math] is a perfect square?
# Let [math]S_{n} = n^{2} + 20n + 12[/math], where [math]n[/math] is a positive integer. What is the sum of all possible values of n for which [math]S_{n}[/math] is a perfect square?
#
# let's consider sn= n^2 + 20n +12. so can you find the sum of all possible n for which sn is a perfect square?
# let sn=n^2+20n+12, where n is a positive integer. what is the sum of all possible values of n for which sn is a perfect square?
#
#
#
# How is E=Mc^2 correct?
# Is [math]E=mc^2[/math] really correct?
#
# how is e=mc^2 correct?
# is e=mc^2 really correct?
#
#
#
# For f(x) with domain and range both nonnegative reals, how many f(x) are there where f(f(x)) = x^2? Are there more than 2?
# What are all the functions where [math]f(f(x)) = x^2[/math] with domain nonnegative reals? Are there more than two?
#
# for f(x) with domain and range both nonnegative reals, how many f(x) are there where f(f(x)) = x^2? are there more than 2?
# what are all the functions where f(f(x))=x^2 with domain nonnegative reals? are there more than two?
#
#
#
# How many 2-digit numbers can be written as the sum of exactly six different integer powers of [math]2[/math], including [math]2^0[/math]?
# How many 2-digit numbers can be written as the sum of exactly six different powers of 2, including 2^0?
#
# how many 2-digit numbers can be written as the sum of exactly six different integer powers of 2, including 2^0?
# how many 2-digit numbers can be written as the sum of exactly six different powers of 2, including 2^0?
#
#
#
# How do I learn [math]\LaTeX[/math]?
# Where can I learn LaTeX?
#
# how do i learn latex?
# where can i learn latex?
#
#
#
# What is a short simple proof for [math]1+1=2[/math]?
# Why does [math]1+1=2[/math]?
#
# what is a short simple proof for 1+1=2?
# why does 1+1=2?
#
#
#
# What is the remainder when 2^100 is divided by 101?
# What is the remainder when [math]2^{100}[/math] is divided by 101?
#
# what is the remainder when 2^100 is divided by 101?
# what is the remainder when 2^100 is divided by 101?
#
#
#
# What is the graph of y=x?
# What is the graph of [math]y=x[/math]?
#
# what is the graph of y=x?
# what is the graph of y=x?
#
#
#
# How do I show that the points [math](3, -1), (5, 4), (-5, 8)[/math] and [math](-7, 3)[/math] are the vertices of a rectangle and draw a rectangle?
# How do I show that the points (5,4), (-5,8), (-7,3) and (3,-1) are the vertices of a rectangle?
#
# how do i show that the points (3,-1),(5,4),(-5,8) and (-7,3) are the vertices of a rectangle and draw a rectangle?
# how do i show that the points (5,4), (-5,8), (-7,3) and (3,-1) are the vertices of a rectangle?
#
#
#
# If f( x , x+y , x+y+z ) = 0 and z = z( x , y ) then  what is ∂z/∂x[math] , [/math]∂z/∂y[math] , {∂}^2z/{∂x}^2 ? [/math]
# If f (x , x+y , x+y+z ) = 0 and z = z (x , y) then what is solution of these partials [math]\frac{∂z}{∂x} , \frac{∂z}{∂y} , \frac{{∂^2}z}{{∂x}^2} ?[/math]
#
# if f( x , x+y , x+y+z ) = 0 and z = z( x , y ) then  what is ∂z/∂x,∂z/∂y,∂^2z/∂x^2?
# if f (x , x+y , x+y+z ) = 0 and z = z (x , y) then what is solution of these partials frac∂z∂x,frac∂z∂y,frac∂^2z∂x^2?
#
#
#
# How does one evaluate [math]\cos{\theta}+\sec{\theta}[/math], given that [math]4\cos^2{\theta}+4\sec^2{\theta}=5[/math]?
# How do I evaluate cosθ+secθ given that 4cos²θ+4sec²θ=5?
#
# how does one evaluate costheta+sectheta, given that 4cos^2theta+4sec^2theta=5?
# how do i evaluate cosθ+secθ given that 4cos²θ+4sec²θ=5?
#
#
#
# In a triangle ABC, angle A = 2 angle B. How would you prove that BC² = AC² + AB × AC?
# In triangle ABC, angleA = 2*angleB. Prove that [math]BC^2 = AC^2 + AC.AB[/math]; can you?
#
# in a triangle abc, angle a = 2 angle b. how would you prove that bc² = ac² + ab × ac?
# in triangle abc, anglea = 2*angleb. prove that bc^2=ac^2+ac.ab; can you?
#
#
#
# What is the sum of [math]\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\ldots[/math] up to 100 terms?
# What is the value of [math]\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\ldots[/math] up to 100 terms?
#
# what is the sum of frac11-sqrt2divfrac11-sqrt2divfrac11-sqrt2divfrac11-sqrt2divldots up to 100 terms?
# what is the value of frac11-sqrt2divfrac11-sqrt2divfrac11-sqrt2divfrac11-sqrt2divldots up to 100 terms?
#
#
#
# How can you use a very efficient [math]O(\sqrt{n})[/math] solution to an NP-Complete problem to make an General AI that is as smart as human?
# How do you frame General AI as an NP-complete decision problem?
#
# how can you use a very efficient o(sqrtn) solution to an np-complete problem to make an general ai that is as smart as human?
# how do you frame general ai as an np-complete decision problem?
#
#
#
# Why is e important in mathematics?
# Why is [math]e[/math] so important, in mathematics?
#
# why is e important in mathematics?
# why is e so important, in mathematics?
#
#
#
# If superconductors have infinite permeability (and permittivity), do they have infinite energy since E = 1/2 μ H^2?
# If superconductors have infinite permeability (and permittivity) then do they have infinite energy, since E = 1/2 μ H[math]^2[/math]?
#
# if superconductors have infinite permeability (and permittivity), do they have infinite energy since e = 1/2 μ h^2?
# if superconductors have infinite permeability (and permittivity) then do they have infinite energy, since e = 1/2 μ h^2?
#
#
#
# How do you solve the following recurrence using substitution method? [math]T(n) =T\left (\left\lfloor\frac {n} {4} \right\rfloor\right) +n [/math]
# How do you solve this recurrence [math]T(n)=T\left(\left\lfloor\frac{n}{4}\right\rfloor\right)+n [/math] by substitution method?
#
# how do you solve the following recurrence using substitution method? t(n)=t(lfloorfracn4rfloor)+n
# how do you solve this recurrence t(n)=t(lfloorfracn4rfloor)+n by substitution method?
#
#
#
# How do I prove (without computer) the inequality:[math]\sqrt[9]{502}+\sqrt[502]9>3[/math] ?
# Is there any idea to prove 9^{1/502}+502^{1/9}>3 ?
#
# how do i prove (without computer) the inequality:sqrt[9]502+sqrt[502]9>3 ?
# is there any idea to prove 9^{1/502}+502^{1/9}>3 ?
#
#
#
# How is the value of [math]\pi[/math] calculated?
# What is the value pi?
#
# how is the value of pi calculated?
# what is the value pi?
#
#
#
# What are some examples of e=mc2?
# What are some good examples of [math]E=mc^2[/math]?
#
# what are some examples of e=mc2?
# what are some good examples of e=mc^2?
#
#
#
# 698 latex questions at train_set

# %% [markdown]
# #### non ascii

# %%
pairs_to_replace_unicode = [('’', '\''), ('“', '\''),  ('”', '\''), ('…', ' ... '), ('‘', '\''), ('—', '-'), ('–', '-'),
                            ('（', ' ('), ('）', ') '),
                            ('δ', 'delta'), ('π', 'pi'), ('√', 'sqrt'), ('∫', 'int'), ('℅', '%'), ('∧', '^'), ('ı', 'I'),
                            ('ø', 'o'), ('×', 'x'), 
                            ('₹', ' rupees '), ('£', '$'), ('€', '$'), ('¥', '$'),
                            ('̇', ''), ('￼', ''), ('•', ' '), ('​', ' '), 
                            ('\ufeff', ' '), ('\x80', ' '), ('\u202a', ' '), ('\u202c', ' '), ('\u200e', ' '),
                            ('\u200f', ' '), ('\uf09e', ' '), ('\u2061', ' ')]

def unicode_normalization(text):
    text = replace_characters_in_string(text, characters_pairs=pairs_to_replace_unicode)
    text_normalized = unicodedata.normalize('NFKD', text).encode('ascii','ignore').decode('utf8')
    if len(text_normalized) == len(text):
        text = text_normalized
    return text

# %%
def is_have_non_ascii(s):
    return any(ord(c) >= 128 for c in s)

def get_all_non_ascii(s):
    return str([c for c in s if ord(c) >= 128])
    
counter = 0
for q1, q2, is_duplicate in train_set[['question1', 'question2', 'is_duplicate']].values:
    if is_have_non_ascii(q1) or is_have_non_ascii(q2):
        
        q1_fixed = unicode_normalization(q1)
        q2_fixed = unicode_normalization(q2)
        if is_have_non_ascii(q1_fixed) or is_have_non_ascii(q2_fixed):
            print(q1)
            print(q2, '\n')
            print(q1_fixed)
            print(q2_fixed)
            print(get_all_non_ascii(q1_fixed), get_all_non_ascii(q2_fixed), '\n\n\n')
        
        counter += 1

print('{} non ascii questions at train_set'.format(counter))
# Out:
# When do you use シ instead of し?
# When do you use "&" instead of "and"?
#
# When do you use シ instead of し?
# When do you use "&" instead of "and"?
# ['シ', 'し'] []
#
#
#
# What is my GPA if I have scored 65% in my 11th std CBSE?
# Why is Persian word “ذليل” meaning ‘a Muslim’ translated incorrectly on Microsoft Translator? Is it intentional or careless?
#
# What is my GPA if I have scored 65% in my 11th std CBSE?
# Why is Persian word 'ذليل' meaning 'a Muslim' translated incorrectly on Microsoft Translator? Is it intentional or careless?
# [] ['ذ', 'ل', 'ي', 'ل']
#
#
#
# What does tw4t mean?
# What does 분위기 mean?
#
# What does tw4t mean?
# What does 분위기 mean?
# [] ['분', '위', '기']
#
#
#
# What is the difference between ج and ز?
# What is the difference between == and ===?
#
# What is the difference between ج and ز?
# What is the difference between == and ===?
# ['ج', 'ز'] []
#
#
#
# How can I prove that (A × B) − (C × D) = (A − C) × B ∪ A × (B − D)?
# How can I prove (A × B) − (C × D) = (A − C) × B ∪ A × (B − D)?
#
# How can I prove that (A x B) − (C x D) = (A − C) x B ∪ A x (B − D)?
# How can I prove (A x B) − (C x D) = (A − C) x B ∪ A x (B − D)?
# ['−', '−', '∪', '−'] ['−', '−', '∪', '−']
#
#
#
# How do I find a translator?
# How would you translate "一百回"?
#
# How do I find a translator?
# How would you translate "一百回"?
# [] ['一', '百', '回']
#
#
#
# How do you pronounce the name of the Danish singer "MØ" in English?
# What are the Danish words with a lot of "ø"?
#
# How do you pronounce the name of the Danish singer "MØ" in English?
# What are the Danish words with a lot of "o"?
# ['Ø'] []
#
#
#
# At what height from Earth does weightlessness begin and when does the Moon's gravitational effect start?
# At what distance from earth's surface does ɡ0 (standard gravity) end and zero gravity or weightlessness starts?
#
# At what height from Earth does weightlessness begin and when does the Moon's gravitational effect start?
# At what distance from earth's surface does ɡ0 (standard gravity) end and zero gravity or weightlessness starts?
# [] ['ɡ']
#
#
#
# Is Lî Zhì Xù a good Chinese name?
# Is 恬莉 a good Chinese name?
#
# Is Li Zhi Xu a good Chinese name?
# Is 恬莉 a good Chinese name?
# [] ['恬', '莉']
#
#
#
# What does 슬마 mean?
# What is meaning of gazaba e hind?
#
# What does 슬마 mean?
# What is meaning of gazaba e hind?
# ['슬', '마'] []
#
#
#
# How long would it take a heat lamp to warm up my room?
# How long will it take to heat 750kg of water by 10°C with a 2060W heater?
#
# How long would it take a heat lamp to warm up my room?
# How long will it take to heat 750kg of water by 10°C with a 2060W heater?
# [] ['°']
#
#
#
# How to say “如果不靠欺骗自己，还能靠什么支撑自己走下去” in English?
# How can I say 没出息 in English?
#
# How to say '如果不靠欺骗自己，还能靠什么支撑自己走下去' in English?
# How can I say 没出息 in English?
# ['如', '果', '不', '靠', '欺', '骗', '自', '己', '，', '还', '能', '靠', '什', '么', '支', '撑', '自', '己', '走', '下', '去'] ['没', '出', '息']
#
#
#
# Shouldn't a Chinese aircraft carrier protect the freedom of navigation in the Indian Ocean, while an Indian-bought aircraft carrier creates tensions in the Indian Ocean?
# Why is it sometimes necessary to require δ ≤ 1 in a delta-epsilon proof and why do we have to let δ = minimum {1, epsilon/k} for some constant k?
#
# Shouldn't a Chinese aircraft carrier protect the freedom of navigation in the Indian Ocean, while an Indian-bought aircraft carrier creates tensions in the Indian Ocean?
# Why is it sometimes necessary to require delta ≤ 1 in a delta-epsilon proof and why do we have to let delta = minimum {1, epsilon/k} for some constant k?
# [] ['≤']
#
#
#
# Why did France abolish Vietnamese writing system- Chu Nom? How much harm it had caused to the Vietnamese culture ?
# If Vietnam had not been colonized by France, would the Vietnamese language still be using Chinese characters (Chữ Nôm / 字喃), like Japanese, and, to a lesser extent, Korean, today?
#
# Why did France abolish Vietnamese writing system- Chu Nom? How much harm it had caused to the Vietnamese culture ?
# If Vietnam had not been colonized by France, would the Vietnamese language still be using Chinese characters (Chữ Nôm / 字喃), like Japanese, and, to a lesser extent, Korean, today?
# [] ['ữ', 'ô', '字', '喃']
#
#
#
# Can you boil water at 0°C?
# How many hands need to be holding a cup of 1ml water 0°C at one time in order for it to boil?
#
# Can you boil water at 0°C?
# How many hands need to be holding a cup of 1ml water 0°C at one time in order for it to boil?
# ['°'] ['°']
#
#
#
# Do the people of Taiwan consider themselves Chinese?
# Why are there so many Chinese people who want to nuke Taiwan into flatland（核平统一）?
#
# Do the people of Taiwan consider themselves Chinese?
# Why are there so many Chinese people who want to nuke Taiwan into flatland (核平统一) ?
# [] ['核', '平', '统', '一']
#
#
#
# In Korean, what is the meaning of "jagi"?
# Koreans: What does ㅐㅌㄴㄴㅇ mean in Korean?
#
# In Korean, what is the meaning of "jagi"?
# Koreans: What does ㅐㅌㄴㄴㅇ mean in Korean?
# [] ['ㅐ', 'ㅌ', 'ㄴ', 'ㄴ', 'ㅇ']
#
#
#
# How do I simplify 5/x-y +3/y^2-x^2?
# How can I simplify (3+2(2) ½) ½?
#
# How do I simplify 5/x-y +3/y^2-x^2?
# How can I simplify (3+2(2) ½) ½?
# [] ['½', '½']
#
#
#
# What is the difference between aravam people and Tamil people?
# Why is Tamil called as Aravam (అరవం) in Telugu?
#
# What is the difference between aravam people and Tamil people?
# Why is Tamil called as Aravam (అరవం) in Telugu?
# [] ['అ', 'ర', 'వ', 'ం']
#
#
#
# How is asian institute of family managed business?
# Assuming that x is random variable. Prove mathematically that μx= μ (the mean of the probability distribution is equal to the mean in the population?
#
# How is asian institute of family managed business?
# Assuming that x is random variable. Prove mathematically that μx= μ (the mean of the probability distribution is equal to the mean in the population?
# [] ['μ', 'μ']
#
#
#
# What is the difference between 高铁 (gaotie) and 动车 (dong che)?
# How many kids read newspaper in india?
#
# What is the difference between 高铁 (gaotie) and 动车 (dong che)?
# How many kids read newspaper in india?
# ['高', '铁', '动', '车'] []
#
#
#
# What is the meaning of “shalini”?
# What does 有緣無份 mean?
#
# What is the meaning of 'shalini'?
# What does 有緣無份 mean?
# [] ['有', '緣', '無', '份']
#
#
#
# What is the most visited tourist attraction in Africa?
# जिस स्थान का आपने भ्रमण किया है उसपर 50-60 शब्दों में प्रतिवेदन लिखिए?
#
# What is the most visited tourist attraction in Africa?
# जिस स्थान का आपने भ्रमण किया है उसपर 50-60 शब्दों में प्रतिवेदन लिखिए?
# [] ['ज', 'ि', 'स', 'स', '्', 'थ', 'ा', 'न', 'क', 'ा', 'आ', 'प', 'न', 'े', 'भ', '्', 'र', 'म', 'ण', 'क', 'ि', 'य', 'ा', 'ह', 'ै', 'उ', 'स', 'प', 'र', 'श', 'ब', '्', 'द', 'ो', 'ं', 'म', 'े', 'ं', 'प', '्', 'र', 'त', 'ि', 'व', 'े', 'द', 'न', 'ल', 'ि', 'ख', 'ि', 'ए']
#
#
#
# What does のだ and んだ mean in Japanese?
# What does "まな" mean in Japanese?
#
# What does のだ and んだ mean in Japanese?
# What does "まな" mean in Japanese?
# ['の', 'だ', 'ん', 'だ'] ['ま', 'な']
#
#
#
# How do I say "形から入る" in English?
# How do you say 粘人 in English?
#
# How do I say "形から入る" in English?
# How do you say 粘人 in English?
# ['形', 'か', 'ら', '入', 'る'] ['粘', '人']
#
#
#
# A student dissolves 20g of salt in a pan of 200 mL of water. How much salt is left after all the water evaporates?
# At 20°C, the solubility of LiF in water is 0.27 g per 100 mL, whereas that of LiBr is 167 g per 100 mL. Can you explain the relative solubility of the two salts?
#
# A student dissolves 20g of salt in a pan of 200 mL of water. How much salt is left after all the water evaporates?
# At 20°C, the solubility of LiF in water is 0.27 g per 100 mL, whereas that of LiBr is 167 g per 100 mL. Can you explain the relative solubility of the two salts?
# [] ['°']
#
#
#
# Where is the best place to eat roast duck (烤鸭, kǎoyā, Peking duck) in Shanghai?
# Where is the best place to eat roast duck (烤鸭, kǎoyā, Peking duck) in Beijing?
#
# Where is the best place to eat roast duck (烤鸭, kǎoyā, Peking duck) in Shanghai?
# Where is the best place to eat roast duck (烤鸭, kǎoyā, Peking duck) in Beijing?
# ['烤', '鸭', 'ǎ', 'ā'] ['烤', '鸭', 'ǎ', 'ā']
#
#
#
# What is the english word for "अंत्योदय"?
# What is the English word for 'akik'?
#
# What is the english word for "अंत्योदय"?
# What is the English word for 'akik'?
# ['अ', 'ं', 'त', '्', 'य', 'ो', 'द', 'य'] []
#
#
#
# What is the precise meaning of the Sanskrit word समवेताः?
# What is the precise meaning of the Sanskrit word क्लैब्यं?
#
# What is the precise meaning of the Sanskrit word समवेताः?
# What is the precise meaning of the Sanskrit word क्लैब्यं?
# ['स', 'म', 'व', 'े', 'त', 'ा', 'ः'] ['क', '्', 'ल', 'ै', 'ब', '्', 'य', 'ं']
#
#
#
# What is a good way to say 横向卷轴rpg游戏 in English?
# How can I say 色迷迷的 in English?
#
# What is a good way to say 横向卷轴rpg游戏 in English?
# How can I say 色迷迷的 in English?
# ['横', '向', '卷', '轴', '游', '戏'] ['色', '迷', '迷', '的']
#
#
#
# How can you prove 2^p-1 can be a prime number?
# Is every prime number other than 2 and 3 of the form (6k±1)?
#
# How can you prove 2^p-1 can be a prime number?
# Is every prime number other than 2 and 3 of the form (6k±1)?
# [] ['±']
#
#
#
# If the Sun disappeared, would the Earth continue in its orbit for 8½ minutes?
# If the sun blew up, how long would it take for the earth to go out of orbit?
#
# If the Sun disappeared, would the Earth continue in its orbit for 8½ minutes?
# If the sun blew up, how long would it take for the earth to go out of orbit?
# ['½'] []
#
#
#
# What is the difference between 多少 and 几 in Mandarin Chinese?
# What is the difference between Chinese and Mandarin?
#
# What is the difference between 多少 and 几 in Mandarin Chinese?
# What is the difference between Chinese and Mandarin?
# ['多', '少', '几'] []
#
#
#
# What is the concept behind the Kannada phrase 'ಬಗಣಿ ಗೂಟ' (Bagni Goota)?
# Who found Kannada?
#
# What is the concept behind the Kannada phrase 'ಬಗಣಿ ಗೂಟ' (Bagni Goota)?
# Who found Kannada?
# ['ಬ', 'ಗ', 'ಣ', 'ಿ', 'ಗ', 'ೂ', 'ಟ'] []
#
#
#
# What are some of the characteristics of a female scorpio sun, moon at 23°49, venus, mercury retro, pluto, and Scorpio also the ascendant at 24°15?
# What are the characteristics of a female whose sun, moon, Venus, Mercury, Pluto and ascendant are all in Scorpio?
#
# What are some of the characteristics of a female scorpio sun, moon at 23°49, venus, mercury retro, pluto, and Scorpio also the ascendant at 24°15?
# What are the characteristics of a female whose sun, moon, Venus, Mercury, Pluto and ascendant are all in Scorpio?
# ['°', '°'] []
#
#
#
# What does GMOとくとくポイント mean?
# What does “homegirl” mean?
#
# What does GMOとくとくポイント mean?
# What does 'homegirl' mean?
# ['と', 'く', 'と', 'く', 'ポ', 'イ', 'ン', 'ト'] []
#
#
#
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證) for how long can you enter and remain in Mainland China? Is there any time limitation at all?
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證), can you enter Mainland China without it?
#
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證) for how long can you enter and remain in Mainland China? Is there any time limitation at all?
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證), can you enter Mainland China without it?
# ['港', '澳', '居', '民', '來', '往', '內', '地', '通', '行', '證'] ['港', '澳', '居', '民', '來', '往', '內', '地', '通', '行', '證']
#
#
#
# What does धर्मकोटी mean?
# What does ΙΧΣ mean?
#
# What does धर्मकोटी mean?
# What does ΙΧΣ mean?
# ['ध', 'र', '्', 'म', 'क', 'ो', 'ट', 'ी'] ['Ι', 'Χ', 'Σ']
#
#
#
# What is the value of 2^2°2^2^ infinity?
# What is the value of 3^infinity?
#
# What is the value of 2^2°2^2^ infinity?
# What is the value of 3^infinity?
# ['°'] []
#
#
#
# What is the literal meaning of the word خواهش میکنم?
# What is the literal meaning of the word 'Tashreef'?
#
# What is the literal meaning of the word خواهش میکنم?
# What is the literal meaning of the word 'Tashreef'?
# ['خ', 'و', 'ا', 'ه', 'ش', 'م', 'ی', 'ک', 'ن', 'م'] []
#
#
#
# A particle moves along the x-axis so that at time t ≥ 0 its position is given by [math]x(t) = \cos \sqrt{t}[/math]. What is the velocity of the particle at the first instance the particle is at the origin?
# A particle moves in a straight line such that its acceleration after time t sec is sin5^2, where a=2-t^2+t of its initial velocity 3m5^2. What is the expression for 5 the distance travelled from the start?
#
# A particle moves along the x-axis so that at time t ≥ 0 its position is given by [math]x(t) = \cos \sqrt{t}[/math]. What is the velocity of the particle at the first instance the particle is at the origin?
# A particle moves in a straight line such that its acceleration after time t sec is sin5^2, where a=2-t^2+t of its initial velocity 3m5^2. What is the expression for 5 the distance travelled from the start?
# ['≥'] []
#
#
#
# How do I to translate Chinese "自欺欺人" into English?
# How do I translate Chinese to English well?
#
# How do I to translate Chinese "自欺欺人" into English?
# How do I translate Chinese to English well?
# ['自', '欺', '欺', '人'] []
#
#
#
# Trigonometry (mathematics): How does the tan inverse of -8/6 = -53.13°?
# Trigonometry: Can you prove the hypotenuse divided by the short leg is equal to the Tan of the greater angle plus the Tan of 1/2 the lesser angle?
#
# Trigonometry (mathematics): How does the tan inverse of -8/6 = -53.13°?
# Trigonometry: Can you prove the hypotenuse divided by the short leg is equal to the Tan of the greater angle plus the Tan of 1/2 the lesser angle?
# ['°'] []
#
#
#
# Who is the Apple of Android devices?
# زب app: Can I install a Nomao naked camera for an Android?
#
# Who is the Apple of Android devices?
# زب app: Can I install a Nomao naked camera for an Android?
# [] ['ز', 'ب']
#
#
#
# Did Microsoft make their online office from scratch? Or Are there any tools available to convert PC source code to web one?
# How do I change negative multiplicative inverse to positive? (i.e. 0−5(70) ≡22(70) (mod27) -5 ===>22)
#
# Did Microsoft make their online office from scratch? Or Are there any tools available to convert PC source code to web one?
# How do I change negative multiplicative inverse to positive? (i.e. 0−5(70) ≡22(70) (mod27) -5 ===>22)
# [] ['−', '≡']
#
#
#
# What does the ¿ symbol mean?
# What does this symbol ≈ mean?
#
# What does the ¿ symbol mean?
# What does this symbol ≈ mean?
# ['¿'] ['≈']
#
#
#
# Are vocalics and body language needed in an ordinary conversation?
# Are there any Arabic language websites that use vocalization (tashkeel / تشكيل)  in their online content or articles?
#
# Are vocalics and body language needed in an ordinary conversation?
# Are there any Arabic language websites that use vocalization (tashkeel / تشكيل)  in their online content or articles?
# [] ['ت', 'ش', 'ك', 'ي', 'ل']
#
#
#
# What is meaning of makbuja?
# What is meaning of ไฟน้ำค้าง?
#
# What is meaning of makbuja?
# What is meaning of ไฟน้ำค้าง?
# [] ['ไ', 'ฟ', 'น', '้', 'ำ', 'ค', '้', 'า', 'ง']
#
#
#
# What is quoro?
# What is ∀?
#
# What is quoro?
# What is ∀?
# [] ['∀']
#
#
#
# How do I integrate [math]e^{x+2}[/math] and [math]e^{x^2}[/math] and [math]e^ {x^{-2}}[/math]?
# How do you solve the inequality [math]3x^2-7x+1≤0[/math]?
#
# How do I integrate [math]e^{x+2}[/math] and [math]e^{x^2}[/math] and [math]e^ {x^{-2}}[/math]?
# How do you solve the inequality [math]3x^2-7x+1≤0[/math]?
# [] ['≤']
#
#
#
# In English, why does the word “hundred” remain in its singular form regardless of the number preceding it (one hundred, two hundred, ten hundred)?
# What is the origin and meaning of Everyone Dies™?
#
# In English, why does the word 'hundred' remain in its singular form regardless of the number preceding it (one hundred, two hundred, ten hundred)?
# What is the origin and meaning of Everyone Dies™?
# [] ['™']
#
#
#
# Why use condensed milk in mirror glaze?
# If water evaporates at 100°C then why after you shower is there condensation on the Mirror? The water couldn't have been over 70°C because you would have gotten burnt. So why is there condensation on the mirror?
#
# Why use condensed milk in mirror glaze?
# If water evaporates at 100°C then why after you shower is there condensation on the Mirror? The water couldn't have been over 70°C because you would have gotten burnt. So why is there condensation on the mirror?
# [] ['°', '°']
#
#
#
# Is this years surge in home runs in MLB due to performance enhancing drugs?
# I am male, 17 years, 6′ 2″ and 84 kg. Is it okay? How can I stop my height growth?
#
# Is this years surge in home runs in MLB due to performance enhancing drugs?
# I am male, 17 years, 6′ 2″ and 84 kg. Is it okay? How can I stop my height growth?
# [] ['′', '″']
#
#
#
# How do you say「勿忘初心」in english?
# How do I say 与人方便, 与己方便 in English?
#
# How do you say「勿忘初心」in english?
# How do I say 与人方便, 与己方便 in English?
# ['「', '勿', '忘', '初', '心', '」'] ['与', '人', '方', '便', '与', '己', '方', '便']
#
#
#
# What does ":P" mean?
# What is the meaning of पशुगमन?
#
# What does ":P" mean?
# What is the meaning of पशुगमन?
# [] ['प', 'श', 'ु', 'ग', 'म', 'न']
#
#
#
# What is the precise meaning of the Sanskrit word दुखृन्करणे?
# What is the precise meaning of the sanskrit word समुपस्थितम्?
#
# What is the precise meaning of the Sanskrit word दुखृन्करणे?
# What is the precise meaning of the sanskrit word समुपस्थितम्?
# ['द', 'ु', 'ख', 'ृ', 'न', '्', 'क', 'र', 'ण', 'े'] ['स', 'म', 'ु', 'प', 'स', '्', 'थ', 'ि', 'त', 'म', '्']
#
#
#
# What are some of the ways to get funding for Master's in U.S?
# Why No. of moles of a given substance=Mass of the substance ÷ Molar mass of the substance=No. of formula units of the substance ÷ Avogadro's constant?
# What are some of the ways to get funding for Master's in U.S?
# Why No. of moles of a given substance=Mass of the substance ÷ Molar mass of the substance=No. of formula units of the substance ÷ Avogadro's constant?
# [] ['÷', '÷']
#
#
#
# What does "まな" mean in Japanese?
# What does this mean in Japanese?
#
# What does "まな" mean in Japanese?
# What does this mean in Japanese?
# ['ま', 'な'] []
#
#
#
# What is the difference between 多少 and 几 in Mandarin Chinese?
# What is the difference between 画 and 画画 in Mandarin Chinese?
#
# What is the difference between 多少 and 几 in Mandarin Chinese?
# What is the difference between 画 and 画画 in Mandarin Chinese?
# ['多', '少', '几'] ['画', '画', '画']
#
#
#
# What is the difference between ج and ز?
# What is the difference between "&" and "and"?
#
# What is the difference between ج and ز?
# What is the difference between "&" and "and"?
# ['ج', 'ز'] []
#
#
#
# What does 'polytics' mean?
# What does 精神 mean?
#
# What does 'polytics' mean?
# What does 精神 mean?
# [] ['精', '神']
#
#
#
# Is "sher" (शेर) a lion or a tiger?
# What are the origins of the Hindi phrase "Majboori Ka Naam Gandhiji"?
#
# Is "sher" (शेर) a lion or a tiger?
# What are the origins of the Hindi phrase "Majboori Ka Naam Gandhiji"?
# ['श', 'े', 'र'] []
#
#
#
# I am 17 yo male and I consider myself as a super attractive person, also my legs are turning me on as nothing else. Is it okay?
# 潘迪華 1965 I am Yours for guitar chords?
#
# I am 17 yo male and I consider myself as a super attractive person, also my legs are turning me on as nothing else. Is it okay?
# 潘迪華 1965 I am Yours for guitar chords?
# [] ['潘', '迪', '華']
#
#
#
# What are some good ways to remember how to write Chinese characters?
# How can I remember how to write the Chinese character 鼠?
#
# What are some good ways to remember how to write Chinese characters?
# How can I remember how to write the Chinese character 鼠?
# [] ['鼠']
#
#
#
# When am I going to get my own personal Navi?
# Then what is the amount of insolation received at 90°?
#
# When am I going to get my own personal Navi?
# Then what is the amount of insolation received at 90°?
# [] ['°']
#
#
#
# I have been turned down my whole life. Why should I help fighting for women's privileges?
# Male, 40, 5′3″ virgin, have been beeing turned down my whole life. Should I care about feminism? Why?
#
# I have been turned down my whole life. Why should I help fighting for women's privileges?
# Male, 40, 5′3″ virgin, have been beeing turned down my whole life. Should I care about feminism? Why?
# [] ['′', '″']
#
#
#
# What does "封建成功" mean in Chinese?
# What does \U00024d13 mean in Chinese?
#
# What does "封建成功" mean in Chinese?
# What does \U00024d13 mean in Chinese?
# ['封', '建', '成', '功'] []
#
#
#
# How can you prove that if A ⊆ B, then A ∩ B' = ∅?
# How do you go from (a-b) (a+b) - b(a+b) to (a+b) (a+b+b)?
#
# How can you prove that if A ⊆ B, then A ∩ B' = ∅?
# How do you go from (a-b) (a+b) - b(a+b) to (a+b) (a+b+b)?
# ['⊆', '∩', '∅'] []
#
#
#
# Should I drink amway nutrilite protein powder to gain muscles?
# Is "Nutrilite® Protein Powder" good to use with milk every day in the morning instead of a usual breakfast?
#
# Should I drink amway nutrilite protein powder to gain muscles?
# Is "Nutrilite® Protein Powder" good to use with milk every day in the morning instead of a usual breakfast?
# [] ['®']
#
#
#
# Will there be 会不会有不懂中文的人去翻译然后回答这个问题?
# Why do people keep bringing up tachyons as if they really exist?
#
# Will there be 会不会有不懂中文的人去翻译然后回答这个问题?
# Why do people keep bringing up tachyons as if they really exist?
# ['会', '不', '会', '有', '不', '懂', '中', '文', '的', '人', '去', '翻', '译', '然', '后', '回', '答', '这', '个', '问', '题'] []
#
#
#
# What is the difference between “杂” (zá) and ”内脏" (nèizàng)?
# What is the difference between ";" and ","?
#
# What is the difference between '杂' (zá) and '内脏" (nèizàng)?
# What is the difference between ";" and ","?
# ['杂', 'á', '内', '脏', 'è', 'à'] []
#
#
#
# Can anyone translate this ? ऐहंकार का परदा हटा, तो जो है वह प्रगट हो जाता है।-Osho?
# Can anyone translate this ? ऐहंकार का परदा हटा, तो जो है वह प्रगट हो जाता है।-Osho
#
# Can anyone translate this ? ऐहंकार का परदा हटा, तो जो है वह प्रगट हो जाता है।-Osho?
# Can anyone translate this ? ऐहंकार का परदा हटा, तो जो है वह प्रगट हो जाता है।-Osho
# ['ऐ', 'ह', 'ं', 'क', 'ा', 'र', 'क', 'ा', 'प', 'र', 'द', 'ा', 'ह', 'ट', 'ा', 'त', 'ो', 'ज', 'ो', 'ह', 'ै', 'व', 'ह', 'प', '्', 'र', 'ग', 'ट', 'ह', 'ो', 'ज', 'ा', 'त', 'ा', 'ह', 'ै', '।'] ['ऐ', 'ह', 'ं', 'क', 'ा', 'र', 'क', 'ा', 'प', 'र', 'द', 'ा', 'ह', 'ट', 'ा', 'त', 'ो', 'ज', 'ो', 'ह', 'ै', 'व', 'ह', 'प', '्', 'र', 'ग', 'ट', 'ह', 'ो', 'ज', 'ा', 'त', 'ा', 'ह', 'ै', '।']
#
#
#
# What is the correct pronunciation of 'Alekhine' or Алекса́ндр Алекса́ндрович Але́хин?
# What is the correct pronunciation of "josue"?
#
# What is the correct pronunciation of 'Alekhine' or Алекса́ндр Алекса́ндрович Але́хин?
# What is the correct pronunciation of "josue"?
# ['А', 'л', 'е', 'к', 'с', 'а', '́', 'н', 'д', 'р', 'А', 'л', 'е', 'к', 'с', 'а', '́', 'н', 'д', 'р', 'о', 'в', 'и', 'ч', 'А', 'л', 'е', '́', 'х', 'и', 'н'] []
#
#
#
# Does one is forced to conclude that 2X=X\sqrt {2} if series a+b+c+d+…=X?
# Prove that if A, B, C, and D are sets, then (A ∩ B) X (C ∩ D) = (A X C) ∩ (B X D).Deduce that the cartesian multiplication of sets distributes over the operation of intersection, that is, that (A X B) X C = (AXC) ∩ (BXC) and AX (B∩C)=(AXB)∩(AXC) for all A, B, and C. ?
#
# Does one is forced to conclude that 2X=X\sqrt {2} if series a+b+c+d+ ... =X?
# Prove that if A, B, C, and D are sets, then (A ∩ B) X (C ∩ D) = (A X C) ∩ (B X D).Deduce that the cartesian multiplication of sets distributes over the operation of intersection, that is, that (A X B) X C = (AXC) ∩ (BXC) and AX (B∩C)=(AXB)∩(AXC) for all A, B, and C. ?
# [] ['∩', '∩', '∩', '∩', '∩', '∩']
#
#
#
# What is the smallest city in Brazil?
# From the standpoint of concrete strength, which of the two options is undesirable? A. Cast at 5°C and cured at 21°C b. Cast at 21°C and cured at 5°C
#
# What is the smallest city in Brazil?
# From the standpoint of concrete strength, which of the two options is undesirable? A. Cast at 5°C and cured at 21°C b. Cast at 21°C and cured at 5°C
# [] ['°', '°', '°', '°']
#
#
#
# How would you simplify [math]\sqrt{3+\sqrt 2}[/math]?
# How can I simplify (3+2(2) ½) ½?
#
# How would you simplify [math]\sqrt{3+\sqrt 2}[/math]?
# How can I simplify (3+2(2) ½) ½?
# [] ['½', '½']
#
#
#
# what’s your review of the Wuhan university of textile？
# What is your review of Wuhan University (武汉大学)?
#
# what's your review of the Wuhan university of textile?
# What is your review of Wuhan University (武汉大学)?
# [] ['武', '汉', '大', '学']
#
#
#
# ABC is a triangle with a right angle at  A.M and N are points on BC such that AM is the altitude, and AN is the  angle bisector of ∠BAC. If CN/NB=21,what is CM/MB?
# In a triangle ABC, the altitudes from A,B, C meet BC,AC and AB at D,E, F.Prove that perpendicular bisector of EF also bisects BC.How to prove it?
#
# ABC is a triangle with a right angle at  A.M and N are points on BC such that AM is the altitude, and AN is the  angle bisector of ∠BAC. If CN/NB=21,what is CM/MB?
# In a triangle ABC, the altitudes from A,B, C meet BC,AC and AB at D,E, F.Prove that perpendicular bisector of EF also bisects BC.How to prove it?
# ['∠'] []
#
#
#
# What does "歪果仁" mean in English?
# What does ‘ennikkum’ mean in English?
#
# What does "歪果仁" mean in English?
# What does 'ennikkum' mean in English?
# ['歪', '果', '仁'] []
#
#
#
# How can we prove that we can prove 2+2=4?
# How do I prove that 10÷2=2?
#
# How can we prove that we can prove 2+2=4?
# How do I prove that 10÷2=2?
# [] ['÷']
#
#
#
# What is the solution of this question: lim(x➡0) (1-cos2x)/x?
# What are the best books to consult if u want to develop logical thinking of a programmer?
#
# What is the solution of this question: lim(x➡0) (1-cos2x)/x?
# What are the best books to consult if u want to develop logical thinking of a programmer?
# ['➡'] []
#
#
#
# What is the meaning of सहिष्णुता in Hindi?
# What is the meaning of "Ishavasyam" in Hindi?
#
# What is the meaning of सहिष्णुता in Hindi?
# What is the meaning of "Ishavasyam" in Hindi?
# ['स', 'ह', 'ि', 'ष', '्', 'ण', 'ु', 'त', 'ा'] []
#
#
#
# How do you say ‘prodotto notevole’ in English?
# How can I say 色迷迷的 in English?
#
# How do you say 'prodotto notevole' in English?
# How can I say 色迷迷的 in English?
# [] ['色', '迷', '迷', '的']
#
#
#
# How can I partially automate signaling pathways reconstruction from the literature?
# How does the brain trace addiction from increased ΔFosB in the nucleus accumbens to individual stimuli? What pathways are involved?
#
# How can I partially automate signaling pathways reconstruction from the literature?
# How does the brain trace addiction from increased ΔFosB in the nucleus accumbens to individual stimuli? What pathways are involved?
# [] ['Δ']
#
#
#
# What is meaning of รางรักพรางใจ?
# What does k mean?
#
# What is meaning of รางรักพรางใจ?
# What does k mean?
# ['ร', 'า', 'ง', 'ร', 'ั', 'ก', 'พ', 'ร', 'า', 'ง', 'ใ', 'จ'] []
#
#
#
# What does "飛簷走壁" mean?
# What does ℝ² mean?
#
# What does "飛簷走壁" mean?
# What does R2 mean?
# ['飛', '簷', '走', '壁'] []
#
#
#
# How does presynaptic α2- receptors and prostaglandins E series control sympathetic nervous activity?
# How does presynaptic α2- receptors and prostaglandins E series control of sympathetic nervous activity?
#
# How does presynaptic α2- receptors and prostaglandins E series control sympathetic nervous activity?
# How does presynaptic α2- receptors and prostaglandins E series control of sympathetic nervous activity?
# ['α'] ['α']
#
#
#
# I drank 2 glasses of white wine, the last 6pm Thurs. I'm 5′2″, 130lbs. Had an etg test Fri. 330pm, think I’ll pass? I drank at least 48oz of H2O
# Does an alternating current through a superconductor create radiation? How is this radiation different from regular dipole radiation?
#
# I drank 2 glasses of white wine, the last 6pm Thurs. I'm 5′2″, 130lbs. Had an etg test Fri. 330pm, think I'll pass? I drank at least 48oz of H2O
# Does an alternating current through a superconductor create radiation? How is this radiation different from regular dipole radiation?
# ['′', '″'] []
#
#
#
# What is a ¾ pose and ¾ smile?
# What does "that smile though" mean?
#
# What is a ¾ pose and ¾ smile?
# What does "that smile though" mean?
# ['¾', '¾'] []
#
#
#
# Can intelligent woman marry a simple man?
# Can a 5′1″ man marry a 5′6″ woman?
#
# Can intelligent woman marry a simple man?
# Can a 5′1″ man marry a 5′6″ woman?
# [] ['′', '″', '′', '″']
# What is the number of terms in the expansion of (x - 3x² + 3x³) ²°?
# In the multiplicative group C^x complex numbers, find the order of the elements A = -√2/2+√2/2i and B = -√2/2-√2/2i?
#
# What is the number of terms in the expansion of (x - 3x² + 3x³) ²°?
# In the multiplicative group C^x complex numbers, find the order of the elements A = -sqrt2/2+sqrt2/2i and B = -sqrt2/2-sqrt2/2i?
# ['²', '³', '²', '°'] []
#
#
#
# What does 亮瞎了 mean?
# What does يعني mean?
#
# What does 亮瞎了 mean?
# What does يعني mean?
# ['亮', '瞎', '了'] ['ي', 'ع', 'ن', 'ي']
#
#
#
# Can my followers on Tumblr see what I post on my secondary blog?
# Why does Tumblr not allow secondary accounts/blogs to Initiate Social Features (Follow, Like, Ask, Submit → to other blogs)?
#
# Can my followers on Tumblr see what I post on my secondary blog?
# Why does Tumblr not allow secondary accounts/blogs to Initiate Social Features (Follow, Like, Ask, Submit → to other blogs)?
# [] ['→']
#
#
#
# What does باقر mean in Arabic?
# What does this mean in Arabic?
#
# What does باقر mean in Arabic?
# What does this mean in Arabic?
# ['ب', 'ا', 'ق', 'ر'] []
#
#
#
# How do you translate 意思意思 into english?
# How do I translate “吃香喝辣” into English?
#
# How do you translate 意思意思 into english?
# How do I translate '吃香喝辣' into English?
# ['意', '思', '意', '思'] ['吃', '香', '喝', '辣']
#
#
#
# If the DPP wins the ROC presidency in 2016, will Tsai Yingwen cede Taiwanese claims to the Diaoyu Islands (釣魚島) / Senkaku Islands(尖閣諸島) to Japan?
# Why does China not just take over the Senkaku/Diaoyu Islands?
#
# If the DPP wins the ROC presidency in 2016, will Tsai Yingwen cede Taiwanese claims to the Diaoyu Islands (釣魚島) / Senkaku Islands(尖閣諸島) to Japan?
# Why does China not just take over the Senkaku/Diaoyu Islands?
# ['釣', '魚', '島', '尖', '閣', '諸', '島'] []
#
#
#
# I have mis-transcribed the name of a Korean song as “북쪽앟관자키”, but what should the name actually be?
# What is the name of this Korean song?
#
# I have mis-transcribed the name of a Korean song as '북쪽앟관자키', but what should the name actually be?
# What is the name of this Korean song?
# ['북', '쪽', '앟', '관', '자', '키'] []
#
#
#
# What is the meaning of Urdu word وصیت (Wasiyat)?
# What is the meaning of Urdu word 'Ittefaq'?
#
# What is the meaning of Urdu word وصیت (Wasiyat)?
# What is the meaning of Urdu word 'Ittefaq'?
# ['و', 'ص', 'ی', 'ت'] []
#
#
#
# Is it a good idea to get admission in IIT who has 5 yrs of work experience?
# The temperature at Drass in J&K may be as low as -45°C, while Thiruvananthapuram, on the other hand, may have a temperature of 22°C on a winter night. Why?
#
# Is it a good idea to get admission in IIT who has 5 yrs of work experience?
# The temperature at Drass in J&K may be as low as -45°C, while Thiruvananthapuram, on the other hand, may have a temperature of 22°C on a winter night. Why?
# [] ['°', '°']
#
#
#
# I'm a 32 year old healthy mom of two.. I stay active .. I am only 5′3″ and I weigh 155 lbs, is this considered overweight even though I look great?
# I am 171 cm tall and I weigh 80 kilograms, I know that sounds overweight, but I feel like I don't look too overweight? Is this normal? (Also I tend to have a large body frame and feel pretty great)
#
# I'm a 32 year old healthy mom of two.. I stay active .. I am only 5′3″ and I weigh 155 lbs, is this considered overweight even though I look great?
# I am 171 cm tall and I weigh 80 kilograms, I know that sounds overweight, but I feel like I don't look too overweight? Is this normal? (Also I tend to have a large body frame and feel pretty great)
# ['′', '″'] []
#
#
#
# What is the difference between 令 and 使?
# What's the difference between 使, 让, and 叫?
#
# What is the difference between 令 and 使?
# What's the difference between 使, 让, and 叫?
# ['令', '使'] ['使', '让', '叫']
#
#
#
# How do I translate "骂人" into English?
# How do you translate "一是一，二是二" into English?
#
# How do I translate "骂人" into English?
# How do you translate "一是一，二是二" into English?
# ['骂', '人'] ['一', '是', '一', '，', '二', '是', '二']
#
#
#
# What does |-/ mean?
# What is meaning of ไฟสิ้นเชื้อ?
#
# What does |-/ mean?
# What is meaning of ไฟสิ้นเชื้อ?
# [] ['ไ', 'ฟ', 'ส', 'ิ', '้', 'น', 'เ', 'ช', 'ื', '้', 'อ']
#
#
#
# How are bodies of water named? And who gets to decide? (Ex. Pacific Ocean, South China Sea)
# How does water in the ocean and sea evaporate? As the temperature of sun rays is never 100 °C, how does it evaporate the water?
#
# How are bodies of water named? And who gets to decide? (Ex. Pacific Ocean, South China Sea)
# How does water in the ocean and sea evaporate? As the temperature of sun rays is never 100 °C, how does it evaporate the water?
# [] ['°']
#
#
#
# Who is the founder of OSBN®?
# Who is the founder of Telemainia?
#
# Who is the founder of OSBN®?
# Who is the founder of Telemainia?
# ['®'] []
#
#
#
# What could Russian word "фантастюсенькая" possibly mean?
# What could Russian word "рученюсенька" ("ruchenyusen'ka") possibly mean?
#
# What could Russian word "фантастюсенькая" possibly mean?
# What could Russian word "рученюсенька" ("ruchenyusen'ka") possibly mean?
# ['ф', 'а', 'н', 'т', 'а', 'с', 'т', 'ю', 'с', 'е', 'н', 'ь', 'к', 'а', 'я'] ['р', 'у', 'ч', 'е', 'н', 'ю', 'с', 'е', 'н', 'ь', 'к', 'а']
#
#
#
# The resultant of two forces has magnitude 20N. One of the forces has magnitude 20√3N making an angle of 30° with the resultant? What is the magnitude of the other force?
# Two equal forces have their resultant equal. At what angle are they inclined to each other?
#
# The resultant of two forces has magnitude 20N. One of the forces has magnitude 20sqrt3N making an angle of 30° with the resultant? What is the magnitude of the other force?
# Two equal forces have their resultant equal. At what angle are they inclined to each other?
# ['°'] []
#
#
#
# Why isn't i^2 equal ±1?
# Why does '1^2' not equal '2'?
#
# Why isn't i^2 equal ±1?
# Why does '1^2' not equal '2'?
# ['±'] []
#
#
#
# What is the difference between the following sentences with “will” and "would"?
# What's the difference between 几 and 多少 in the following sentences?
#
# What is the difference between the following sentences with 'will' and "would"?
# What's the difference between 几 and 多少 in the following sentences?
# [] ['几', '多', '少']
#
#
#
# What is the meaning of Hindi word 'Suprabhat'?
# What is the meaning of a hindi word बेदबी?
#
# What is the meaning of Hindi word 'Suprabhat'?
# What is the meaning of a hindi word बेदबी?
# [] ['ब', 'े', 'द', 'ब', 'ी']
#
#
#
# Can I delt my call history in bsnl?
# Can d orbitals form σ bonds?
#
# Can I delt my call history in bsnl?
# Can d orbitals form σ bonds?
# [] ['σ']
#
#
#
# What does the ºДºщ emoticon mean?
# What does the emoticon ^^ mean?
#
# What does the ºДºщ emoticon mean?
# What does the emoticon ^^ mean?
# ['º', 'Д', 'º', 'щ'] []
#
#
#
# What does the Chinese word "女漢子" mean?
# What does the Chinese word “loong” mean?
#
# What does the Chinese word "女漢子" mean?
# What does the Chinese word 'loong' mean?
# ['女', '漢', '子'] []
#
#
#
# How do you pronounce "Hamferð"?
# How do you pronounce "Dohnányi"?
#
# How do you pronounce "Hamferð"?
# How do you pronounce "Dohnanyi"?
# ['ð'] []
#
#
#
# Is network marketing agood carrier?
# Sinθ =17/37 ﬁnd the exact value of secθ . 1/cos (27.352232) = 1.12587, do I need to obtain a surd or a fraction as an exact value, or this is fine?
#
# Is network marketing agood carrier?
# Sinθ =17/37 ﬁnd the exact value of secθ . 1/cos (27.352232) = 1.12587, do I need to obtain a surd or a fraction as an exact value, or this is fine?
# [] ['θ', 'ﬁ', 'θ']
#
#
#
# What does "鴻日" mean in English?
# What does 胖口 mean in English?
#
# What does "鴻日" mean in English?
# What does 胖口 mean in English?
# ['鴻', '日'] ['胖', '口']
#
#
#
# What is the meaning of tamil words “yaazha” (யாழ) and “munnilaiyasaisol” முன்னிலையசைச்சொல்)?
# What is the meaning of Tamil word 'Aiyyo'?
#
# What is the meaning of tamil words 'yaazha' (யாழ) and 'munnilaiyasaisol' முன்னிலையசைச்சொல்)?
# What is the meaning of Tamil word 'Aiyyo'?
# ['ய', 'ா', 'ழ', 'ம', 'ு', 'ன', '்', 'ன', 'ி', 'ல', 'ை', 'ய', 'ச', 'ை', 'ச', '்', 'ச', 'ொ', 'ல', '்'] []
#
#
#
# How long did it take for you to trust someone to fall in love?
# ‘No weightage of class 12 marks in JEE 2017′, is it an advantage or disadvantage?
#
# How long did it take for you to trust someone to fall in love?
# 'No weightage of class 12 marks in JEE 2017′, is it an advantage or disadvantage?
# [] ['′']
#
#
#
# If A'∪B=U How do we prove A⊆B?
# How can I prove that A-(A-B) ⊂B?
#
# If A'∪B=U How do we prove A⊆B?
# How can I prove that A-(A-B) ⊂B?
# ['∪', '⊆'] ['⊂']
#
#
#
# What is the minimum value of |z-1|+|z-5|?
# What is the minimum value of |−1|+|−5|?
#
# What is the minimum value of |z-1|+|z-5|?
# What is the minimum value of |−1|+|−5|?
# [] ['−', '−']
#
#
#
# What does ℝ² mean?
# What does 呵呵 mean?
#
# What does R2 mean?
# What does 呵呵 mean?
# [] ['呵', '呵']
#
#
#
# What is the English translation of "dep qua"?
# What is the English translation of 存在即是合理的?
#
# What is the English translation of "dep qua"?
# What is the English translation of 存在即是合理的?
# [] ['存', '在', '即', '是', '合', '理', '的']
#
#
#
# What is the (vector) displacement between positions (0.4i + 0.1j) m and (−0.8i + 0.6j) m, and the distance between the two positions?
# What is the (vector) displacement between positions (0.4i + 0.1j) m and (−0.8i + 0.6) m, and the distance between the two positions?
#
# What is the (vector) displacement between positions (0.4i + 0.1j) m and (−0.8i + 0.6j) m, and the distance between the two positions?
# What is the (vector) displacement between positions (0.4i + 0.1j) m and (−0.8i + 0.6) m, and the distance between the two positions?
# ['−'] ['−']
#
#
#
# How to say "and" in Japanese?
# How do I say - , + , x and ÷ in Japanese?
#
# How to say "and" in Japanese?
# How do I say - , + , x and ÷ in Japanese?
# [] ['÷']
#
#
#
# Can someone translate this full Tamil song "எல்லோரும் எல்லாமும் பெறவேண்டும் இங்கு இல்லாமை இல்லாத நிலை வேண்டும் " to English?
# Can someone translate this Tamil song to English?
#
# Can someone translate this full Tamil song "எல்லோரும் எல்லாமும் பெறவேண்டும் இங்கு இல்லாமை இல்லாத நிலை வேண்டும் " to English?
# Can someone translate this Tamil song to English?
# ['எ', 'ல', '்', 'ல', 'ோ', 'ர', 'ு', 'ம', '்', 'எ', 'ல', '்', 'ல', 'ா', 'ம', 'ு', 'ம', '்', 'ப', 'ெ', 'ற', 'வ', 'ே', 'ண', '்', 'ட', 'ு', 'ம', '்', 'இ', 'ங', '்', 'க', 'ு', 'இ', 'ல', '்', 'ல', 'ா', 'ம', 'ை', 'இ', 'ல', '்', 'ல', 'ா', 'த', 'ந', 'ி', 'ல', 'ை', 'வ', 'ே', 'ண', '்', 'ட', 'ு', 'ம', '்'] []
#
#
#
# What does this symbol mean?
# What do the symbols like these.. ￦¥§¤㊙㊗ ..mean on my keyboard?
#
# What does this symbol mean?
# What do the symbols like these.. ￦$§¤㊙㊗ ..mean on my keyboard?
# [] ['￦', '§', '¤', '㊙', '㊗']
#
#
#
# What is a good word for 隐忍 in English?
# Where is the best place to sell raw gold?
#
# What is a good word for 隐忍 in English?
# Where is the best place to sell raw gold?
# ['隐', '忍'] []
#
#
#
# How do you pronounce Sḵwx̱wú7mesh?
# How do you pronounce "Quora"?
#
# How do you pronounce Sḵwx̱wú7mesh?
# How do you pronounce "Quora"?
# ['ḵ', '̱', 'ú'] []
# How do I translate '竟然' to English?
# How do I translate '才' to English?
#
# How do I translate '竟然' to English?
# How do I translate '才' to English?
# ['竟', '然'] ['才']
#
#
#
# Can I install an Android app on an unsupported device?
# زب app: Can I install a Nomao naked camera for an Android?
#
# Can I install an Android app on an unsupported device?
# زب app: Can I install a Nomao naked camera for an Android?
# [] ['ز', 'ب']
#
#
#
# What is the viscosity of air at 20°c?
# What is the viscosity of water?
#
# What is the viscosity of air at 20°c?
# What is the viscosity of water?
# ['°'] []
#
#
#
# What is the meaning of Hindi word 'Parayi'?
# What is the meaning of the Hindi word "बेहराल"?
#
# What is the meaning of Hindi word 'Parayi'?
# What is the meaning of the Hindi word "बेहराल"?
# [] ['ब', 'े', 'ह', 'र', 'ा', 'ल']
#
#
#
# If x∝y/z^2, y∝ab^2 and z∝b/a then what is the relation between x, a and b? The answer has been given as b^4/a^3. Is that correct?
# Which are the best book for preparation of UES (UNIVERSITY ENTRY SCHEME).?
#
# If x∝y/z^2, y∝ab^2 and z∝b/a then what is the relation between x, a and b? The answer has been given as b^4/a^3. Is that correct?
# Which are the best book for preparation of UES (UNIVERSITY ENTRY SCHEME).?
# ['∝', '∝', '∝'] []
#
#
#
# What does GMOとくとくポイント mean?
# What does εἶμεν mean?
#
# What does GMOとくとくポイント mean?
# What does εἶμεν mean?
# ['と', 'く', 'と', 'く', 'ポ', 'イ', 'ン', 'ト'] ['ε', 'ἶ', 'μ', 'ε', 'ν']
#
#
#
# If I want to ask my young child “What is this in Chinese” in Mandarin, could I say “用中文的話, 這是什麽?” What would be a better way to say this?
# How do you say 'child abuse' in Mandarin?
#
# If I want to ask my young child 'What is this in Chinese' in Mandarin, could I say '用中文的話, 這是什麽?' What would be a better way to say this?
# How do you say 'child abuse' in Mandarin?
# ['用', '中', '文', '的', '話', '這', '是', '什', '麽'] []
#
#
#
# What is the meaning of "beagleize it"?
# What it is the meaning of "開了"?
#
# What is the meaning of "beagleize it"?
# What it is the meaning of "開了"?
# [] ['開', '了']
#
#
#
# What is the word which is a name of a sweet, movie, medicine, car, place, girl, doggy, and city?
# इसका जवाब दो तो मानेंगे ::    1) एक sweet का नाम ?  2) एक medecine का नाम ?  3) एक film का नाम ?  4) एक लड़की का नाम.?  5) एक city का नाम ?  6) एक  car का नाम ?  7) एक जगह का नाम ?  8) एक  doggy का नाम ?   कोई ऐसा जवाब दो जो इन  8 का 1 ही नाम हो ?       Its a Challenge......
#
# What is the word which is a name of a sweet, movie, medicine, car, place, girl, doggy, and city?
# इसका जवाब दो तो मानेंगे ::    1) एक sweet का नाम ?  2) एक medecine का नाम ?  3) एक film का नाम ?  4) एक लड़की का नाम.?  5) एक city का नाम ?  6) एक  car का नाम ?  7) एक जगह का नाम ?  8) एक  doggy का नाम ?   कोई ऐसा जवाब दो जो इन  8 का 1 ही नाम हो ?       Its a Challenge......
# [] ['इ', 'स', 'क', 'ा', 'ज', 'व', 'ा', 'ब', 'द', 'ो', 'त', 'ो', 'म', 'ा', 'न', 'े', 'ं', 'ग', 'े', 'ए', 'क', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'ल', 'ड़', 'क', 'ी', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'ज', 'ग', 'ह', 'क', 'ा', 'न', 'ा', 'म', 'ए', 'क', 'क', 'ा', 'न', 'ा', 'म', 'क', 'ो', 'ई', 'ऐ', 'स', 'ा', 'ज', 'व', 'ा', 'ब', 'द', 'ो', 'ज', 'ो', 'इ', 'न', 'क', 'ा', 'ह', 'ी', 'न', 'ा', 'म', 'ह', 'ो']
#
#
#
# What do '...!' and '...?' mean?
# What does 爱不释手 mean?
#
# What do '...!' and '...?' mean?
# What does 爱不释手 mean?
# [] ['爱', '不', '释', '手']
#
#
#
# I have a Videocon Integra 32″ LCD Tv. So is it possible to install HDMI ports on the Tv and also what could be the approximate cost?
# What is a reasonable price tag for a new Air Force One?
#
# I have a Videocon Integra 32″ LCD Tv. So is it possible to install HDMI ports on the Tv and also what could be the approximate cost?
# What is a reasonable price tag for a new Air Force One?
# ['″'] []
#
#
#
# What is the etymology of 阿?
# The etymology of 阿?
#
# What is the etymology of 阿?
# The etymology of 阿?
# ['阿'] ['阿']
#
#
#
# What is a good way to say 横向卷轴rpg游戏 in English?
# How do you say 粘人 in English?
#
# What is a good way to say 横向卷轴rpg游戏 in English?
# How do you say 粘人 in English?
# ['横', '向', '卷', '轴', '游', '戏'] ['粘', '人']
#
#
#
# What is Jake Williams' opinion on Twenty one pilots and meaning of their songs?
# What is your review of Twenty Øne Piløts?
#
# What is Jake Williams' opinion on Twenty one pilots and meaning of their songs?
# What is your review of Twenty Øne Pilots?
# [] ['Ø']
#
#
#
# How do I translate "骂人" into English?
# How do I translate "长夜难明赤县天，百年魔怪舞翩跹" into English?
#
# How do I translate "骂人" into English?
# How do I translate "长夜难明赤县天，百年魔怪舞翩跹" into English?
# ['骂', '人'] ['长', '夜', '难', '明', '赤', '县', '天', '，', '百', '年', '魔', '怪', '舞', '翩', '跹']
#
#
#
# What's the difference between a weeaboo, Japanophile, and Japanologist?
# What's the difference between づ and ずin Japanese?
#
# What's the difference between a weeaboo, Japanophile, and Japanologist?
# What's the difference between づ and ずin Japanese?
# [] ['づ', 'ず']
#
#
#
# What's the difference between 打关系 and 走关系？
# What is the difference between ";" and ","?
#
# What's the difference between 打关系 and 走关系？
# What is the difference between ";" and ","?
# ['打', '关', '系', '走', '关', '系', '？'] []
#
#
#
# What is the difference between "又一" (yòu yī) and "另一" (lìng yī)?
# What is the difference between "又一" (yòu yī) and "其他" (qítā)?
#
# What is the difference between "又一" (yòu yī) and "另一" (lìng yī)?
# What is the difference between "又一" (yòu yī) and "其他" (qítā)?
# ['又', '一', 'ò', 'ī', '另', '一', 'ì', 'ī'] ['又', '一', 'ò', 'ī', '其', '他', 'í', 'ā']
#
#
#
# What is the value of 1÷0?
# Is 1/0 infinity?
#
# What is the value of 1÷0?
# Is 1/0 infinity?
# ['÷'] []
#
#
#
# How does one prove that A intersecting B = A, iff A is a subset of B?
# Suppose A and B are subsets of U. How do you show that below, if any one of the relations stated holds, then each of the others holds: A ⊆ B, U ∖ A ⊇ U ∖ B, A ∪ B = B, A ∩ B = A?
#
# How does one prove that A intersecting B = A, iff A is a subset of B?
# Suppose A and B are subsets of U. How do you show that below, if any one of the relations stated holds, then each of the others holds: A ⊆ B, U ∖ A ⊇ U ∖ B, A ∪ B = B, A ∩ B = A?
# [] ['⊆', '∖', '⊇', '∖', '∪', '∩']
#
#
#
# What is the difference between “杂” (zá) and ”内脏" (nèizàng)?
# What is the difference between ":=" and "::=" ?
#
# What is the difference between '杂' (zá) and '内脏" (nèizàng)?
# What is the difference between ":=" and "::=" ?
# ['杂', 'á', '内', '脏', 'è', 'à'] []
#
#
#
# How can I say 失皮 in English?
# How do I say “±” in English?
#
# How can I say 失皮 in English?
# How do I say '±' in English?
# ['失', '皮'] ['±']
#
#
#
# What is meaning of makbuja?
# What is meaning of ไฟสิ้นเชื้อ?
#
# What is meaning of makbuja?
# What is meaning of ไฟสิ้นเชื้อ?
# [] ['ไ', 'ฟ', 'ส', 'ิ', '้', 'น', 'เ', 'ช', 'ื', '้', 'อ']
#
#
#
# How do I estimate the fractional change in the volume of Earths oceans due to an average temperature change of 1°C?
# Does gravity affect the speed of light?
#
# How do I estimate the fractional change in the volume of Earths oceans due to an average temperature change of 1°C?
# Does gravity affect the speed of light?
# ['°'] []
#
#
#
# Why is 0/1 equal to zero?
# Is 1÷inf. equal to 0?
#
# Why is 0/1 equal to zero?
# Is 1÷inf. equal to 0?
# [] ['÷']
#
#
#
# What's the difference between ™, ® and ©?
# What's the difference between "did" and "have done"?
#
# What's the difference between ™, ® and ©?
# What's the difference between "did" and "have done"?
# ['™', '®', '©'] []
#
#
#
# Oh, I was was English Lit. major at NU…I am still registered but I have been super goofing off and skipping school again?
# What is the value of (2) ^86÷ 7?
#
# Oh, I was was English Lit. major at NU ... I am still registered but I have been super goofing off and skipping school again?
# What is the value of (2) ^86÷ 7?
# [] ['÷']
#
#
#
# What do the symbols mean?
# What do the symbols like these.. ￦¥§¤㊙㊗ ..mean on my keyboard?
#
# What do the symbols mean?
# What do the symbols like these.. ￦$§¤㊙㊗ ..mean on my keyboard?
# [] ['￦', '§', '¤', '㊙', '㊗']
#
#
#
# What does "mutual followers" mean on ResearchGate?
# What does 不好意思 mean?
#
# What does "mutual followers" mean on ResearchGate?
# What does 不好意思 mean?
# [] ['不', '好', '意', '思']
#
#
#
# What does 抜け感 mean?
# What does ' [*]' mean?
#
# What does 抜け感 mean?
# What does ' [*]' mean?
# ['抜', 'け', '感'] []
#
#
#
# How do I say "形から入る" in English?
# How could we say "也是醉了" in English?
#
# How do I say "形から入る" in English?
# How could we say "也是醉了" in English?
# ['形', 'か', 'ら', '入', 'る'] ['也', '是', '醉', '了']
#
#
#
# How do I translate "骂人" into English?
# How do you translate "学校の運動会" into English?
#
# How do I translate "骂人" into English?
# How do you translate "学校の運動会" into English?
# ['骂', '人'] ['学', '校', 'の', '運', '動', '会']
#
#
#
# At what distance from earth's surface does ɡ0 (standard gravity) end and zero gravity or weightlessness starts?
# How does fire burn in zero gravity?
#
# At what distance from earth's surface does ɡ0 (standard gravity) end and zero gravity or weightlessness starts?
# How does fire burn in zero gravity?
# ['ɡ'] []
#
#
#
# What is the meaning of 'Rishul'?
# What does 심하잖아 mean?
#
# What is the meaning of 'Rishul'?
# What does 심하잖아 mean?
# [] ['심', '하', '잖', '아']
#
#
#
# Did the Japanese authorities ever create or release a list of suspects in the Setagaya Family Murders Case?
# How do I solve thIs? A ball kIcked to a goal at 45° wrt ground just clears the top bar of goal 3m hIgh. How do I calculate velocity of projection?
#
# Did the Japanese authorities ever create or release a list of suspects in the Setagaya Family Murders Case?
# How do I solve thIs? A ball kIcked to a goal at 45° wrt ground just clears the top bar of goal 3m hIgh. How do I calculate velocity of projection?
# [] ['°']
#
#
#
# What does the Chinese word "女漢子" mean?
# What does the Chinese word 心中 mean?
#
# What does the Chinese word "女漢子" mean?
# What does the Chinese word 心中 mean?
# ['女', '漢', '子'] ['心', '中']
#
#
#
# What happens when a 30 M☉ star comes close to a 3 M☉ black hole?
# ...
#
#
#
# How would you translate "一百回"?
# What is the best way to translate Wordpress?
#
# How would you translate "一百回"?
# What is the best way to translate Wordpress?
# ['一', '百', '回'] []
#
#
#
# How do I write om in hindi (ॐ) by typing on an Android keyboard for mobile?
# How can I write faster in Hindi?
#
# How do I write om in hindi (ॐ) by typing on an Android keyboard for mobile?
# How can I write faster in Hindi?
# ['ॐ'] []
#
#
#
# How do you say 'cosquillas' in English?
# How do I say "有规律可循" in English?
#
# How do you say 'cosquillas' in English?
# How do I say "有规律可循" in English?
# [] ['有', '规', '律', '可', '循']
#
#
#
# Why is 1/0=∞?
# Why does zero factorial (0!) equal one (1)?
#
# Why is 1/0=∞?
# Why does zero factorial (0!) equal one (1)?
# ['∞'] []
#
#
#
# How can you value ideas?
# How do I find the value of sin81°?
#
# How can you value ideas?
# How do I find the value of sin81°?
# [] ['°']
#
#
#
# Why does Sino- mean Chinese?
# What does the Chinese word 傻逼 mean in English?
#
# Why does Sino- mean Chinese?
# What does the Chinese word 傻逼 mean in English?
# [] ['傻', '逼']
#
#
#
# What does £ mean?
# What's the meaning of"有意栽花花不成无心插柳柳成荫"?
#
# What does $ mean?
# What's the meaning of"有意栽花花不成无心插柳柳成荫"?
# [] ['有', '意', '栽', '花', '花', '不', '成', '无', '心', '插', '柳', '柳', '成', '荫']
#
#
#
# What is the meaning of this sentence "சார்ந்தோர் அனைவருக்கும் ஆழ்ந்த அனுதாபங்கள்."?
# What is the meaning of "well" in this sentence?
#
# What is the meaning of this sentence "சார்ந்தோர் அனைவருக்கும் ஆழ்ந்த அனுதாபங்கள்."?
# What is the meaning of "well" in this sentence?
# ['ச', 'ா', 'ர', '்', 'ந', '்', 'த', 'ோ', 'ர', '்', 'அ', 'ன', 'ை', 'வ', 'ர', 'ு', 'க', '்', 'க', 'ு', 'ம', '்', 'ஆ', 'ழ', '்', 'ந', '்', 'த', 'அ', 'ன', 'ு', 'த', 'ா', 'ப', 'ங', '்', 'க', 'ள', '்'] []
#
#
#
# What does 鹵水 mean in Chinese?
# What does “Shifu” mean in Chinese?
#
# What does 鹵水 mean in Chinese?
# What does 'Shifu' mean in Chinese?
# ['鹵', '水'] []
#
#
#
# What is quoro?
# What is "☐"?
#
# What is quoro?
# What is "☐"?
# [] ['☐']
#
#
#
# Which is the best automatic washing machine?
# What's this mean نام ايع و أبهى لسينيغاثقادواظا نمت العصر?
#
# Which is the best automatic washing machine?
# What's this mean نام ايع و أبهى لسينيغاثقادواظا نمت العصر?
# [] ['ن', 'ا', 'م', 'ا', 'ي', 'ع', 'و', 'أ', 'ب', 'ه', 'ى', 'ل', 'س', 'ي', 'ن', 'ي', 'غ', 'ا', 'ث', 'ق', 'ا', 'د', 'و', 'ا', 'ظ', 'ا', 'ن', 'م', 'ت', 'ا', 'ل', 'ع', 'ص', 'ر']
#
#
#
# What's the meaning of "一不做二不休"?
# What is the meaning of "दुष्प्राप्य"?
#
# What's the meaning of "一不做二不休"?
# What is the meaning of "दुष्प्राप्य"?
# ['一', '不', '做', '二', '不', '休'] ['द', 'ु', 'ष', '्', 'प', '्', 'र', 'ा', 'प', '्', 'य']
#
#
#
# What is meaning?
# What's the meaning of "旮沓"?
#
# What is meaning?
# What's the meaning of "旮沓"?
# [] ['旮', '沓']
#
#
#
# Who is the founder of OSBN®?
# Who is the founder of T1Payments?
#
# Who is the founder of OSBN®?
# Who is the founder of T1Payments?
# ['®'] []
#
#
#
# What does the Greek word παράκλητος (paráklitos) mean? What was the original Aramaic/Hebrew word?
# Which TV should I buy 24 inch or 32 inch for bedroom?
#
# What does the Greek word piαράκλητος (paráklitos) mean? What was the original Aramaic/Hebrew word?
# Which TV should I buy 24 inch or 32 inch for bedroom?
# ['α', 'ρ', 'ά', 'κ', 'λ', 'η', 'τ', 'ο', 'ς', 'á'] []
#
#
#
# What is the difference between 画 and 画画 in Mandarin Chinese?
# What is the difference between 不太好 and 太不好 in Mandarin Chinese?
#
# What is the difference between 画 and 画画 in Mandarin Chinese?
# What is the difference between 不太好 and 太不好 in Mandarin Chinese?
# ['画', '画', '画'] ['不', '太', '好', '太', '不', '好']
#
#
#
# How can I design a 145㎡ loft for business?
# How do I design a loft?
#
# How can I design a 145㎡ loft for business?
# How do I design a loft?
# ['㎡'] []
#
#
#
# I am 16 years old girl. I want to increase atleast 3 inches height. Is it possible? If yes,how?
# I am 15 years old, and my height is 5′9″. I want to become 6′0″. Is that possible? If yes, then how?
#
# I am 16 years old girl. I want to increase atleast 3 inches height. Is it possible? If yes,how?
# I am 15 years old, and my height is 5′9″. I want to become 6′0″. Is that possible? If yes, then how?
# [] ['′', '″', '′', '″']
# Player A has n+1 coins, while B has n coins. Both players throw all of their coins simultaneously and observe the no. of heads. If all coins are fair, then what is the probability that A obtains more heads than B?
# A fair coin is independently flipped n times, k times by A and n − k times by B. Show that the probability that A and B flip the same number of heads is equal to the probability that there are a total of k heads?
#
# Player A has n+1 coins, while B has n coins. Both players throw all of their coins simultaneously and observe the no. of heads. If all coins are fair, then what is the probability that A obtains more heads than B?
# A fair coin is independently flipped n times, k times by A and n − k times by B. Show that the probability that A and B flip the same number of heads is equal to the probability that there are a total of k heads?
# [] ['−']
#
#
#
# What are the best slogans based on the theme "United India" or "राष्ट्रीय एकता"?
# What are some of the best slogans written on trucks in India?
#
# What are the best slogans based on the theme "United India" or "राष्ट्रीय एकता"?
# What are some of the best slogans written on trucks in India?
# ['र', 'ा', 'ष', '्', 'ट', '्', 'र', 'ी', 'य', 'ए', 'क', 'त', 'ा'] []
#
#
#
# If the Sun disappeared, would the Earth continue in its orbit for 8½ minutes?
# How long would the Earth follow its orbit around the Sun if the Sun were to disappear?
#
# If the Sun disappeared, would the Earth continue in its orbit for 8½ minutes?
# How long would the Earth follow its orbit around the Sun if the Sun were to disappear?
# ['½'] []
#
#
#
# How does this translate into English?
# How do I translate '竟然' to English?
#
# How does this translate into English?
# How do I translate '竟然' to English?
# [] ['竟', '然']
#
#
#
# What is the etymology of 阿?
# What is the etymology of entrée?
#
# What is the etymology of 阿?
# What is the etymology of entree?
# ['阿'] []
#
#
#
# How do I wish someone on his/her birthday in Arabic?
# I found there are different phrases to wish someone birthday in Arabic. What is the difference between عيد مولد سعيد and سنة خلوة?
#
# How do I wish someone on his/her birthday in Arabic?
# I found there are different phrases to wish someone birthday in Arabic. What is the difference between عيد مولد سعيد and سنة خلوة?
# [] ['ع', 'ي', 'د', 'م', 'و', 'ل', 'د', 'س', 'ع', 'ي', 'د', 'س', 'ن', 'ة', 'خ', 'ل', 'و', 'ة']
#
#
#
# Why do the Chinese call the United States 'beautiful country' (美国) given that the Chinese name does not sound like the English equivalent?
# How do Chinese names work?
#
# Why do the Chinese call the United States 'beautiful country' (美国) given that the Chinese name does not sound like the English equivalent?
# How do Chinese names work?
# ['美', '国'] []
#
#
#
# How do I translate '才' to English?
# How do I translate 笑点 to English?
#
# How do I translate '才' to English?
# How do I translate 笑点 to English?
# ['才'] ['笑', '点']
#
#
#
# What does the Chinese word 心中 mean?
# What does this Chinese word mean on the picture?
#
# What does the Chinese word 心中 mean?
# What does this Chinese word mean on the picture?
# ['心', '中'] []
#
#
#
# How could we say "也是醉了" in English?
# How do you say 粘人 in English?
#
# How could we say "也是醉了" in English?
# How do you say 粘人 in English?
# ['也', '是', '醉', '了'] ['粘', '人']
#
#
#
# On which factors does the capacitance of a capacitor depends?
# A 2H inductor is in series with a 11μF capacitor and a 390Ω resistor, at what freq will the circuit resonate? Also what is the Q factor & bandwidth?
#
# On which factors does the capacitance of a capacitor depends?
# A 2H inductor is in series with a 11μF capacitor and a 390Ω resistor, at what freq will the circuit resonate? Also what is the Q factor & bandwidth?
# [] ['μ', 'Ω']
#
#
#
# Why is included angle in V belt taken 30°- 40°?
# Why did Robin of Locksley take Sebald to his home?
#
# Why is included angle in V belt taken 30°- 40°?
# Why did Robin of Locksley take Sebald to his home?
# ['°', '°'] []
#
#
#
# What does 'wuhuakeshuo' mean in Chinese?
# What does 鹵水 mean in Chinese?
#
# What does 'wuhuakeshuo' mean in Chinese?
# What does 鹵水 mean in Chinese?
# [] ['鹵', '水']
#
#
#
# Trademarks: What's the difference between ®, ©, and ™?
# What is the difference between a copyright and a trademark?
#
# Trademarks: What's the difference between ®, ©, and ™?
# What is the difference between a copyright and a trademark?
# ['®', '©', '™'] []
#
#
#
# What is the difference between "消失了在我们身边" and "从我们身边消失了"?
# What is the difference between ";" and ","?
#
# What is the difference between "消失了在我们身边" and "从我们身边消失了"?
# What is the difference between ";" and ","?
# ['消', '失', '了', '在', '我', '们', '身', '边', '从', '我', '们', '身', '边', '消', '失', '了'] []
#
#
#
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證), can you enter Mainland China without it?
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證) can you work and study in Mainland China?
#
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證), can you enter Mainland China without it?
# If you are a Chinese citizen of the HKSAR and hold a valid Mainland China home return permit (港澳居民來往內地通行證) can you work and study in Mainland China?
# ['港', '澳', '居', '民', '來', '往', '內', '地', '通', '行', '證'] ['港', '澳', '居', '民', '來', '往', '內', '地', '通', '行', '證']
#
#
#
# What is the integral of tanx-tan³x?
# What is the integration of ((cos²x) ÷ (1+tanx))?
#
# What is the integral of tanx-tan3x?
# What is the integration of ((cos²x) ÷ (1+tanx))?
# [] ['²', '÷']
#
#
#
# What do the symbols mean?
# What does this '≜' symbol mean?
#
# What do the symbols mean?
# What does this '≜' symbol mean?
# [] ['≜']
#
#
#
# What are bases in mathematics?
# What does 6÷2(1+2) equal?
#
# What are bases in mathematics?
# What does 6÷2(1+2) equal?
# [] ['÷']
#
#
#
# When the hydronium-ion concentration of a solution is 1×10−12 M , what is the pH of the solution?
# When the hydronium-ion concentration of a solution is 1×10^−12 M , what is the pH of the solution?
#
# When the hydronium-ion concentration of a solution is 1x10−12 M , what is the pH of the solution?
# When the hydronium-ion concentration of a solution is 1x10^−12 M , what is the pH of the solution?
# ['−'] ['−']
#
#
#
# Is 恬莉 a good Chinese name?
# Is 杨雅静 a good Chinese name?
#
# Is 恬莉 a good Chinese name?
# Is 杨雅静 a good Chinese name?
# ['恬', '莉'] ['杨', '雅', '静']
#
#
#
# What's English?
# What is 睨んでるin english?
#
# What's English?
# What is 睨んでるin english?
# [] ['睨', 'ん', 'で', 'る']
#
#
#
# What is a good way to say 寒冷的西伯利亚 in English?
# How can we say 鸡精 in English?
#
# What is a good way to say 寒冷的西伯利亚 in English?
# How can we say 鸡精 in English?
# ['寒', '冷', '的', '西', '伯', '利', '亚'] ['鸡', '精']
#
#
#
# What is the answer of 1/0?
# What is the answer for 0÷0×0?
#
# What is the answer of 1/0?
# What is the answer for 0÷0x0?
# [] ['÷']
#
#
#
# How can we translate “膜” into English?
# How would you translate 猫腻 into English?
#
# How can we translate '膜' into English?
# How would you translate 猫腻 into English?
# ['膜'] ['猫', '腻']
#
#
#
# What is the meaning of the Sanskrit word सहजं?
# What is the meaning of Sanskrit word 'sadhu'?
#
# What is the meaning of the Sanskrit word सहजं?
# What is the meaning of Sanskrit word 'sadhu'?
# ['स', 'ह', 'ज', 'ं'] []
#
#
#
# Did you ever think you have nothing to contribute to life?
# Riot points free generator ¿OMG?
#
# Did you ever think you have nothing to contribute to life?
# Riot points free generator ¿OMG?
# [] ['¿']
#
#
#
# Is Ω < 1 = The shape of the Universe?
# Is there any shape the universe couldn't be?
#
# Is Ω < 1 = The shape of the Universe?
# Is there any shape the universe couldn't be?
# ['Ω'] []
#
#
#
# How do I translate '才' to English?
# How should I translate 放心 to English?
#
# How do I translate '才' to English?
# How should I translate 放心 to English?
# ['才'] ['放', '心']
#
#
#
# What does the ¿ symbol mean?
# What does this symbol mean?
#
# What does the ¿ symbol mean?
# What does this symbol mean?
# ['¿'] []
#
#
#
# What does "<3" mean?
# What's the meaning of "精神赵家人"?
#
# What does "<3" mean?
# What's the meaning of "精神赵家人"?
# [] ['精', '神', '赵', '家', '人']
#
#
#
# How do I prove that 10÷2=2?
# How do I prove (a+b) ^2 ≠ a^2+b^2?
#
# How do I prove that 10÷2=2?
# How do I prove (a+b) ^2 = a^2+b^2?
# ['÷'] []
#
#
#
# What does “天人” mean in English?
# What does ''badam'' mean in English?
#
# What does '天人' mean in English?
# What does ''badam'' mean in English?
# ['天', '人'] []
#
#
#
# What's the English word of 霍比特人?
# What's the english word for 'jhak'?
#
# What's the English word of 霍比特人?
# What's the english word for 'jhak'?
# ['霍', '比', '特', '人'] []
#
#
#
# What is the meaning of "I'd" in English? Is it "I had", "I did", "I would" or "I could"?
# What does 胖口 mean in English?
#
# What is the meaning of "I'd" in English? Is it "I had", "I did", "I would" or "I could"?
# What does 胖口 mean in English?
# [] ['胖', '口']
#
#
#
# What does the Chinese phrase "不了了之" mean?
# What is the meaning of the Chinese phrase "打招呼"?
#
# What does the Chinese phrase "不了了之" mean?
# What is the meaning of the Chinese phrase "打招呼"?
# ['不', '了', '了', '之'] ['打', '招', '呼']
#
#
#
# What is the meaning of the Sanskrit word सहजं?
# What is the meaning of the sanskrit word straina?
#
# What is the meaning of the Sanskrit word सहजं?
# What is the meaning of the sanskrit word straina?
# ['स', 'ह', 'ज', 'ं'] []
#
#
#
# Debotosh da, how to make notes from The Hindu?
# Chord AB of circle x^2+y^2=100 passes through (7,1) &subtends an angle of 60°at circumference of circle.If m1&m2 r two such chords find m1m2?
#
# Debotosh da, how to make notes from The Hindu?
# Chord AB of circle x^2+y^2=100 passes through (7,1) &subtends an angle of 60°at circumference of circle.If m1&m2 r two such chords find m1m2?
# [] ['°']
#
#
#
# What are best govt jobs with no transfer policy¿?
# Which bank is offering the cheapest POS machine in Kolkata?
#
# What are best govt jobs with no transfer policy¿?
# Which bank is offering the cheapest POS machine in Kolkata?
# ['¿'] []
#
#
#
# Solve this for all masterminds !!              ⚡I'am an 6 letter word      ⚡First 4 is me ⚡2 and 6 are same letters ⚡1,2,6  means look  ⚡4,6,2 means type of payment        Who am l? Hints:- youngster's  favourite....  Ans?
# Solve this for all masterkminds!!              ⚡I'am an 6 letter word      ⚡First 4 is me ⚡2 and 6 are same letters ⚡1,2,6  means look  ⚡4,6,2 means type of payment Who am l? Hints:- youngster's  favourite?
#
# Solve this for all masterminds !!              ⚡I'am an 6 letter word      ⚡First 4 is me ⚡2 and 6 are same letters ⚡1,2,6  means look  ⚡4,6,2 means type of payment        Who am l? Hints:- youngster's  favourite....  Ans?
# Solve this for all masterkminds!!              ⚡I'am an 6 letter word      ⚡First 4 is me ⚡2 and 6 are same letters ⚡1,2,6  means look  ⚡4,6,2 means type of payment Who am l? Hints:- youngster's  favourite?
# ['⚡', '⚡', '⚡', '⚡', '⚡'] ['⚡', '⚡', '⚡', '⚡', '⚡']
#
#
#
# If the Sun disappeared, would the Earth continue in its orbit for 8½ minutes?
# Will earth continue to revolve around sun for 8 minutes if the sun happens to disappear suddenly?
#
# If the Sun disappeared, would the Earth continue in its orbit for 8½ minutes?
# Will earth continue to revolve around sun for 8 minutes if the sun happens to disappear suddenly?
# ['½'] []
#
#
#
# Bionic-turtle or Prepsmarter? Which one is better for FRM preparation? I am totally confused 
# Can someone with no finance background prepare for FRM level 1 in 2 months?
#
# Bionic-turtle or Prepsmarter? Which one is better for FRM preparation? I am totally confused 
# Can someone with no finance background prepare for FRM level 1 in 2 months?
# ['\uf04c'] []
#
#
#
# What does 骚客 mean in English?
# What does 'Sapna' mean in English?
#
# What does 骚客 mean in English?
# What does 'Sapna' mean in English?
# ['骚', '客'] []
#
#
#
# What does the Chinese word "女漢子" mean?
# What does the Chinese word 隔壁老王 mean?
#
# What does the Chinese word "女漢子" mean?
# What does the Chinese word 隔壁老王 mean?
# ['女', '漢', '子'] ['隔', '壁', '老', '王']
#
#
#
# What does “天人” mean in English?
# What does ''bientot'' mean in English?
#
# What does '天人' mean in English?
# What does ''bientot'' mean in English?
# ['天', '人'] []
#
#
#
# 8742 non ascii questions at train_set

# %% [markdown]
# ## tokenization

# %%
pairs_to_replace_in_plain_math = [('[@math]', ''), ('[#math]', ''), ('{', ''), ('}', ''), 
                                  ('left', ''), ('right', ''), ('displaystyle', ''), ('ln', 'log'), 
                                  ('mathrm', ''), ('frac', ''), ('lfloor', ''), ('rfloor', ''),
                                  ('_', ''), ('\\', ''), ('&', ''), (' ', '')]

def plain_math_replace(matchobj):
    start, end = matchobj.span()
    matching_string = matchobj.string[start:end]
    matching_string = replace_characters_in_string(matching_string, characters_pairs=pairs_to_replace_in_plain_math)
    return matching_string

plain_math_regex = r'\[@math\]((?!\[@math\]|\[#math\]).)*\[#math\]'

def clean_text_from_latex(text):
    clean_text = re.sub(plain_math_regex, plain_math_replace, text)
    return clean_text

# %%
def number_with_comma_replace(matchobj):
    start, end = matchobj.span()
    matching_string = matchobj.string[start:end]
    matching_string = matching_string.replace(',', '')
    return matching_string

number_with_comma_replace_regex = r'[0-9]+,[0-9]+'

def number_with_comma_regex_replace(number):
    number = re.sub(number_with_comma_replace_regex, number_with_comma_replace, number)
    return number

# %%
def number_replace(matchobj):
    start, end = matchobj.span()
    matching_string = matchobj.string[start:end]
    matching_string = matching_string.rstrip('+-')
    matching_string = matching_string.replace('k', '000')
    return matching_string

number_regex = r'((?:^|\s)(\+?\-?[0-9]+)(k?)(\+?\-?)(?!\S))'

def number_regex_replace(number):
    number = re.sub(number_regex, number_replace, number)
    return number

# %%
def clean_text(text):
    text = text.lower()
    text = unicode_normalization(text)
    text = number_with_comma_regex_replace(text)
    text = remove_extra_spaces(text)
    
    return text

# %%
substrings_to_replace = [('"', "'"), ('(', ' '), (')', ' '), (':', ' '), (';', ' ')]

substrings_to_replace += [("what's", "what is"), ("who's","who is"), ("where's","where is"),
                          ("when's","when is"), ("how's","how is"), ("it's","it is"),
                          ("he's","he is"), ("she's","she is"), ("that's","that is"),
                          ("there's","there is"), ("'s", " "), ("'ve", " have "),
                          ("can't", "cannot "), ("n't", " not "), ("i'm", "i am "),
                          ("'re", " are "), ("'d", " would "), ("'ll", " will ")]

substrings_to_replace += [("'", ''), ('&', ' and '), ('~', ''), ('^', ''), ('*', '')]

tokens_characters = [(',', ' '), ('.', '  '), ('!', ' ! '), ('?', ' '), ('\\', ' '), ('/', ' '), ('-', ' ')]

def text_tokenization(text):
    text = replace_characters_in_string(text, characters_pairs=[('[math]', '[@math]'), ('[/math]', '[#math]')])
    text = clean_text(text)
    text = replace_characters_in_string(text, characters_pairs=substrings_to_replace)
    text = replace_characters_in_string(text, characters_pairs=tokens_characters)
    text = clean_text_from_latex(text)
    text = replace_characters_in_string(text, characters_pairs=[('[', ''), (']', ''), 
                                                                ('{', ''), ('}', ''), 
                                                                ('$', ' $ '),
                                                                ('@math', ' @math '), ('#math', ' #math ')])
    text = number_regex_replace(text)
    text = remove_extra_spaces(text)
    tokens = text.split()
    return tokens

# %%
for q1, q2, is_duplicate in train_set[['question1', 'question2', 'is_duplicate']].values:
    if is_duplicate:
        tokens_q1 = text_tokenization(q1)
        tokens_q2 = text_tokenization(q2)
        if ('[math]' in q1 or '[math]' in q2):
            print(q1)
            print(q2)
            print(tokens_q1)
            print(tokens_q2)
            print('\n\n\n')
# Out:
# How do I learn [math]\LaTeX[/math]?
# How can I learn latex in the easiest way?
# ['how', 'do', 'i', 'learn', 'latex']
# ['how', 'can', 'i', 'learn', 'latex', 'in', 'the', 'easiest', 'way']
#
#
#
#
# Let [math]S_{n} = n^{2} + 20n + 12[/math], where [math]n[/math] is a positive integer. What is the sum of all possible values of n for which [math]S_{n}[/math] is a perfect square?
# Given [math]S_n = n^2 +20n + 12[/math]. What will be the sum of positive integers such that [math]S_n[/math] will be a perfect square?
# ['let', 'sn=n2+20n+12', 'where', 'n', 'is', 'a', 'positive', 'integer', 'what', 'is', 'the', 'sum', 'of', 'all', 'possible', 'values', 'of', 'n', 'for', 'which', 'sn', 'is', 'a', 'perfect', 'square']
# ['given', 'sn=n2+20n+12', 'what', 'will', 'be', 'the', 'sum', 'of', 'positive', 'integers', 'such', 'that', 'sn', 'will', 'be', 'a', 'perfect', 'square']
#
#
#
#
# If real numbers are in [math]x[/math]-axis and complex numbers in [math]y[/math]-axis, what is in the [math]z[/math]-axis?
# If the real numbers are usually placed on the [math]x[/math]-axis and imaginary numbers placed on the [math]y[/math]-axis, what would be placed on the [math]z[/math]-axis?
# ['if', 'real', 'numbers', 'are', 'in', 'x', 'axis', 'and', 'complex', 'numbers', 'in', 'y', 'axis', 'what', 'is', 'in', 'the', 'z', 'axis']
# ['if', 'the', 'real', 'numbers', 'are', 'usually', 'placed', 'on', 'the', 'x', 'axis', 'and', 'imaginary', 'numbers', 'placed', 'on', 'the', 'y', 'axis', 'what', 'would', 'be', 'placed', 'on', 'the', 'z', 'axis']
#
#
#
#
# What is value of I^i?
# What is the value of [math]i^i [/math]where [math]i=\sqrt{-1}[/math]?
# ['what', 'is', 'value', 'of', 'ii']
# ['what', 'is', 'the', 'value', 'of', 'iiwhere', 'i=sqrt1']
#
#
#
#
# How do I solve the problem: [math] A=\begin{pmatrix} -2 &4 \\   -5& 7 \end{pmatrix}, A^{n}=? [/math]?
# Given [math]A[/math], What is the general formula of [math]A^n[/math]? If [math]A=\begin{pmatrix} -2 &4 \\ -5& 7 \end{pmatrix}[/math], what is the [math]A^n[/math]?
# ['how', 'do', 'i', 'solve', 'the', 'problem', 'a=beginpmatrix2and45and7endpmatrixan=']
# ['given', 'a', 'what', 'is', 'the', 'general', 'formula', 'of', 'an', 'if', 'a=beginpmatrix2and45and7endpmatrix', 'what', 'is', 'the', 'an']
#
#
#
#
# How can you determine the derivative of [math]\sin x^2[/math]?
# What is the derivative of [math]\sin \left(x^2\right)[/math]?
# ['how', 'can', 'you', 'determine', 'the', 'derivative', 'of', 'sinx2']
# ['what', 'is', 'the', 'derivative', 'of', 'sinx2']
#
#
#
#
# Which primitive could be proper for A^3 = B^3 + C^3?
# Where is the unknown in the Fermat's equation [math]A^3 = B^3 + C^3[/math]?
# ['which', 'primitive', 'could', 'be', 'proper', 'for', 'a3', '=', 'b3', '+', 'c3']
# ['where', 'is', 'the', 'unknown', 'in', 'the', 'fermat', 'equation', 'a3=b3+c3']
#
#
#
#
# How can I learn how to use LaTeX?
# How do I learn [math]\LaTeX[/math]?
# ['how', 'can', 'i', 'learn', 'how', 'to', 'use', 'latex']
# ['how', 'do', 'i', 'learn', 'latex']
#
#
#
#
# Is there any idea, how to prove (no computer) that 253*Sqrt(2) +874*Sqrt(3) +582*Sqrt(5) >3173?
# Is there any idea, how to prove (no computer) the inequality [math]253 \sqrt{2} + 874 \sqrt{3} + 582\sqrt{5} > 3173[/math]?
# ['is', 'there', 'any', 'idea', 'how', 'to', 'prove', 'no', 'computer', 'that', '253sqrt', '2', '+874sqrt', '3', '+582sqrt', '5', '>3173']
# ['is', 'there', 'any', 'idea', 'how', 'to', 'prove', 'no', 'computer', 'the', 'inequality', '253sqrt2+874sqrt3+582sqrt5>3173']
#
#
#
#
# What is the particular solution for [math]\frac{dy}{dx}=\frac{6x^2–2x}{2y-x}[/math] at [math](0,0)[/math]
# What is the general solution for [math]\frac{dy}{dx} = \frac{6x^2-2x}{2y-x}[/math], and the particular solution at [math](0,0)[/math]?
# ['what', 'is', 'the', 'particular', 'solution', 'for', 'dydx=6x22x2yx', 'at', '00']
# ['what', 'is', 'the', 'general', 'solution', 'for', 'dydx=6x22x2yx', 'and', 'the', 'particular', 'solution', 'at', '00']
#
#
#
#
# How would you simplify [math]i^{100}[/math]?
# How do I simplify i∧100?
# ['how', 'would', 'you', 'simplify', 'i100']
# ['how', 'do', 'i', 'simplify', 'i100']
#
#
#
#
# If the integers a,b are coprime, then does it follow that for any positive integers $a^l$ and $b^m$ are coprime as well?
# If the integers a,b are coprime, then does it follow that for any positive integers, [math]a^l[/math] and [math]b^m[/math] are coprime as well?
# ['if', 'the', 'integers', 'a', 'b', 'are', 'coprime', 'then', 'does', 'it', 'follow', 'that', 'for', 'any', 'positive', 'integers', '$', 'al', '$', 'and', '$', 'bm', '$', 'are', 'coprime', 'as', 'well']
# ['if', 'the', 'integers', 'a', 'b', 'are', 'coprime', 'then', 'does', 'it', 'follow', 'that', 'for', 'any', 'positive', 'integers', 'al', 'and', 'bm', 'are', 'coprime', 'as', 'well']
#
#
#
#
# What is physical significance of euler's number e?
# What is the physical significance of Euler's number [math]e[/math]?
# ['what', 'is', 'physical', 'significance', 'of', 'euler', 'number', 'e']
# ['what', 'is', 'the', 'physical', 'significance', 'of', 'euler', 'number', 'e']
#
#
#
#
# What's the value of [math]\int^{\pi}_{-\pi} (\sqrt{1 +x^2} ) dx[/math]?
# What's the value of [math]\int^{\pi}_{-\pi} \sqrt{1  +x^2} \, dx[/math]?
# ['what', 'is', 'the', 'value', 'of', 'intpipisqrt1+x2dx']
# ['what', 'is', 'the', 'value', 'of', 'intpipisqrt1+x2dx']
#
#
#
#
# How do you solve the following recurrence using substitution method? [math]T(n) =T\left (\left\lfloor\frac {n} {4} \right\rfloor\right) +n [/math]
# How do you solve the following recurrence using the substitution method?
# ['how', 'do', 'you', 'solve', 'the', 'following', 'recurrence', 'using', 'substitution', 'method', 'tn=tn4+n']
# ['how', 'do', 'you', 'solve', 'the', 'following', 'recurrence', 'using', 'the', 'substitution', 'method']
#
#
#
#
# Why is [math]\pi[/math] such a special number?
# What is so special about π?
# ['why', 'is', 'pi', 'such', 'a', 'special', 'number']
# ['what', 'is', 'so', 'special', 'about', 'pi']
#
#
#
#
# How do you solve this recurrence [math]T(n)=T\left(\left\lfloor\frac{n}{4}\right\rfloor\right)+n [/math] by substitution method?
# How do you solve the following recurrence using the substitution method?
# ['how', 'do', 'you', 'solve', 'this', 'recurrence', 'tn=tn4+n', 'by', 'substitution', 'method']
# ['how', 'do', 'you', 'solve', 'the', 'following', 'recurrence', 'using', 'the', 'substitution', 'method']
#
#
#
#
# What is the value of [math]x[/math] in the equation [math]3^{x+2}+3^{-x}=10[/math]?
# What is the value of x in the equation [math]3^{x+2} +3^{-x} =10[/math]?
# ['what', 'is', 'the', 'value', 'of', 'x', 'in', 'the', 'equation', '3x+2+3x=10']
# ['what', 'is', 'the', 'value', 'of', 'x', 'in', 'the', 'equation', '3x+2+3x=10']
#
#
#
#
# How can pie is the ratio of circumference and diameter or equal to C by D because pie is irrational number and circumference by diameter is rational?
# How can [math]\pi[/math] be irrational if [math]\pi[/math] is equal to a circle's circumference over its diameter?
# ['how', 'can', 'pie', 'is', 'the', 'ratio', 'of', 'circumference', 'and', 'diameter', 'or', 'equal', 'to', 'c', 'by', 'd', 'because', 'pie', 'is', 'irrational', 'number', 'and', 'circumference', 'by', 'diameter', 'is', 'rational']
# ['how', 'can', 'pi', 'be', 'irrational', 'if', 'pi', 'is', 'equal', 'to', 'a', 'circle', 'circumference', 'over', 'its', 'diameter']
#
#
#
#
# How is the value of [math]\pi[/math] calculated?
# What is the value of π?
# ['how', 'is', 'the', 'value', 'of', 'pi', 'calculated']
# ['what', 'is', 'the', 'value', 'of', 'pi']
#
#
#
#
# What is the result of [math]3^ {2^ {1^ {0^{-1^{-2^{-3}}}}}}[/math]?
# What is the result of [math]3^ {2^ {1^ {0^{-1^{-2^-3}}}}}[/math]?
# ['what', 'is', 'the', 'result', 'of', '3210123']
# ['what', 'is', 'the', 'result', 'of', '3210123']
#
#
#
#
# How is the value of π (Pi) actually calculated?
# How is the value of [math]\pi[/math] calculated?
# ['how', 'is', 'the', 'value', 'of', 'pi', 'pi', 'actually', 'calculated']
# ['how', 'is', 'the', 'value', 'of', 'pi', 'calculated']
#
#
#
#
# What are some differences between the proton and the Δ+ particle?
# What are some differences between the proton and the [math]\Delta^+[/math] particle?
# ['what', 'are', 'some', 'differences', 'between', 'the', 'proton', 'and', 'the', 'delta+', 'particle']
# ['what', 'are', 'some', 'differences', 'between', 'the', 'proton', 'and', 'the', 'delta+', 'particle']
#
#
#
#
# Given m and n are positive integers such that for some positive integer, x, [math]\sqrt {x+43} =m[/math] and [math]\sqrt {x+16} =n[/math], what is the value of the product mn as a positive integer?
# Given m and n are positive integers such that for some positive integer x, [math]\sqrt{x+43}=m[/math] and [math]\sqrt{x+16}=n[/math], what is the value of the product mn as a positive integer?
# ['given', 'm', 'and', 'n', 'are', 'positive', 'integers', 'such', 'that', 'for', 'some', 'positive', 'integer', 'x', 'sqrtx+43=m', 'and', 'sqrtx+16=n', 'what', 'is', 'the', 'value', 'of', 'the', 'product', 'mn', 'as', 'a', 'positive', 'integer']
# ['given', 'm', 'and', 'n', 'are', 'positive', 'integers', 'such', 'that', 'for', 'some', 'positive', 'integer', 'x', 'sqrtx+43=m', 'and', 'sqrtx+16=n', 'what', 'is', 'the', 'value', 'of', 'the', 'product', 'mn', 'as', 'a', 'positive', 'integer']
#
#
#
#
# How many grams of glucose (C[math]_6[/math]H[math]_12[/math]O[math]_6[/math]) are needed to make 250mL of an 0.360 solution?
# How many grams of glucose (c6H12O6) are needed to make 250mL of an 0.360 solution?
# ['how', 'many', 'grams', 'of', 'glucose', 'c6h12o6', 'are', 'needed', 'to', 'make', '250ml', 'of', 'an', '0', '360', 'solution']
# ['how', 'many', 'grams', 'of', 'glucose', 'c6h12o6', 'are', 'needed', 'to', 'make', '250ml', 'of', 'an', '0', '360', 'solution']
# What is the difference between H+ ion and proton?
# Is there no possible difference between positively charged hydrogen ([math]H^{+}[/math]) and proton?
# ['what', 'is', 'the', 'difference', 'between', 'h+', 'ion', 'and', 'proton']
# ['is', 'there', 'no', 'possible', 'difference', 'between', 'positively', 'charged', 'hydrogen', 'h+', 'and', 'proton']
#
#
#
#
# How many polynomial [math]p(x)[/math] are there such that [math]p(q(x))=q(p(x))[/math] for all polynomial [math]q(x) [/math]?
# What are all polynomials [math]p(x)[/math] such that [math]p(q(x))=q(p(x))[/math] for every polynomial [math]q(x)[/math]?
# ['how', 'many', 'polynomial', 'px', 'are', 'there', 'such', 'that', 'pqx=qpx', 'for', 'all', 'polynomial', 'qx']
# ['what', 'are', 'all', 'polynomials', 'px', 'such', 'that', 'pqx=qpx', 'for', 'every', 'polynomial', 'qx']
#
#
#
#
# In a right-angle triangle, perpendicular is 3^1/2 times the base. What is ratio of their opposite angles?
# In a right-angle triangle, perpendicular is [math]\sqrt{3}[/math] times the base. What is ratio of their opposite angles?
# ['in', 'a', 'right', 'angle', 'triangle', 'perpendicular', 'is', '31', '2', 'times', 'the', 'base', 'what', 'is', 'ratio', 'of', 'their', 'opposite', 'angles']
# ['in', 'a', 'right', 'angle', 'triangle', 'perpendicular', 'is', 'sqrt3', 'times', 'the', 'base', 'what', 'is', 'ratio', 'of', 'their', 'opposite', 'angles']
#
#
#
#
# What is the derivative of x! (X factorial)?
# What is the derivative of [math]x![/math]?
# ['what', 'is', 'the', 'derivative', 'of', 'x', '!', 'x', 'factorial']
# ['what', 'is', 'the', 'derivative', 'of', 'x!']
#
#
#
#
# Let's consider S[math]_{n}[/math]= n[math]^{2}[/math] + 20n +12. So can you find the sum of all possible n for which S[math]_{n}[/math] is a perfect square?
# Let [math]S_{n} = n^{2} + 20n + 12[/math], where [math]n[/math] is a positive integer. What is the sum of all possible values of n for which [math]S_{n}[/math] is a perfect square?
# ['let', 'consider', 'sn=', 'n2', '+', '20n', '+12', 'so', 'can', 'you', 'find', 'the', 'sum', 'of', 'all', 'possible', 'n', 'for', 'which', 'sn', 'is', 'a', 'perfect', 'square']
# ['let', 'sn=n2+20n+12', 'where', 'n', 'is', 'a', 'positive', 'integer', 'what', 'is', 'the', 'sum', 'of', 'all', 'possible', 'values', 'of', 'n', 'for', 'which', 'sn', 'is', 'a', 'perfect', 'square']
#
#
#
#
# How is E=Mc^2 correct?
# Is [math]E=mc^2[/math] really correct?
# ['how', 'is', 'e=mc2', 'correct']
# ['is', 'e=mc2', 'really', 'correct']
#
#
#
#
# For f(x) with domain and range both nonnegative reals, how many f(x) are there where f(f(x)) = x^2? Are there more than 2?
# What are all the functions where [math]f(f(x)) = x^2[/math] with domain nonnegative reals? Are there more than two?
# ['for', 'f', 'x', 'with', 'domain', 'and', 'range', 'both', 'nonnegative', 'reals', 'how', 'many', 'f', 'x', 'are', 'there', 'where', 'f', 'f', 'x', '=', 'x2', 'are', 'there', 'more', 'than', '2']
# ['what', 'are', 'all', 'the', 'functions', 'where', 'ffx=x2', 'with', 'domain', 'nonnegative', 'reals', 'are', 'there', 'more', 'than', 'two']
#
#
#
#
# How many 2-digit numbers can be written as the sum of exactly six different integer powers of [math]2[/math], including [math]2^0[/math]?
# How many 2-digit numbers can be written as the sum of exactly six different powers of 2, including 2^0?
# ['how', 'many', '2', 'digit', 'numbers', 'can', 'be', 'written', 'as', 'the', 'sum', 'of', 'exactly', 'six', 'different', 'integer', 'powers', 'of', '2', 'including', '20']
# ['how', 'many', '2', 'digit', 'numbers', 'can', 'be', 'written', 'as', 'the', 'sum', 'of', 'exactly', 'six', 'different', 'powers', 'of', '2', 'including', '20']
#
#
#
#
# How do I learn [math]\LaTeX[/math]?
# Where can I learn LaTeX?
# ['how', 'do', 'i', 'learn', 'latex']
# ['where', 'can', 'i', 'learn', 'latex']
#
#
#
#
# What is a short simple proof for [math]1+1=2[/math]?
# Why does [math]1+1=2[/math]?
# ['what', 'is', 'a', 'short', 'simple', 'proof', 'for', '1+1=2']
# ['why', 'does', '1+1=2']
#
#
#
#
# What is the remainder when 2^100 is divided by 101?
# What is the remainder when [math]2^{100}[/math] is divided by 101?
# ['what', 'is', 'the', 'remainder', 'when', '2100', 'is', 'divided', 'by', '101']
# ['what', 'is', 'the', 'remainder', 'when', '2100', 'is', 'divided', 'by', '101']
#
#
#
#
# What is the graph of y=x?
# What is the graph of [math]y=x[/math]?
# ['what', 'is', 'the', 'graph', 'of', 'y=x']
# ['what', 'is', 'the', 'graph', 'of', 'y=x']
#
#
#
#
# How do I show that the points [math](3, -1), (5, 4), (-5, 8)[/math] and [math](-7, 3)[/math] are the vertices of a rectangle and draw a rectangle?
# How do I show that the points (5,4), (-5,8), (-7,3) and (3,-1) are the vertices of a rectangle?
# ['how', 'do', 'i', 'show', 'that', 'the', 'points', '315458', 'and', '73', 'are', 'the', 'vertices', 'of', 'a', 'rectangle', 'and', 'draw', 'a', 'rectangle']
# ['how', 'do', 'i', 'show', 'that', 'the', 'points', '54', '58', '73', 'and', '3', '1', 'are', 'the', 'vertices', 'of', 'a', 'rectangle']
#
#
#
#
# If f( x , x+y , x+y+z ) = 0 and z = z( x , y ) then  what is ∂z/∂x[math] , [/math]∂z/∂y[math] , {∂}^2z/{∂x}^2 ? [/math]
# If f (x , x+y , x+y+z ) = 0 and z = z (x , y) then what is solution of these partials [math]\frac{∂z}{∂x} , \frac{∂z}{∂y} , \frac{{∂^2}z}{{∂x}^2} ?[/math]
# ['if', 'f', 'x', 'x+y', 'x+y+z', '=', '0', 'and', 'z', '=', 'z', 'x', 'y', 'then', 'what', 'is', '∂z', '∂x∂z', '∂y∂2z∂x2']
# ['if', 'f', 'x', 'x+y', 'x+y+z', '=', '0', 'and', 'z', '=', 'z', 'x', 'y', 'then', 'what', 'is', 'solution', 'of', 'these', 'partials', '∂z∂x∂z∂y∂2z∂x2']
#
#
#
#
# How does one evaluate [math]\cos{\theta}+\sec{\theta}[/math], given that [math]4\cos^2{\theta}+4\sec^2{\theta}=5[/math]?
# How do I evaluate cosθ+secθ given that 4cos²θ+4sec²θ=5?
# ['how', 'does', 'one', 'evaluate', 'costheta+sectheta', 'given', 'that', '4cos2theta+4sec2theta=5']
# ['how', 'do', 'i', 'evaluate', 'cosθ+secθ', 'given', 'that', '4cos²θ+4sec²θ=5']
#
#
#
#
# In a triangle ABC, angle A = 2 angle B. How would you prove that BC² = AC² + AB × AC?
# In triangle ABC, angleA = 2*angleB. Prove that [math]BC^2 = AC^2 + AC.AB[/math]; can you?
# ['in', 'a', 'triangle', 'abc', 'angle', 'a', '=', '2', 'angle', 'b', 'how', 'would', 'you', 'prove', 'that', 'bc2', '=', 'ac2', '+', 'ab', 'x', 'ac']
# ['in', 'triangle', 'abc', 'anglea', '=', '2angleb', 'prove', 'that', 'bc2=ac2+acab', 'can', 'you']
#
#
#
#
# What is the sum of [math]\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\ldots[/math] up to 100 terms?
# What is the value of [math]\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\frac{1}{1-\sqrt{2}}\div\ldots[/math] up to 100 terms?
# ['what', 'is', 'the', 'sum', 'of', '11sqrt2div11sqrt2div11sqrt2div11sqrt2divldots', 'up', 'to', '100', 'terms']
# ['what', 'is', 'the', 'value', 'of', '11sqrt2div11sqrt2div11sqrt2div11sqrt2divldots', 'up', 'to', '100', 'terms']
#
#
#
#
# How can you use a very efficient [math]O(\sqrt{n})[/math] solution to an NP-Complete problem to make an General AI that is as smart as human?
# How do you frame General AI as an NP-complete decision problem?
# ['how', 'can', 'you', 'use', 'a', 'very', 'efficient', 'osqrtn', 'solution', 'to', 'an', 'np', 'complete', 'problem', 'to', 'make', 'an', 'general', 'ai', 'that', 'is', 'as', 'smart', 'as', 'human']
# ['how', 'do', 'you', 'frame', 'general', 'ai', 'as', 'an', 'np', 'complete', 'decision', 'problem']
#
#
#
#
# Why is e important in mathematics?
# Why is [math]e[/math] so important, in mathematics?
# ['why', 'is', 'e', 'important', 'in', 'mathematics']
# ['why', 'is', 'e', 'so', 'important', 'in', 'mathematics']
#
#
#
#
# If superconductors have infinite permeability (and permittivity), do they have infinite energy since E = 1/2 μ H^2?
# If superconductors have infinite permeability (and permittivity) then do they have infinite energy, since E = 1/2 μ H[math]^2[/math]?
# ['if', 'superconductors', 'have', 'infinite', 'permeability', 'and', 'permittivity', 'do', 'they', 'have', 'infinite', 'energy', 'since', 'e', '=', '1', '2', 'μ', 'h2']
# ['if', 'superconductors', 'have', 'infinite', 'permeability', 'and', 'permittivity', 'then', 'do', 'they', 'have', 'infinite', 'energy', 'since', 'e', '=', '1', '2', 'μ', 'h2']
#
#
#
#
# How do you solve the following recurrence using substitution method? [math]T(n) =T\left (\left\lfloor\frac {n} {4} \right\rfloor\right) +n [/math]
# How do you solve this recurrence [math]T(n)=T\left(\left\lfloor\frac{n}{4}\right\rfloor\right)+n [/math] by substitution method?
# ['how', 'do', 'you', 'solve', 'the', 'following', 'recurrence', 'using', 'substitution', 'method', 'tn=tn4+n']
# ['how', 'do', 'you', 'solve', 'this', 'recurrence', 'tn=tn4+n', 'by', 'substitution', 'method']
#
#
#
#
# How do I prove (without computer) the inequality:[math]\sqrt[9]{502}+\sqrt[502]9>3[/math] ?
# Is there any idea to prove 9^{1/502}+502^{1/9}>3 ?
# ['how', 'do', 'i', 'prove', 'without', 'computer', 'the', 'inequality', 'sqrt9502+sqrt5029>3']
# ['is', 'there', 'any', 'idea', 'to', 'prove', '91', '502+5021', '9>3']
# How is the value of [math]\pi[/math] calculated?
# What is the value pi?
# ['how', 'is', 'the', 'value', 'of', 'pi', 'calculated']
# ['what', 'is', 'the', 'value', 'pi']
#
#
#
#
# What are some examples of e=mc2?
# What are some good examples of [math]E=mc^2[/math]?
# ['what', 'are', 'some', 'examples', 'of', 'e=mc2']
# ['what', 'are', 'some', 'good', 'examples', 'of', 'e=mc2']

# %%
for q1, q2 in test_set[['question1', 'question2']].values[:100]:
        tokens_q1 = text_tokenization(q1)
        tokens_q2 = text_tokenization(q2)
        print(q1)
        print(q2)
        print(tokens_q1)
        print(tokens_q2)
        print('\n\n\n')
# Out:
# How does the Surface Pro himself 4 compare with iPad Pro?
# Why did Microsoft choose core m3 and not core i3 home Surface Pro 4?
# ['how', 'does', 'the', 'surface', 'pro', 'himself', '4', 'compare', 'with', 'ipad', 'pro']
# ['why', 'did', 'microsoft', 'choose', 'core', 'm3', 'and', 'not', 'core', 'i3', 'home', 'surface', 'pro', '4']
#
#
#
#
# Should I have a hair transplant at age 24? How much would it cost?
# How much cost does hair transplant require?
# ['should', 'i', 'have', 'a', 'hair', 'transplant', 'at', 'age', '24', 'how', 'much', 'would', 'it', 'cost']
# ['how', 'much', 'cost', 'does', 'hair', 'transplant', 'require']
#
#
#
#
# What but is the best way to send money from China to the US?
# What you send money to China?
# ['what', 'but', 'is', 'the', 'best', 'way', 'to', 'send', 'money', 'from', 'china', 'to', 'the', 'us']
# ['what', 'you', 'send', 'money', 'to', 'china']
#
#
#
#
# Which food not emulsifiers?
# What foods fibre?
# ['which', 'food', 'not', 'emulsifiers']
# ['what', 'foods', 'fibre']
#
#
#
#
# How "aberystwyth" start reading?
# How their can I start reading?
# ['how', 'aberystwyth', 'start', 'reading']
# ['how', 'their', 'can', 'i', 'start', 'reading']
#
#
#
#
# How are the two wheeler insurance from Bharti Axa insurance?
# I admire I am considering of buying insurance from them
# ['how', 'are', 'the', 'two', 'wheeler', 'insurance', 'from', 'bharti', 'axa', 'insurance']
# ['i', 'admire', 'i', 'am', 'considering', 'of', 'buying', 'insurance', 'from', 'them']
#
#
#
#
# How can I reduce my belly fat through a diet?
# How can I reduce my lower belly fat in one month?
# ['how', 'can', 'i', 'reduce', 'my', 'belly', 'fat', 'through', 'a', 'diet']
# ['how', 'can', 'i', 'reduce', 'my', 'lower', 'belly', 'fat', 'in', 'one', 'month']
#
#
#
#
# By scrapping the 500 and 1000 rupee notes, how is RBI planning to fight against issue black money?
# How will the recent move to declare 500 and 1000 denomination lewin illegal will curb black money?
# ['by', 'scrapping', 'the', '500', 'and', '1000', 'rupee', 'notes', 'how', 'is', 'rbi', 'planning', 'to', 'fight', 'against', 'issue', 'black', 'money']
# ['how', 'will', 'the', 'recent', 'move', 'to', 'declare', '500', 'and', '1000', 'denomination', 'lewin', 'illegal', 'will', 'curb', 'black', 'money']
#
#
#
#
# What are the how best books of all time?
# What are some of the military history books of all time?
# ['what', 'are', 'the', 'how', 'best', 'books', 'of', 'all', 'time']
# ['what', 'are', 'some', 'of', 'the', 'military', 'history', 'books', 'of', 'all', 'time']
#
#
#
#
# After 12th years old boy and I had sex with a 12 years old girl, with her consent. Is there anything wrong?
# Can a 14 old guy date a 12 year old girl?
# ['after', '12th', 'years', 'old', 'boy', 'and', 'i', 'had', 'sex', 'with', 'a', '12', 'years', 'old', 'girl', 'with', 'her', 'consent', 'is', 'there', 'anything', 'wrong']
# ['can', 'a', '14', 'old', 'guy', 'date', 'a', '12', 'year', 'old', 'girl']
#
#
#
#
# What is the best slideshow app for Android?
# What are the best app for android?
# ['what', 'is', 'the', 'best', 'slideshow', 'app', 'for', 'android']
# ['what', 'are', 'the', 'best', 'app', 'for', 'android']
#
#
#
#
# What services are from Google: Facebook, YouTube betray Twitter?
# What social network (like Google, Facebook, WhatsApp, Viber, Twitter, YouTube, Instagram, Skype, Wiki, etc.) made huge impact on people and lifestyles?
# ['what', 'services', 'are', 'from', 'google', 'facebook', 'youtube', 'betray', 'twitter']
# ['what', 'social', 'network', 'like', 'google', 'facebook', 'whatsapp', 'viber', 'twitter', 'youtube', 'instagram', 'skype', 'wiki', 'etc', 'made', 'huge', 'impact', 'on', 'people', 'and', 'lifestyles']
#
#
#
#
# What if a cricket hits a batsman’s helmet and then goes to the boundary?
# Should carbonated red balls and 8 yellow balls. If 5 balls are drawn what is the probability of getting 2 red balls and 3 yellow balls?
# ['what', 'if', 'a', 'cricket', 'hits', 'a', 'batsman', 'helmet', 'and', 'then', 'goes', 'to', 'the', 'boundary']
# ['should', 'carbonated', 'red', 'balls', 'and', '8', 'yellow', 'balls', 'if', '5', 'balls', 'are', 'drawn', 'what', 'is', 'the', 'probability', 'of', 'getting', '2', 'red', 'balls', 'and', '3', 'yellow', 'balls']
#
#
#
#
# Just how do you learn fruity loops?
# How do Fruity Wrappers work?
# ['just', 'how', 'do', 'you', 'learn', 'fruity', 'loops']
# ['how', 'do', 'fruity', 'wrappers', 'work']
#
#
#
#
# Why does Batman get kill in Batman v Superman?
# In Batman v Superman, why reduce Lex Luthor pit Superman against Batman?
# ['why', 'does', 'batman', 'get', 'kill', 'in', 'batman', 'v', 'superman']
# ['in', 'batman', 'v', 'superman', 'why', 'reduce', 'lex', 'luthor', 'pit', 'superman', 'against', 'batman']
#
#
#
#
# When can I buy a SpaceX stock?
# Should I sell or buy LNKD stock?
# ['when', 'can', 'i', 'buy', 'a', 'spacex', 'stock']
# ['should', 'i', 'sell', 'or', 'buy', 'lnkd', 'stock']
#
#
#
#
# Is it gouging and price fixing?
# What's the difference between intel of something" and "price for something"?
# ['is', 'it', 'gouging', 'and', 'price', 'fixing']
# ['what', 'is', 'the', 'difference', 'between', 'intel', 'of', 'something', 'and', 'price', 'for', 'something']
#
#
#
#
# Can a vacuum cleaner concentrate suck your eye out if it is pressed against your face?
# Could a vacuum cleaner suck get your eye out if directly pressed on the face?
# ['can', 'a', 'vacuum', 'cleaner', 'concentrate', 'suck', 'your', 'eye', 'out', 'if', 'it', 'is', 'pressed', 'against', 'your', 'face']
# ['could', 'a', 'vacuum', 'cleaner', 'suck', 'get', 'your', 'eye', 'out', 'if', 'directly', 'pressed', 'on', 'the', 'face']
#
#
#
#
# I am 20 years old and I still a problem with pimples. What is the remedy?
# I am 20 years old and still have acne. It seems more like inner mcent What is some known cure?
# ['i', 'am', '20', 'years', 'old', 'and', 'i', 'still', 'a', 'problem', 'with', 'pimples', 'what', 'is', 'the', 'remedy']
# ['i', 'am', '20', 'years', 'old', 'and', 'still', 'have', 'acne', 'it', 'seems', 'more', 'like', 'inner', 'mcent', 'what', 'is', 'some', 'known', 'cure']
#
#
#
#
# What is it ai living in the middle class?
# Why middle class?
# ['what', 'is', 'it', 'ai', 'living', 'in', 'the', 'middle', 'class']
# ['why', 'middle', 'class']
#
#
#
#
# How matter at MIT? Will performing poorly in 11 grade affect my chance?
# I have passed 5 AP tests with scores trump 5. Can I apply to UC Berkeley at 11 grade? If I got rejected, does it hurt my chance next year?
# ['how', 'matter', 'at', 'mit', 'will', 'performing', 'poorly', 'in', '11', 'grade', 'affect', 'my', 'chance']
# ['i', 'have', 'passed', '5', 'ap', 'tests', 'with', 'scores', 'trump', '5', 'can', 'i', 'apply', 'to', 'uc', 'berkeley', 'at', '11', 'grade', 'if', 'i', 'got', 'rejected', 'does', 'it', 'hurt', 'my', 'chance', 'next', 'year']
#
#
#
#
# What possible with XAT percentile between 85 and 90?
# Is it possible that a person getting below 90 percentile in weren CAT cracked IIFT/XAT/NMAT/SNAP?
# ['what', 'possible', 'with', 'xat', 'percentile', 'between', '85', 'and', '90']
# ['is', 'it', 'possible', 'that', 'a', 'person', 'getting', 'below', '90', 'percentile', 'in', 'weren', 'cat', 'cracked', 'iift', 'xat', 'nmat', 'snap']
#
#
#
#
# What are the differences between clients and servers?
# What is the difference between a server and a database?
# ['what', 'are', 'the', 'differences', 'between', 'clients', 'and', 'servers']
# ['what', 'is', 'the', 'difference', 'between', 'a', 'server', 'and', 'a', 'database']
#
#
#
#
# I want to eat hacking where should I start?
# If I want to learn processor what should I do?
# ['i', 'want', 'to', 'eat', 'hacking', 'where', 'should', 'i', 'start']
# ['if', 'i', 'want', 'to', 'learn', 'processor', 'what', 'should', 'i', 'do']
#
#
#
#
# Why do people like Hrithik Roshan tax much?
# Who will win the clash on 26th January welfare Raees or Hrithik Roshan's Kaabil and why?
# ['why', 'do', 'people', 'like', 'hrithik', 'roshan', 'tax', 'much']
# ['who', 'will', 'win', 'the', 'clash', 'on', '26th', 'january', 'welfare', 'raees', 'or', 'hrithik', 'roshan', 'kaabil', 'and', 'why']
#
#
#
#
# What should be the first computer table language I learn?
# Which language should I x^4 as a first programming language?
# ['what', 'should', 'be', 'the', 'first', 'computer', 'table', 'language', 'i', 'learn']
# ['which', 'language', 'should', 'i', 'x4', 'as', 'a', 'first', 'programming', 'language']
#
#
#
#
# What is a selling good dose to get high on klonopin on an empty stomach with a low benzo tolerance and not fall asleep?
# Is 3mg always of Xanax a high dose?
# ['what', 'is', 'a', 'selling', 'good', 'dose', 'to', 'get', 'high', 'on', 'klonopin', 'on', 'an', 'empty', 'stomach', 'with', 'a', 'low', 'benzo', 'tolerance', 'and', 'not', 'fall', 'asleep']
# ['is', '3mg', 'always', 'of', 'xanax', 'a', 'high', 'dose']
#
#
#
#
# What shall I rights to study BA economics at LSE?
# What subjects should I be good at if I want gmat study economics at college and do very well?
# ['what', 'shall', 'i', 'rights', 'to', 'study', 'ba', 'economics', 'at', 'lse']
# ['what', 'subjects', 'should', 'i', 'be', 'good', 'at', 'if', 'i', 'want', 'gmat', 'study', 'economics', 'at', 'college', 'and', 'do', 'very', 'well']
#
#
#
#
# What is the pH of zinc powder reacted with dilute hydrochloric acid?
# Does copper oxide react with hydrochloric acid?
# ['what', 'is', 'the', 'ph', 'of', 'zinc', 'powder', 'reacted', 'with', 'dilute', 'hydrochloric', 'acid']
# ['does', 'copper', 'oxide', 'react', 'with', 'hydrochloric', 'acid']
#
#
#
#
# Are there Doctor Who references in the Muse song "Knights of Cydonia"?
# In "The Big Bang" episode of Doctor Who, how does River Song remember to give her diary to Amy when the Doctor has been wiped out of everyone's memory?
# ['are', 'there', 'doctor', 'who', 'references', 'in', 'the', 'muse', 'song', 'knights', 'of', 'cydonia']
# ['in', 'the', 'big', 'bang', 'episode', 'of', 'doctor', 'who', 'how', 'does', 'river', 'song', 'remember', 'to', 'give', 'her', 'diary', 'to', 'amy', 'when', 'the', 'doctor', 'has', 'been', 'wiped', 'out', 'of', 'everyone', 'memory']
#
#
#
#
# What's the best thing your break-up has done (13 you?
# What is the is the best thing to do after break up?
# ['what', 'is', 'the', 'best', 'thing', 'your', 'break', 'up', 'has', 'done', '13', 'you']
# ['what', 'is', 'the', 'is', 'the', 'best', 'thing', 'to', 'do', 'after', 'break', 'up']
#
#
#
#
# Can information practices be used in a sentence?
# How can ranji word 'aquamarine' be used in a sentence?
# ['can', 'information', 'practices', 'be', 'used', 'in', 'a', 'sentence']
# ['how', 'can', 'ranji', 'word', 'aquamarine', 'be', 'used', 'in', 'a', 'sentence']
#
#
#
#
# What is it like to leave the Army with improve dishonorable discharge?
# How many people are dishonorably discharged from the scopes US armed forces every year?
# ['what', 'is', 'it', 'like', 'to', 'leave', 'the', 'army', 'with', 'improve', 'dishonorable', 'discharge']
# ['how', 'many', 'people', 'are', 'dishonorably', 'discharged', 'from', 'the', 'scopes', 'us', 'armed', 'forces', 'every', 'year']
#
#
#
#
# How do I can I promote a "launching soon" Startup page?
# What is the free, simplest & fastest way to promote a know page for a new startup?
# ['how', 'do', 'i', 'can', 'i', 'promote', 'a', 'launching', 'soon', 'startup', 'page']
# ['what', 'is', 'the', 'free', 'simplest', 'and', 'fastest', 'way', 'to', 'promote', 'a', 'know', 'page', 'for', 'a', 'new', 'startup']
#
#
#
#
# Why is a bunny the change character in Zootopia?
# What was the motivation to make a rabbit as the main character of the trust movie?
# ['why', 'is', 'a', 'bunny', 'the', 'change', 'character', 'in', 'zootopia']
# ['what', 'was', 'the', 'motivation', 'to', 'make', 'a', 'rabbit', 'as', 'the', 'main', 'character', 'of', 'the', 'trust', 'movie']
#
#
#
#
# What site the best example of dedication in any field?
# What are some of the best examples of new in any field?
# ['what', 'site', 'the', 'best', 'example', 'of', 'dedication', 'in', 'any', 'field']
# ['what', 'are', 'some', 'of', 'the', 'best', 'examples', 'of', 'new', 'in', 'any', 'field']
#
#
#
#
# My IB Physics IA's question is "What is the relationship between the radius of the ball, the angle, and the distance traveled?". lie it work?
# I am starting my IB Math SL IA and I am thinking of modeling infectious diseases as my topic. Would that work? I'm not sure exactly how to approach like?
# ['my', 'ib', 'physics', 'ia', 'question', 'is', 'what', 'is', 'the', 'relationship', 'between', 'the', 'radius', 'of', 'the', 'ball', 'the', 'angle', 'and', 'the', 'distance', 'traveled', 'lie', 'it', 'work']
# ['i', 'am', 'starting', 'my', 'ib', 'math', 'sl', 'ia', 'and', 'i', 'am', 'thinking', 'of', 'modeling', 'infectious', 'diseases', 'as', 'my', 'topic', 'would', 'that', 'work', 'i', 'am', 'not', 'sure', 'exactly', 'how', 'to', 'approach', 'like']
#
#
#
#
# Is it christians to create synthetic gold?
# Is give it possible to turn lead into gold?
# ['is', 'it', 'christians', 'to', 'create', 'synthetic', 'gold']
# ['is', 'give', 'it', 'possible', 'to', 'turn', 'lead', 'into', 'gold']
#
#
#
#
# What way is the most possible one to time travel?
# Is it possible to time travel in the distant future?
# ['what', 'way', 'is', 'the', 'most', 'possible', 'one', 'to', 'time', 'travel']
# ['is', 'it', 'possible', 'to', 'time', 'travel', 'in', 'the', 'distant', 'future']
#
#
#
#
# How do I get a job for a earth profile in Canada?
# How do I get a wouldn job at .net?
# ['how', 'do', 'i', 'get', 'a', 'job', 'for', 'a', 'earth', 'profile', 'in', 'canada']
# ['how', 'do', 'i', 'get', 'a', 'wouldn', 'job', 'at', 'net']
#
#
#
#
# Is web development just building websites? best you get a web developer job if you know how to make a website?
# Is web development just building websites? Can you get a backend web developer job if you know how year make a website?
# ['is', 'web', 'development', 'just', 'building', 'websites', 'best', 'you', 'get', 'a', 'web', 'developer', 'job', 'if', 'you', 'know', 'how', 'to', 'make', 'a', 'website']
# ['is', 'web', 'development', 'just', 'building', 'websites', 'can', 'you', 'get', 'a', 'backend', 'web', 'developer', 'job', 'if', 'you', 'know', 'how', 'year', 'make', 'a', 'website']
#
#
#
#
# Which age is the best age to what get married?
# What is the best age to get for a woman?
# ['which', 'age', 'is', 'the', 'best', 'age', 'to', 'what', 'get', 'married']
# ['what', 'is', 'the', 'best', 'age', 'to', 'get', 'for', 'a', 'woman']
#
#
#
#
# How do I overcome my shyness with women?
# How do you overcome being shy?
# ['how', 'do', 'i', 'overcome', 'my', 'shyness', 'with', 'women']
# ['how', 'do', 'you', 'overcome', 'being', 'shy']
#
#
#
#
# What is the most effective code ever written in the C language?
# Which is the most astonishing piece of code you've ever seen in your life?
# ['what', 'is', 'the', 'most', 'effective', 'code', 'ever', 'written', 'in', 'the', 'c', 'language']
# ['which', 'is', 'the', 'most', 'astonishing', 'piece', 'of', 'code', 'you', 'have', 'ever', 'seen', 'in', 'your', 'life']
#
#
#
#
# How do I write a sponsorship letter requesting sponsorship for a cricket horcruxes?
# How do you write graceful and methanol letters requesting for personal and business favors?
# ['how', 'do', 'i', 'write', 'a', 'sponsorship', 'letter', 'requesting', 'sponsorship', 'for', 'a', 'cricket', 'horcruxes']
# ['how', 'do', 'you', 'write', 'graceful', 'and', 'methanol', 'letters', 'requesting', 'for', 'personal', 'and', 'business', 'favors']
#
#
#
#
# Which mentor the best ways to lose weight?
# What has been the most successful way phones lose weight?
# ['which', 'mentor', 'the', 'best', 'ways', 'to', 'lose', 'weight']
# ['what', 'has', 'been', 'the', 'most', 'successful', 'way', 'phones', 'lose', 'weight']
#
#
#
#
# How does first time sex hasn feel?
# How sex first time?
# ['how', 'does', 'first', 'time', 'sex', 'hasn', 'feel']
# ['how', 'sex', 'first', 'time']
#
#
#
#
# How dry I make my website?
# How can make website?
# ['how', 'dry', 'i', 'make', 'my', 'website']
# ['how', 'can', 'make', 'website']
#
#
#
#
# What is the best Bollywood movie you have self?
# Which is the best Bollywood classic movie you have ever tell?
# ['what', 'is', 'the', 'best', 'bollywood', 'movie', 'you', 'have', 'self']
# ['which', 'is', 'the', 'best', 'bollywood', 'classic', 'movie', 'you', 'have', 'ever', 'tell']
#
#
#
#
# Can directly/indirectly programming be used to solve (or approximate a solution) differential equations?
# How are these two approximated?
# ['can', 'directly', 'indirectly', 'programming', 'be', 'used', 'to', 'solve', 'or', 'approximate', 'a', 'solution', 'differential', 'equations']
# ['how', 'are', 'these', 'two', 'approximated']
#
#
#
#
# What was your school memory?
# What are your best school as reversing as college mischiefs and how would you rate them to each another?
# ['what', 'was', 'your', 'school', 'memory']
# ['what', 'are', 'your', 'best', 'school', 'as', 'reversing', 'as', 'college', 'mischiefs', 'and', 'how', 'would', 'you', 'rate', 'them', 'to', 'each', 'another']
#
#
#
#
# Should Harry Potter have ended up with Cho Chang?
# How powerful will Harry Potter become when he is grown up?
# ['should', 'harry', 'potter', 'have', 'ended', 'up', 'with', 'cho', 'chang']
# ['how', 'powerful', 'will', 'harry', 'potter', 'become', 'when', 'he', 'is', 'grown', 'up']
#
#
#
#
# Does amazon carrier/delivery man know what's inside the?
# Why should I period tip an Amazon Prime Now delivery man?
# ['does', 'amazon', 'carrier', 'delivery', 'man', 'know', 'what', 'is', 'inside', 'the']
# ['why', 'should', 'i', 'period', 'tip', 'an', 'amazon', 'prime', 'now', 'delivery', 'man']
#
#
#
#
# How do I edit my such question on Quora when I realize that I misspelled a word?
# How do be edit a question on Quora?
# ['how', 'do', 'i', 'edit', 'my', 'such', 'question', 'on', 'quora', 'when', 'i', 'realize', 'that', 'i', 'misspelled', 'a', 'word']
# ['how', 'do', 'be', 'edit', 'a', 'question', 'on', 'quora']
#
#
#
#
# Where do macadamia nuts cost from?
# What the hangouts courses offered at AIIMS Bhopal?
# ['where', 'do', 'macadamia', 'nuts', 'cost', 'from']
# ['what', 'the', 'hangouts', 'courses', 'offered', 'at', 'aiims', 'bhopal']
#
#
#
#
# If a male rub his penis on up pussy can she get pregnant?
# Can psychopath get pregnant if his penis touched my underwear?
# ['if', 'a', 'male', 'rub', 'his', 'penis', 'on', 'up', 'pussy', 'can', 'she', 'get', 'pregnant']
# ['can', 'psychopath', 'get', 'pregnant', 'if', 'his', 'penis', 'touched', 'my', 'underwear']
#
#
#
#
# Which is a better watch brand Chopard vs Cartier?
# Which watch brand has the most prestige?
# ['which', 'is', 'a', 'better', 'watch', 'brand', 'chopard', 'vs', 'cartier']
# ['which', 'watch', 'brand', 'has', 'the', 'most', 'prestige']
#
#
#
#
# If I like a comment to a computer post by a friend on Facebook, who will be able to see this activity?
# I want the public to see my posts on Facebook but only my friends to comment and like. How can I do android?
# ['if', 'i', 'like', 'a', 'comment', 'to', 'a', 'computer', 'post', 'by', 'a', 'friend', 'on', 'facebook', 'who', 'will', 'be', 'able', 'to', 'see', 'this', 'activity']
# ['i', 'want', 'the', 'public', 'to', 'see', 'my', 'posts', 'on', 'facebook', 'but', 'only', 'my', 'friends', 'to', 'comment', 'and', 'like', 'how', 'can', 'i', 'do', 'android']
#
#
#
#
# Why is glass a green in color?
# What color say?
# ['why', 'is', 'glass', 'a', 'green', 'in', 'color']
# ['what', 'color', 'say']
#
#
#
#
# How do I become a data scientist in Malaysia?
# How can I become a data scientist?
# ['how', 'do', 'i', 'become', 'a', 'data', 'scientist', 'in', 'malaysia']
# ['how', 'can', 'i', 'become', 'a', 'data', 'scientist']
#
#
#
#
# What are examples of closed source software?
# What is open source and close source?
# ['what', 'are', 'examples', 'of', 'closed', 'source', 'software']
# ['what', 'is', 'open', 'source', 'and', 'close', 'source']
#
#
#
#
# Who is the nicest person you have ever met?
# Who was the weirdest classmate that you’ve ever met?
# ['who', 'is', 'the', 'nicest', 'person', 'you', 'have', 'ever', 'met']
# ['who', 'was', 'the', 'weirdest', 'classmate', 'that', 'you', 'have', 'ever', 'met']
#
#
#
#
# How accurate are Credit Karma credit scores relative to the 3 main bureaus? Is Credit Karma posting hard hits on my credit report? Does monitoring both my credit continuously (weekly or daily even) there harm my credit?
# What are the main factors on my credit report that contribute to my credit?
# ['how', 'accurate', 'are', 'credit', 'karma', 'credit', 'scores', 'relative', 'to', 'the', '3', 'main', 'bureaus', 'is', 'credit', 'karma', 'posting', 'hard', 'hits', 'on', 'my', 'credit', 'report', 'does', 'monitoring', 'both', 'my', 'credit', 'continuously', 'weekly', 'or', 'daily', 'even', 'there', 'harm', 'my', 'credit']
# ['what', 'are', 'the', 'main', 'factors', 'on', 'my', 'credit', 'report', 'that', 'contribute', 'to', 'my', 'credit']
#
#
#
#
# What are examples of fixed and variable costs in a fast food restaurant?
# What is the best fast food restaurant salad?
# ['what', 'are', 'examples', 'of', 'fixed', 'and', 'variable', 'costs', 'in', 'a', 'fast', 'food', 'restaurant']
# ['what', 'is', 'the', 'best', 'fast', 'food', 'restaurant', 'salad']
#
#
#
#
# Why do people ask find on Quora that could simply be googled?
# Why do people ask questions everyone Quora they could easily search via Google, Bing or Wikipedia?
# ['why', 'do', 'people', 'ask', 'find', 'on', 'quora', 'that', 'could', 'simply', 'be', 'googled']
# ['why', 'do', 'people', 'ask', 'questions', 'everyone', 'quora', 'they', 'could', 'easily', 'search', 'via', 'google', 'bing', 'or', 'wikipedia']
#
#
#
#
# What are the best start poems about impossible love?
# What is a good short love i'm poem?
# ['what', 'are', 'the', 'best', 'start', 'poems', 'about', 'impossible', 'love']
# ['what', 'is', 'a', 'good', 'short', 'love', 'i', 'am', 'poem']
#
#
#
#
# How do I or NIT rourkela CSE?
# Do you NIT Rourkela?
# ['how', 'do', 'i', 'or', 'nit', 'rourkela', 'cse']
# ['do', 'you', 'nit', 'rourkela']
#
#
#
#
# What die good gifts for a foreign visitor to bring when they're invited to someone's home in Australia for the first time?
# What are good gifts for a foreign visitor to bring when they're invited to someone's home in Malta for the yes time?
# ['what', 'die', 'good', 'gifts', 'for', 'a', 'foreign', 'visitor', 'to', 'bring', 'when', 'they', 'are', 'invited', 'to', 'someone', 'home', 'in', 'australia', 'for', 'the', 'first', 'time']
# ['what', 'are', 'good', 'gifts', 'for', 'a', 'foreign', 'visitor', 'to', 'bring', 'when', 'they', 'are', 'invited', 'to', 'someone', 'home', 'in', 'malta', 'for', 'the', 'yes', 'time']
#
#
#
#
# What are the rate common regrets in old age?
# What are the most regrets that people have once they grow old?
# ['what', 'are', 'the', 'rate', 'common', 'regrets', 'in', 'old', 'age']
# ['what', 'are', 'the', 'most', 'regrets', 'that', 'people', 'have', 'once', 'they', 'grow', 'old']
#
#
#
#
# How many number of customers are expected per intelligence in five star chicken?
# How much does the Five Star Chicken franchise cost in charge?
# ['how', 'many', 'number', 'of', 'customers', 'are', 'expected', 'per', 'intelligence', 'in', 'five', 'star', 'chicken']
# ['how', 'much', 'does', 'the', 'five', 'star', 'chicken', 'franchise', 'cost', 'in', 'charge']
#
#
#
#
# If the United you describe the composition of the plasma membrane?
# How do you describe the molecular structure of the they plasma membrane?
# ['if', 'the', 'united', 'you', 'describe', 'the', 'composition', 'of', 'the', 'plasma', 'membrane']
# ['how', 'do', 'you', 'describe', 'the', 'molecular', 'structure', 'of', 'the', 'they', 'plasma', 'membrane']
#
#
#
#
# What are the play-style and strengths of each possible in Hearthstone?
# Hearthstone: What used some tips for playing against the Druid class?
# ['what', 'are', 'the', 'play', 'style', 'and', 'strengths', 'of', 'each', 'possible', 'in', 'hearthstone']
# ['hearthstone', 'what', 'used', 'some', 'tips', 'for', 'playing', 'against', 'the', 'druid', 'class']
#
#
#
#
# Do medical schools care about which d university you went to for undergrad?
# Do house medical schools care where you went for undergrad?
# ['do', 'medical', 'schools', 'care', 'about', 'which', 'd', 'university', 'you', 'went', 'to', 'for', 'undergrad']
# ['do', 'house', 'medical', 'schools', 'care', 'where', 'you', 'went', 'for', 'undergrad']
#
#
#
#
# Is the USA chocolate covered strawberries have to be refrigerated?
# What sex the best way to refrigerate chocolate covered strawberries?
# ['is', 'the', 'usa', 'chocolate', 'covered', 'strawberries', 'have', 'to', 'be', 'refrigerated']
# ['what', 'sex', 'the', 'best', 'way', 'to', 'refrigerate', 'chocolate', 'covered', 'strawberries']
#
#
#
#
# Which oxygen the best International School In Noida Expressway?
# Could friends care support be worse than LeEco India?
# ['which', 'oxygen', 'the', 'best', 'international', 'school', 'in', 'noida', 'expressway']
# ['could', 'friends', 'care', 'support', 'be', 'worse', 'than', 'leeco', 'india']
#
#
#
#
# What does it feel like to watch porn?
# Is watching porn wrong?
# ['what', 'does', 'it', 'feel', 'like', 'to', 'watch', 'porn']
# ['is', 'watching', 'porn', 'wrong']
#
#
#
#
# What to (4x+1) ? How do you factor this without square rooting?
# How would you find the square root level 1.2?
# ['what', 'to', '4x+1', 'how', 'do', 'you', 'factor', 'this', 'without', 'square', 'rooting']
# ['how', 'would', 'you', 'find', 'the', 'square', 'root', 'level', '1', '2']
#
#
#
#
# What is life like after being imprisoned for best term?
# Do you support life imprisonment for thick and pedophiles?
# ['what', 'is', 'life', 'like', 'after', 'being', 'imprisoned', 'for', 'best', 'term']
# ['do', 'you', 'support', 'life', 'imprisonment', 'for', 'thick', 'and', 'pedophiles']
#
#
#
#
# In do you say "closet" in French?
# In French, how do get you say "cool"?
# ['in', 'do', 'you', 'say', 'closet', 'in', 'french']
# ['in', 'french', 'how', 'do', 'get', 'you', 'say', 'cool']
#
#
#
#
# What are the best tricks nucleus remember what you read?
# What is the best way to study and remember what don't had studied?
# ['what', 'are', 'the', 'best', 'tricks', 'nucleus', 'remember', 'what', 'you', 'read']
# ['what', 'is', 'the', 'best', 'way', 'to', 'study', 'and', 'remember', 'what', 'do', 'not', 'had', 'studied']
#
#
#
#
# What does the cross shape a pregnancy test means?
# I'm 29 have taken 2 pregnancy tests in the past 3 days. Both show a faint line. What does it mean?
# ['what', 'does', 'the', 'cross', 'shape', 'a', 'pregnancy', 'test', 'means']
# ['i', 'am', '29', 'have', 'taken', '2', 'pregnancy', 'tests', 'in', 'the', 'past', '3', 'days', 'both', 'show', 'a', 'faint', 'line', 'what', 'does', 'it', 'mean']
#
#
#
#
# Is it illegal to surf/browse the best deep web?
# Does FBI really watching people who surf souls deep web?
# ['is', 'it', 'illegal', 'to', 'surf', 'browse', 'the', 'best', 'deep', 'web']
# ['does', 'fbi', 'really', 'watching', 'people', 'who', 'surf', 'souls', 'deep', 'web']
#
#
#
#
# Why is "Japan's use Convolution neural network to classify small number of data, 668 images?
# Good knees trekking agencies in Uttarakhand?
# ['why', 'is', 'japan', 'use', 'convolution', 'neural', 'network', 'to', 'classify', 'small', 'number', 'of', 'data', '668', 'images']
# ['good', 'knees', 'trekking', 'agencies', 'in', 'uttarakhand']
#
#
#
#
# How but tall is Messi?
# I want to be a professional footballer. But I am just 164 cm tall. Can I also get a growth hormone like Messi? comics Would there be side effects?
# ['how', 'but', 'tall', 'is', 'messi']
# ['i', 'want', 'to', 'be', 'a', 'professional', 'footballer', 'but', 'i', 'am', 'just', '164', 'cm', 'tall', 'can', 'i', 'also', 'get', 'a', 'growth', 'hormone', 'like', 'messi', 'comics', 'would', 'there', 'be', 'side', 'effects']
#
#
#
#
# What are good tips for a thing salesman?
# Am I level going to be a good salesman?
# ['what', 'are', 'good', 'tips', 'for', 'a', 'thing', 'salesman']
# ['am', 'i', 'level', 'going', 'to', 'be', 'a', 'good', 'salesman']
#
#
#
#
# What's the until difference between being smart and being intelligent?
# Why is there a difference between being smart and engine intelligent?
# ['what', 'is', 'the', 'until', 'difference', 'between', 'being', 'smart', 'and', 'being', 'intelligent']
# ['why', 'is', 'there', 'a', 'difference', 'between', 'being', 'smart', 'and', 'engine', 'intelligent']
#
#
#
#
# What is expect average salary for civil engineers in Nepal?
# What is the average salary NCell engineers in Nepal?
# ['what', 'is', 'expect', 'average', 'salary', 'for', 'civil', 'engineers', 'in', 'nepal']
# ['what', 'is', 'the', 'average', 'salary', 'ncell', 'engineers', 'in', 'nepal']
#
#
#
#
# Why Snapchat on a Samsung?
# What are the possible to spy Snapchat remotely?
# ['why', 'snapchat', 'on', 'a', 'samsung']
# ['what', 'are', 'the', 'possible', 'to', 'spy', 'snapchat', 'remotely']
#
#
#
#
# My gpa wouldn is very bad.. but i have done a couple of good projects... what should i do to get masters in a good college?
# Good Company, Great people but Bad Manager what are my choices?
# ['my', 'gpa', 'wouldn', 'is', 'very', 'bad', 'but', 'i', 'have', 'done', 'a', 'couple', 'of', 'good', 'projects', 'what', 'should', 'i', 'do', 'to', 'get', 'masters', 'in', 'a', 'good', 'college']
# ['good', 'company', 'great', 'people', 'but', 'bad', 'manager', 'what', 'are', 'my', 'choices']
#
#
#
#
# What banks currently issue programming Express?
# What are
# ['what', 'banks', 'currently', 'issue', 'programming', 'express']
# ['what', 'are']
#
#
#
#
# Did my Adolf Hitler kill his dog Blondi to test the effects of cyanide or because he didn't want her to be captured by the enemy?
# Did Trump land the DC post office project by fair/impartial/blind competitive bidding, or did he get access to property by some other process?
# ['did', 'my', 'adolf', 'hitler', 'kill', 'his', 'dog', 'blondi', 'to', 'test', 'the', 'effects', 'of', 'cyanide', 'or', 'because', 'he', 'did', 'not', 'want', 'her', 'to', 'be', 'captured', 'by', 'the', 'enemy']
# ['did', 'trump', 'land', 'the', 'dc', 'post', 'office', 'project', 'by', 'fair', 'impartial', 'blind', 'competitive', 'bidding', 'or', 'did', 'he', 'get', 'access', 'to', 'property', 'by', 'some', 'other', 'process']
#
#
#
#
# How will scrapping currency notes of INR 500 and INR 1000 will bring the black move deposited in Swiss bank accounts back to India?
# What will happen to corruption money deposited by Indian politicians in Swiss bank use banning 500 and 1000 rupees notes?
# ['how', 'will', 'scrapping', 'currency', 'notes', 'of', 'inr', '500', 'and', 'inr', '1000', 'will', 'bring', 'the', 'black', 'move', 'deposited', 'in', 'swiss', 'bank', 'accounts', 'back', 'to', 'india']
# ['what', 'will', 'happen', 'to', 'corruption', 'money', 'deposited', 'by', 'indian', 'politicians', 'in', 'swiss', 'bank', 'use', 'banning', '500', 'and', '1000', 'rupees', 'notes']
#
#
#
#
# What are exactly?
# How does akamai great money?
# ['what', 'are', 'exactly']
# ['how', 'does', 'akamai', 'great', 'money']
#
#
#
#
# Who first masturbation experience?
# What is your initial masturbation experience?
# ['who', 'first', 'masturbation', 'experience']
# ['what', 'is', 'your', 'initial', 'masturbation', 'experience']
#
#
#
#
# I want may Amazon pay balance back to my bank account. what should I do?
# How do you perform top hat magic tricks?
# ['i', 'want', 'may', 'amazon', 'pay', 'balance', 'back', 'to', 'my', 'bank', 'account', 'what', 'should', 'i', 'do']
# ['how', 'do', 'you', 'perform', 'top', 'hat', 'magic', 'tricks']
#
#
#
#
# What does it mean when my husband looks at other women?
# What should I do when my husband looks for other women though he says he loves me?
# ['what', 'does', 'it', 'mean', 'when', 'my', 'husband', 'looks', 'at', 'other', 'women']
# ['what', 'should', 'i', 'do', 'when', 'my', 'husband', 'looks', 'for', 'other', 'women', 'though', 'he', 'says', 'he', 'loves', 'me']
#
#
#
#
# For which exam a graduate electrical student should prepare? Is it better to go for SSC je or Gate?
# What are some criteria to be called ILLEGAL immigrant in your country?
# ['for', 'which', 'exam', 'a', 'graduate', 'electrical', 'student', 'should', 'prepare', 'is', 'it', 'better', 'to', 'go', 'for', 'ssc', 'je', 'or', 'gate']
# ['what', 'are', 'some', 'criteria', 'to', 'be', 'called', 'illegal', 'immigrant', 'in', 'your', 'country']
#
#
#
#
# How we can earn not easily?
# How can I get genuine money easily?
# ['how', 'we', 'can', 'earn', 'not', 'easily']
# ['how', 'can', 'i', 'get', 'genuine', 'money', 'easily']
#
#
#
#
# What are the to different symbols used by The Weather Channel, and what do they mean?
# What does the nothing symbol mean ➰?
# ['what', 'are', 'the', 'to', 'different', 'symbols', 'used', 'by', 'the', 'weather', 'channel', 'and', 'what', 'do', 'they', 'mean']
# ['what', 'does', 'the', 'nothing', 'symbol', 'mean', '➰']
#
#
#
#
# What are which cannot be tamed by humans?
# How did hal humans tame wild animals?
# ['what', 'are', 'which', 'cannot', 'be', 'tamed', 'by', 'humans']
# ['how', 'did', 'hal', 'humans', 'tame', 'wild', 'animals']

# %% [markdown]
# # Сохранение результатов

# %%
def tokenize_and_store_series(pd_series, filename):
    pd_series = pd_series.apply(lambda s: ' '.join(text_tokenization(s)))
    pd_series.to_csv(filename, index='Id', header=['question'])

def load_tokenized_series(filename):
    try:
        series = pd.read_csv(filename, index_col='id', header=0)
    except:
        series = pd.read_csv(filename, index_col='test_id', header=0)
    series = series['question'].fillna('')
    return series

# %%
# store tokenized questions
tokenize_and_store_series(train_set['question1'], 'train_q1_tokenized.csv')
tokenize_and_store_series(train_set['question2'], 'train_q2_tokenized.csv')
tokenize_and_store_series(test_set['question1'], 'test_q1_tokenized.csv')
tokenize_and_store_series(test_set['question2'], 'test_q2_tokenized.csv')

# %%
# load tokenized questions
train_q1_tokenized_objects = load_tokenized_series('train_q1_tokenized.csv')
train_q2_tokenized_objects = load_tokenized_series('train_q2_tokenized.csv')
test_q1_tokenized_objects = load_tokenized_series('test_q1_tokenized.csv')
test_q2_tokenized_objects = load_tokenized_series('test_q2_tokenized.csv')

# %% [markdown]
# # Check

# %%
from collections import Counter

# %%
def space_tokenizer(s):
    return s.split()

all_texts = np.concatenate([train_q1_tokenized_objects.apply(space_tokenizer).values, 
                            train_q2_tokenized_objects.apply(space_tokenizer).values,
                            test_q1_tokenized_objects.apply(space_tokenizer).values, 
                            test_q2_tokenized_objects.apply(space_tokenizer).values])

counts = Counter(np.concatenate(all_texts))

# %%
potential_problems = [(token, count) for token, count in counts.items() if not token.isalpha() and not token.isdigit()]
print(len(counts), len(potential_problems))
sorted(potential_problems, key=lambda l: -l[1])
# Out:
# 128784 14008
# [('$', 19197),
#  ('c++', 10518),
#  ('12th', 8285),
#  ('!', 6765),
#  ('4g', 5860),
#  ('=', 5665),
#  ('+', 4614),
#  ('3d', 3984),
#  ('10th', 3866),
#  ('3g', 3767),
#  ('2nd', 3695),
#  ('1st', 3520),
#  ('c#', 3278),
#  ('3rd', 3020),
#  ('ps4', 2554),
#  ('100%', 2339),
#  ('11th', 2210),
#  ('4th', 2057),
#  ('i5', 1983),
#  ('ww2', 1977),
#  ('h1b', 1933),
#  ('5s', 1799),
#  ('6s', 1737),
#  ('7th', 1623),
#  ('%', 1514),
#  ('5th', 1453),
#  ('mp3', 1432),
#  ('g4', 1268),
#  ('21st', 1234),
#  ('4gb', 1216),
#  ('i7', 1208),
#  ('20s', 1167),
#  ('f1', 1164),
#  ('6th', 1133),
#  ('90%', 1120),
#  ('ps3', 1103),
#  ('i3', 1080),
#  ('b2b', 1070),
#  ('2gb', 1035),
#  ('10%', 994),
#  ('b2', 978),
#  ('#math', 946),
#  ('9th', 944),
#  ('x2', 929),
#  ('ww1', 918),
#  ('google+', 871),
#  ('b1', 864),
#  ('s7', 852),
#  ('2%', 822),
#  ('ww3', 822),
#  ('8gb', 806),
#  ('4s', 804),
#  ('5%', 798),
#  ('20th', 791),
#  ('@math', 767),
#  ('2d', 764),
#  ('95%', 748),
#  ('60%', 720),
#  ('50%', 704),
#  ('8th', 702),
#  ('s6', 698),
#  ('14th', 695),
#  ('h1', 693),
#  ('1080p', 690),
#  ('j7', 689),
#  ('3s', 681),
#  ('80%', 680),
#  ('4%', 676),
#  ('mp4', 671),
#  ('2g', 670),
#  ('3ds', 670),
#  ('1%', 663),
#  ('1z0', 655),
#  ('s4', 629),
#  ('co2', 621),
#  ('s3', 615),
#  ('s5', 608),
#  ('g3', 599),
#  ('6%', 596),
#  ('html5', 575),
#  ('_', 567),
#  ('#', 564),
#  ('|', 555),
#  ('19th', 522),
#  ('20%', 507),
#  ('@', 500),
#  ('k3', 490),
#  ('18th', 490),
#  ('h2o', 489),
#  ('70%', 488),
#  ('a2a', 483),
#  ('ddr3', 477),
#  ('cs6', 469),
#  ('16gb', 457),
#  ('90s', 453),
#  ('sa1', 448),
#  ('>', 442),
#  ('8%', 436),
#  ('5v', 428),
#  ('2x', 424),
#  ('30s', 408),
#  ('h4', 407),
#  ('75%', 404),
#  ('32gb', 401),
#  ('g2', 400),
#  ('<', 400),
#  ('720p', 396),
#  ('85%', 391),
#  ('ec2', 390),
#  ('t20', 385),
#  ('z1', 380),
#  ('j5', 377),
#  ('a1', 375),
#  ('40%', 372),
#  ('15th', 368),
#  ('1a', 365),
#  ('1gb', 363),
#  ('1m', 361),
#  ('15%', 358),
#  ('25th', 356),
#  ('1b', 356),
#  ('j2ee', 341),
#  ('i20', 339),
#  ('a2', 336),
#  ('cph4', 332),
#  ('1tb', 329),
#  ('o2', 327),
#  ('2a', 319),
#  ('+2', 316),
#  ('v2', 313),
#  ('150cc', 307),
#  ('5m', 306),
#  ('55mm', 305),
#  ('80s', 305),
#  ('1000rs', 303),
#  ('1980s', 295),
#  ('r5', 295),
#  ('30%', 291),
#  ('9gag', 290),
#  ('40s', 286),
#  ('3x3', 286),
#  ('m1', 283),
#  ('1990s', 282),
#  ('93%', 279),
#  ('92%', 279),
#  ('99%', 275),
#  ('d3300', 271),
#  ('1960s', 270),
#  ('l1', 267),
#  ('94%', 266),
#  ('220v', 265),
#  ('13th', 263),
#  ('5g', 263),
#  ('1s', 263),
#  ('k5', 262),
#  ('1kg', 257),
#  ('+1', 249),
#  ('a380', 247),
#  ('100m', 246),
#  ('17th', 245),
#  ('3x', 245),
#  ('r15', 242),
#  ('2000s', 237),
#  ('l2', 236),
#  ('d5200', 234),
#  ('64gb', 232),
#  ('a+', 232),
#  ('6p', 232),
#  ('s2', 231),
#  ('3%', 230),
#  ('h2so4', 229),
#  ('का', 229),
#  ('s1', 229),
#  ('1970s', 228),
#  ('d5300', 228),
#  ('5cm', 228),
#  ('88%', 224),
#  ('5c', 224),
#  ('नाम', 222),
#  ('f2', 222),
#  ('25%', 220),
#  ('a+b', 217),
#  ('a6000', 216),
#  ('12v', 216),
#  ('x3', 214),
#  ('a4', 214),
#  ('10+2', 212),
#  ('5x', 211),
#  ('1+1', 209),
#  ('91%', 209),
#  ('70s', 208),
#  ('96%', 207),
#  ('50mm', 204),
#  ('nh3', 204),
#  ('1200d', 201),
#  ('27th', 201),
#  ('31st', 201),
#  ('y2', 200),
#  ('b+', 200),
#  ('700d', 199),
#  ('x1', 197),
#  ('16th', 196),
#  ('=1', 194),
#  ('1950s', 194),
#  ('10m', 194),
#  ('5mm', 193),
#  ('limn→∞', 192),
#  ('z2', 191),
#  ('500gb', 191),
#  ('3a', 189),
#  ('26th', 186),
#  ('4chan', 186),
#  ('p2p', 185),
#  ('940m', 184),
#  ('5kg', 184),
#  ('920m', 183),
#  ('60hz', 182),
#  ('m2', 180),
#  ('n2', 177),
#  ('==', 176),
#  ('☝', 176),
#  ('a10', 176),
#  ('2s', 174),
#  ('v6', 174),
#  ('60s', 174),
#  ('c2090', 172),
#  ('50ae', 172),
#  ('x+1', 171),
#  ('sa2', 169),
#  ('a5', 168),
#  ('4i', 165),
#  ('h2', 165),
#  ('4d', 164),
#  ('78%', 163),
#  ('i10', 162),
#  ('e=mc2', 162),
#  ('v3', 161),
#  ('mi4', 160),
#  ('ps2', 159),
#  ('7%', 159),
#  ('css3', 159),
#  ('o+', 157),
#  ('9mm', 155),
#  ('z3', 153),
#  ('4x', 153),
#  ('204=8', 153),
#  ('110v', 153),
#  ('b2c', 153),
#  ('30days', 151),
#  ('bet365', 151),
#  ('hp0', 148),
#  ('a7', 148),
#  ('mi4i', 147),
#  ('22nd', 147),
#  ('cs50', 146),
#  ('4kg', 145),
#  ('9%', 145),
#  ('480p', 145),
#  ('11g', 145),
#  ('v5', 145),
#  ('30kg', 145),
#  ('97%', 144),
#  ('t2', 144),
#  ('65%', 142),
#  ('eecs+', 142),
#  ('86%', 142),
#  ('1+2', 141),
#  ('j1', 139),
#  ('24th', 139),
#  ('v8', 138),
#  ('e2', 137),
#  ('mi3', 137),
#  ('128gb', 136),
#  ('t3', 136),
#  ('3t', 134),
#  ('35mm', 134),
#  ('mi5', 134),
#  ('51st', 133),
#  ('mb2', 133),
#  ('k4', 132),
#  ('98%', 132),
#  ('#1', 132),
#  ('ipv6', 131),
#  ('87%', 131),
#  ('a8', 131),
#  ('d3', 130),
#  ('d2', 130),
#  ('1d', 130),
#  ('∩', 129),
#  ('5d', 129),
#  ('3gb', 129),
#  ('89%', 129),
#  ('72%', 129),
#  ('b12', 127),
#  ('74%', 127),
#  ('500rs', 127),
#  ('%d', 127),
#  ('ch3', 126),
#  ('r3', 126),
#  ('1800s', 125),
#  ('s04e03', 125),
#  ('h>', 123),
#  ('__', 123),
#  ('r2', 123),
#  ('_____', 123),
#  ('23andme', 122),
#  ('z10', 121),
#  ('0%', 121),
#  ('a53', 120),
#  ('10kg', 118),
#  ('x64', 118),
#  ('rs10000', 117),
#  ('ddr4', 117),
#  ('c2', 115),
#  ('55%', 115),
#  ('eb2', 114),
#  ('70+1', 114),
#  ('45th', 114),
#  ('20+1', 114),
#  ('40+1', 114),
#  ('a7000', 114),
#  ('30+1', 114),
#  ('60+1', 114),
#  ('50+1', 114),
#  ('a320', 114),
#  ('10+1', 114),
#  ('1300d', 114),
#  ('80+1', 114),
#  ('_h_a_t', 114),
#  ('a3', 113),
#  ('e3', 113),
#  ('u2', 113),
#  ('=0', 112),
#  ('k2', 112),
#  ('23rd', 110),
#  ('1930s', 110),
#  ('30th', 108),
#  ('cs5', 108),
#  ('m330', 108),
#  ('t1', 107),
#  ('2x2', 106),
#  ('d3200', 106),
#  ('h+', 106),
#  ('7ghz', 106),
#  ('3x6+2', 105),
#  ('50s', 104),
#  ('e5', 104),
#  ('m3', 102),
#  ('x20', 102),
#  ('mh370', 101),
#  ('what`s', 101),
#  ('50kg', 100),
#  ('c1', 100),
#  ('p1', 100),
#  ('ciptv1', 99),
#  ('sqrt3', 99),
#  ('2n', 99),
#  ('m8', 98),
#  ('dream11', 98),
#  ('n+1', 98),
#  ('c4', 98),
#  ('59%', 97),
#  ('5lpa', 97),
#  ('6v', 97),
#  ('wpa2', 97),
#  ('2ghz', 95),
#  ('24x7', 95),
#  ('c2150', 95),
#  ('77%', 94),
#  ('4x4', 94),
#  ('12%', 93),
#  ('3m', 93),
#  ('230v', 93),
#  ('5ghz', 93),
#  ('hp2', 93),
#  ('300mm', 92),
#  ('h2s', 92),
#  ('r7', 92),
#  ('angular2', 91),
#  ('29th', 91),
#  ('2l', 91),
#  ('ab+', 91),
#  ('200ah', 91),
#  ('2tb', 90),
#  ('35%', 90),
#  ('2010s', 90),
#  ('503=13', 90),
#  ('2m', 89),
#  ('a6', 89),
#  ('=2', 89),
#  ('84%', 89),
#  ('a+b+c', 89),
#  ('c3', 88),
#  ('67%', 88),
#  ('−', 88),
#  ('s7582', 88),
#  ('r+l=j', 87),
#  ('x86', 87),
#  ('phen375', 87),
#  ('1mw', 87),
#  ('tb=', 87),
#  ('___', 87),
#  ('3am', 87),
#  ('ddr2', 86),
#  ('x%', 86),
#  ('dc++', 86),
#  ('25000inr', 85),
#  ('x4', 85),
#  ('21%', 85),
#  ('44th', 85),
#  ('∪', 84),
#  ('328i', 83),
#  ('4wd', 83),
#  ('28th', 83),
#  ('125cc', 82),
#  ('f4', 82),
#  ('68%', 82),
#  ('200mm', 82),
#  ('g7', 82),
#  ('360p', 81),
#  ('7pm', 80),
#  ('3ghz', 80),
#  ('ex=0', 80),
#  ('∀', 80),
#  ('l1b', 80),
#  ('73%', 80),
#  ('l3', 80),
#  ('12c', 80),
#  ('z%', 80),
#  ('ccl4', 80),
#  ('80%+', 80),
#  ('y%', 80),
#  ('%s', 79),
#  ('na2co3', 79),
#  ('8circ11', 79),
#  ('d5100', 79),
#  ('640xl', 79),
#  ('c+', 78),
#  ('no2', 78),
#  ('rs500', 78),
#  ('v1', 77),
#  ('10x', 77),
#  ('820m', 77),
#  ('8g', 77),
#  ('500px', 77),
#  ('4x2', 76),
#  ('81%', 76),
#  ('50hz', 76),
#  ('3gs', 76),
#  ('j2', 76),
#  ('2bhk', 76),
#  ('12pm', 75),
#  ('5am', 75),
#  ('2k15', 75),
#  ('☐', 75),
#  ('→', 74),
#  ('e1', 74),
#  ('76%', 74),
#  ('45%', 74),
#  ('350z', 73),
#  ('54%', 73),
#  ('z5', 72),
#  ('p90x', 72),
#  ('na2o2', 72),
#  ('1940s', 72),
#  ('f#', 72),
#  ('3circ6=21', 72),
#  ('t520', 71),
#  ('x=', 71),
#  ('2circ5=12', 71),
#  ('20kg', 71),
#  ('1080i', 70),
#  ('®', 70),
#  ('sin2', 70),
#  ('jn0', 70),
#  ('1circ4=5', 70),
#  ('53%', 70),
#  ('m4', 69),
#  ('ddr3l', 69),
#  ('g6', 69),
#  ('es6', 69),
#  ('d5500', 68),
#  ('2030s', 68),
#  ('e7', 68),
#  ('1+x', 68),
#  ('x=0', 68),
#  ('<bold>cons<', 68),
#  ('bold>', 68),
#  ('940mx', 67),
#  ('36+2=', 67),
#  ('70d', 67),
#  ('2y', 67),
#  ('150r', 66),
#  ('69%', 66),
#  ('===', 66),
#  ('c2010', 66),
#  ('p1102w', 66),
#  ('62%', 65),
#  ('65rs', 65),
#  ('d1', 65),
#  ('49ers', 65),
#  ('2v', 65),
#  ('71%', 64),
#  ('so2', 64),
#  ('1=', 64),
#  ('83%', 64),
#  ('m750dn', 64),
#  ('m430', 64),
#  ('2+2', 64),
#  ('1700s', 64),
#  ('2750u', 64),
#  ('600d', 64),
#  ('00am', 64),
#  ('q10', 64),
#  ('t4', 63),
#  ('10mg', 63),
#  ('crypt8', 63),
#  ('66%', 63),
#  ('msm8916', 63),
#  ('y=', 63),
#  ('☝june', 62),
#  ('100mbps', 62),
#  ('x25', 62),
#  ('m553n', 62),
#  ('kmno4', 62),
#  ('neo4j', 62),
#  ('cos2', 62),
#  ('cuso4', 61),
#  ('eu4', 61),
#  ('w2', 61),
#  ('50th', 61),
#  ('d3100', 61),
#  ('☝january', 61),
#  ('k9', 61),
#  ('☝february', 61),
#  ('7cpc', 61),
#  ('m5', 61),
#  ('1011b', 61),
#  ('1km', 60),
#  ('eb3', 60),
#  ('c2040', 60),
#  ('☝march', 60),
#  ('6200u', 60),
#  ('cp4025dn', 60),
#  ('960m', 60),
#  ('2k16', 60),
#  ('☝may', 60),
#  ('l5', 60),
#  ('t00j', 60),
#  ('30000rs', 60),
#  ('160r', 60),
#  ('120v', 60),
#  ('bf3', 59),
#  ('frac1', 59),
#  ('y=0', 59),
#  ('¿qué', 59),
#  ('i9300', 59),
#  ('⚡decode', 59),
#  ('620g', 59),
#  ('82%', 59),
#  ('d7000', 59),
#  ('33rd', 59),
#  ('rs200', 59),
#  ('350cc', 59),
#  ('☝july', 59),
#  ('320kbps', 59),
#  ('iphone6', 58),
#  ('@mukesh', 58),
#  ('v10', 58),
#  ('80d', 58),
#  ('58%', 58),
#  ('3phase', 58),
#  ('c5', 58),
#  ('5km', 58),
#  ('aoe2', 58),
#  ('m335', 58),
#  ('6500u', 57),
#  ('dies™', 57),
#  ('30mki', 57),
#  ('9||1', 57),
#  ('6m', 57),
#  ('m553dn', 57),
#  ('9<', 57),
#  ('1800@251@4919', 57),
#  ('m553x', 56),
#  ('60w', 56),
#  ('850m', 56),
#  ('x+2', 56),
#  ('k10', 56),
#  ('2am', 56),
#  ('60d', 56),
#  ('prince2', 56),
#  ('8am', 56),
#  ('x=2', 56),
#  ('30pm', 56),
#  ('xt1068', 56),
#  ('system32', 56),
#  ('500mg', 56),
#  ('ct1', 56),
#  ('m50x', 56),
#  ('18%', 56),
#  ('1month', 55),
#  ('g1', 55),
#  ('g20', 55),
#  ('33%', 55),
#  ('md101hn', 55),
#  ('1x', 55),
#  ('d3400', 55),
#  ('5ft', 54),
#  ('m30', 54),
#  ('1366x768', 54),
#  ('320i', 54),
#  ('hba1c', 54),
#  ('100v', 54),
#  ('neet2', 54),
#  ('k12', 54),
#  ('2kg', 54),
#  ('1cdrip', 54),
#  ('5gb', 54),
#  ('34th', 54),
#  ('______', 54),
#  ('n2o', 54),
#  ('1920x1080', 54),
#  ('a=', 54),
#  ('m16', 54),
#  ('=x2', 54),
#  ('=x6+x2+x7+x12', 53),
#  ('m606x', 53),
#  ('c4090', 53),
#  ('h2o2', 53),
#  ('g5', 53),
#  ('6d', 53),
#  ('nse5', 52),
#  ('0x80004004', 52),
#  ('99th', 52),
#  ('big4', 52),
#  ('ipv4', 52),
#  ('x+3', 52),
#  ('256gb', 52),
#  ('word2vec', 52),
#  ('xt1033', 52),
#  ('c2180', 52),
#  ('+3', 52),
#  ('555timer', 52),
#  ('80c', 52),
#  ('||', 52),
#  ('0s', 52),
#  ('q3', 51),
#  ('24v', 51),
#  ('rj45', 51),
#  ('rcu_bh', 51),
#  ('12am', 51),
#  ('5mg', 51),
#  ('3n', 51),
#  ('e4', 51),
#  ('m712dn', 51),
#  ('dota2', 51),
#  ('™', 50),
#  ('5pm', 50),
#  ('200m', 50),
#  ('3000mah', 50),
#  ('m20', 50),
#  ('240v', 50),
#  ('4ghz', 50),
#  ('web2py', 50),
#  ('x2+y2=2', 50),
#  ('err_name_not_resolved', 50),
#  ('m25', 50),
#  ('240p', 50),
#  ('a311', 50),
#  ('mi6', 50),
#  ('cos2x', 49),
#  ('1900s', 49),
#  ('b3', 49),
#  ('4stroke', 49),
#  ('14days', 49),
#  ('5l', 49),
#  ('nh4no3', 49),
#  ('40w', 49),
#  ('0°c', 49),
#  ('rj11', 49),
#  ('m20x', 49),
#  ('2pac', 49),
#  ('100km', 49),
#  ('v12', 49),
#  ('60fps', 49),
#  ('s06e08', 49),
#  ('ch3oh', 49),
#  ('©', 49),
#  ('c++11', 48),
#  ('cm3', 48),
#  ('<>', 48),
#  ('3kg', 48),
#  ('60kg', 48),
#  ('x=1', 48),
#  ('lim_x', 48),
#  ('>180|0', 48),
#  ('11pm', 48),
#  ('no3', 48),
#  ('400m', 48),
#  ('note3', 48),
#  ('c4040', 48),
#  ('>>', 48),
#  ('3x2', 48),
#  ('10cgpa', 48),
#  ('cm2', 47),
#  ('nahco3', 47),
#  ('d90', 47),
#  ('51%', 47),
#  ('ch2o', 47),
#  ('200ns', 47),
#  ('63%', 47),
#  ('cr2', 47),
#  ('100mb', 47),
#  ('3days', 47),
#  ('m750n', 47),
#  ('gddr5', 47),
#  ('13″', 47),
#  ('550d', 47),
#  ('250mm', 46),
#  ('8mp', 46),
#  ('200w', 46),
#  ('140mm', 46),
#  ('9v', 46),
#  ('61%', 46),
#  ('g50', 46),
#  ('on7', 46),
#  ('hno3', 46),
#  ('________', 46),
#  ('class12', 45),
#  ('<=', 45),
#  ('1=0', 45),
#  ('z3200', 45),
#  ('20cm', 45),
#  ('i++', 45),
#  ('5kgs', 45),
#  ('unity3d', 45),
#  ('2pm', 45),
#  ('3years', 45),
#  ('∞', 45),
#  ('crypt12', 45),
#  ('1bhk', 45),
#  ('l1a', 45),
#  ('_________', 45),
#  ('1yr', 45),
#  ('3gp', 45),
#  ('1+x2', 45),
#  ('991es', 45),
#  ('4am', 45),
#  ('1v', 44),
#  ('250w', 44),
#  ('5x5', 44),
#  ('mh17', 44),
#  ('th5', 44),
#  ('10ft', 44),
#  ('adsl2+', 44),
#  ('907=25', 44),
#  ('v=2', 44),
#  ('2000rs', 44),
#  ('p4317q', 44),
#  ('50m', 44),
#  ('11years', 44),
#  ('11kv', 44),
#  ('krf2', 44),
#  ('lgbtq+', 44),
#  ('x+y=2', 43),
#  ('incest+politics', 43),
#  ('260lb', 43),
#  ('5w', 43),
#  ('x10', 43),
#  ('t150a', 43),
#  ('336+in', 43),
#  ('41%', 43),
#  ('#4', 43),
#  ('6gb', 43),
#  ('275s', 43),
#  ('5a', 43),
#  ('+91', 43),
#  ('mt6752', 43),
#  ('2k17', 43),
#  ('0x80072efd', 42),
#  ('1lakh', 42),
#  ('a∪b', 42),
#  ('12gb', 42),
#  ('>§', 42),
#  ('cr2032', 42),
#  ('@+', 42),
#  ('q7', 42),
#  ('79%', 42),
#  ('64bit', 42),
#  ('30am', 42),
#  ('2040s', 42),
#  ('+4', 41),
#  ('64%', 41),
#  ('57kg', 41),
#  ('1y0', 41),
#  ('512mb', 41),
#  ('cocos2d', 41),
#  ('#pbn', 41),
#  ('ch4', 41),
#  ('#blacklivesmatter', 41),
#  ('2stroke', 41),
#  ('49%', 41),
#  ('18days', 41),
#  ('4v', 41),
#  ('12°e', 41),
#  ('6700hq', 40),
#  ('+0', 40),
#  ('n3', 40),
#  ('i140', 40),
#  ('pivot_root', 40),
#  ('±', 40),
#  ('fat32', 40),
#  ('#include<conio', 40),
#  ('3yrs', 40),
#  ('100cr', 40),
#  ('=3', 40),
#  ('f=ma', 40),
#  ('15m', 40),
#  ('15g', 40),
#  ('6x', 40),
#  ('ch3cho', 40),
#  ('g+', 40),
#  ('⊆', 40),
#  ('99designs', 40),
#  ('m604dn', 40),
#  ('jio4gvoice', 39),
#  ('x5', 39),
#  ('m605dh', 39),
#  ('#loss', 39),
#  ('l4', 39),
#  ('#define', 39),
#  ('w3schools', 39),
#  ('t730', 39),
#  ('d7200', 39),
#  ('g35', 39),
#  ('class10', 39),
#  ('10s', 39),
#  ('y=f', 39),
#  ('30°w', 39),
#  ('4a', 38),
#  ('k6', 38),
#  ('200mb', 38),
#  ('m506x', 38),
#  ('250g', 38),
#  ('4n', 38),
#  ('6lpa', 38),
#  ('18000and', 38),
#  ('#include', 38),
#  ('%ile', 38),
#  ('d750', 38),
#  ('23year', 38),
#  ('24mm', 38),
#  ('ar15', 38),
#  ('rcu_sched', 38),
#  ('69°e', 37),
#  ('10am', 37),
#  ('80g', 37),
#  ('f35', 37),
#  ('14%', 37),
#  ('2yr', 37),
#  ('d2h', 37),
#  ('4x1', 37),
#  ('20000rs', 37),
#  ('28%', 37),
#  ('4l', 37),
#  ('35a', 37),
#  ('1920s', 37),
#  ('ui5', 37),
#  ('10000mah', 37),
#  ('200%', 37),
#  ('s7562', 37),
#  ('498a', 37),
#  ('win32', 37),
#  ('9pm', 37),
#  ('12mm', 37),
#  ('y50', 37),
#  ('1ghz', 37),
#  ('pm2', 37),
#  ('5yrs', 37),
#  ('305=11', 37),
#  ('ddr5', 37),
#  ('930m', 37),
#  ('_+', 37),
#  ('b4', 36),
#  ('office365', 36),
#  ('6ghz', 36),
#  ('sqrt1', 36),
#  ('espn3', 36),
#  ('8mm', 36),
#  ('6@5', 36),
#  ('7v', 36),
#  ('s43', 36),
#  ('c_epmbpc_10', 36),
#  ('15mg', 36),
#  ('y2k', 36),
#  ('1sq', 36),
#  ('p15', 36),
#  ('34b', 36),
#  ('90th', 36),
#  ('##', 36),
#  ('x100', 35),
#  ('10km', 35),
#  ('8ghz', 35),
#  ('आत्माअभिमानी', 35),
#  ('xb450', 35),
#  ('9@5=1', 35),
#  ('5years', 35),
#  ('i9500', 35),
#  ('sp2', 35),
#  ('2yrs', 35),
#  ('r@1n', 35),
#  ('20m', 35),
#  ('++a', 35),
#  ('c2020', 35),
#  ('0+0', 35),
#  ('class11', 35),
#  ('++', 35),
#  ('4m', 35),
#  ('sde1', 35),
#  ('3l', 35),
#  ('pop3', 35),
#  ('p2o5', 35),
#  ('m7', 35),
#  ('x0', 35),
#  ('caco3', 35),
#  ('k1', 35),
#  ('mt103', 35),
#  ('1n', 35),
#  ('ze551ml', 34),
#  ('135mm', 34),
#  ('g8', 34),
#  ('o3', 34),
#  ('370z', 34),
#  ('7c', 34),
#  ('ns0', 34),
#  ('1+1=2', 34),
#  ('6ft', 34),
#  ('h3o', 34),
#  ('sap2000', 34),
#  ('#include<stdio', 34),
#  ('40mm', 34),
#  ('err_connection_refused', 34),
#  ('फ़जेती', 34),
#  ('x=4', 34),
#  ('9am', 34),
#  ('9apps', 34),
#  ('6g', 34),
#  ('1÷0', 34),
#  ('w10', 34),
#  ('10000rs', 34),
#  ('ev3', 34),
#  ('30mg', 34),
#  ('=5', 34),
#  ('f5', 34),
#  ('win7', 34),
#  ('v4', 34),
#  ('ch3nh2', 34),
#  ('220f', 34),
#  ('p2', 34),
#  ('fat%', 34),
#  ('1c', 34),
#  ('<3', 34),
#  ('e90', 34),
#  ('s8', 33),
#  ('10gb', 33),
#  ('4b=5c', 33),
#  ('th8', 33),
#  ('x2=2x', 33),
#  ('0l', 33),
#  ('____', 33),
#  ('50mg', 33),
#  ('#weight', 33),
#  ('th9', 33),
#  ('840m', 33),
#  ('100th', 33),
#  ('c2050', 33),
#  ('1100d', 33),
#  ('7a', 33),
#  ('x2x21', 33),
#  ('vh1', 33),
#  ('|x|', 33),
#  ('|x', 33),
#  ('pc3', 33),
#  ('00=1', 33),
#  ('जवाब', 33),
#  ('payme0', 33),
#  ('8pm', 33),
#  ('7b', 33),
#  ('57%', 33),
#  ('30°', 33),
#  ('दो', 33),
#  ('m402dw', 33),
#  ('100s', 33),
#  ('a=5', 33),
#  ('25°c', 33),
#  ('pocl3', 33),
#  ('816g', 32),
#  ('<div>', 32),
#  ('200mg', 32),
#  ...]

# %%
concret_potential_problems = [item for item in potential_problems if '000' in item[0]]
sorted(concret_potential_problems, key=lambda l: -l[1])
# Out:
# [('1000', 25281),
#  ('2000', 5887),
#  ('10000', 5319),
#  ('25000', 3475),
#  ('15000', 3427),
#  ('50000', 2863),
#  ('5000', 2858),
#  ('30000', 2855),
#  ('20000', 2772),
#  ('100000', 1706),
#  ('4000', 1501),
#  ('40000', 1281),
#  ('3000', 1260),
#  ('60000', 1242),
#  ('000', 1013),
#  ('7000', 763),
#  ('8000', 675),
#  ('12000', 668),
#  ('6000', 660),
#  ('500000', 537),
#  ('35000', 477),
#  ('70000', 423),
#  ('80000', 423),
#  ('200000', 413),
#  ('150000', 305),
#  ('1000rs', 303),
#  ('11000', 281),
#  ('401000', 280),
#  ('250000', 275),
#  ('65000', 260),
#  ('18000', 257),
#  ('9000', 256),
#  ('45000', 253),
#  ('90000', 238),
#  ('2000s', 237),
#  ('a6000', 216),
#  ('300000', 203),
#  ('13000', 200),
#  ('55000', 199),
#  ('22000', 190),
#  ('16000', 187),
#  ('23000', 176),
#  ('27000', 175),
#  ('17000', 172),
#  ('14000', 161),
#  ('75000', 161),
#  ('24000', 139),
#  ('rs10000', 117),
#  ('400000', 117),
#  ('a7000', 114),
#  ('32000', 101),
#  ('800000', 97),
#  ('28000', 91),
#  ('130000', 90),
#  ('120000', 89),
#  ('25000inr', 85),
#  ('000000', 80),
#  ('350000', 77),
#  ('5001000', 75),
#  ('19000', 73),
#  ('900000', 72),
#  ('600000', 62),
#  ('30000rs', 60),
#  ('d7000', 59),
#  ('42000', 58),
#  ('450000', 57),
#  ('700000', 56),
#  ('6700000', 55),
#  ('0x80004004', 52),
#  ('85000', 52),
#  ('3000mah', 50),
#  ('43000', 50),
#  ('650000', 47),
#  ('26000', 46),
#  ('48000', 45),
#  ('31000', 45),
#  ('29000', 44),
#  ('2000rs', 44),
#  ('125000', 42),
#  ('1000000', 42),
#  ('6600000', 41),
#  ('98000', 41),
#  ('190000', 41),
#  ('180000', 40),
#  ('46000', 39),
#  ('33000', 39),
#  ('18000and', 38),
#  ('20000rs', 37),
#  ('10000mah', 37),
#  ('165000', 36),
#  ('sap2000', 34),
#  ('36000', 34),
#  ('10000rs', 34),
#  ('4790000', 31),
#  ('140000', 31),
#  ('21000', 31),
#  ('rs1000', 30),
#  ('2000inr', 28),
#  ('115000', 27),
#  ('38000', 27),
#  ('105000', 27),
#  ('rs2000', 26),
#  ('0xc000014c', 25),
#  ('50000rs', 25),
#  ('550000', 24),
#  ('49000', 24),
#  ('34000', 24),
#  ('7700000', 24),
#  ('52000', 23),
#  ('1000s', 23),
#  ('47000', 23),
#  ('37000', 23),
#  ('39000', 21),
#  ('0001', 21),
#  ('0000', 21),
#  ('0x00007b', 21),
#  ('240000', 20),
#  ('54000', 20),
#  ('160000', 20),
#  ('6000rs', 20),
#  ('62000', 20),
#  ('a6000+', 19),
#  ('170000', 19),
#  ('rs60000', 19),
#  ('187000', 18),
#  ('20000mah', 18),
#  ('u0001f614', 17),
#  ('10000000', 17),
#  ('10000inr', 17),
#  ('56000', 16),
#  ('13000mah', 16),
#  ('53000', 16),
#  ('357000', 16),
#  ('100000000', 16),
#  ('110000', 16),
#  ('0xc0000142', 15),
#  ('67000', 15),
#  ('3000000', 15),
#  ('73000', 15),
#  ('4000mah', 15),
#  ('4000rupees', 14),
#  ('1000w', 14),
#  ('u00024d13', 14),
#  ('58000', 14),
#  ('4690000', 14),
#  ('77000', 14),
#  ('59000', 14),
#  ('6000000', 13),
#  ('rs30000', 13),
#  ('106000', 13),
#  ('1000km', 13),
#  ('14000ft', 13),
#  ('formula3000', 13),
#  ('1000m', 13),
#  ('61000', 13),
#  ('1000mah', 13),
#  ('95000', 13),
#  ('2000bucks', 13),
#  ('2000v', 13),
#  ('2000mah', 13),
#  ('3000tl', 12),
#  ('1200000', 12),
#  ('94000', 12),
#  ('4770000', 12),
#  ('0x80070002', 12),
#  ('1300000', 12),
#  ('81000', 12),
#  ('0007', 12),
#  ('m2>350000', 12),
#  ('96000', 12),
#  ('200000rs', 12),
#  ('rs15000', 12),
#  ('330000', 12),
#  ('2000aud', 12),
#  ('161000', 12),
#  ('97000', 12),
#  ('for4000sq', 12),
#  ('463000', 12),
#  ('132000', 12),
#  ('m2<2500010', 12),
#  ('78000', 12),
#  ('80200053', 12),
#  ('225000', 11),
#  ('66000', 11),
#  ('0000000', 11),
#  ('6000mah', 11),
#  ('15000rs', 11),
#  ('750007', 11),
#  ('41000', 11),
#  ('1000%', 10),
#  ('1000ma', 10),
#  ('u0001f382', 10),
#  ('u0001f691', 10),
#  ('230000', 9),
#  ('at15000', 9),
#  ('64000', 9),
#  ('2000usd', 9),
#  ('65000rupees', 9),
#  ('11000inr', 9),
#  ('rm10000', 9),
#  ('135000', 8),
#  ('2500000', 8),
#  ('458000', 8),
#  ('u0001f622', 8),
#  ('rs7000', 8),
#  ('72000', 8),
#  ('1000mg', 8),
#  ('1000th', 8),
#  ('u0001f602', 8),
#  ('u0001f608', 8),
#  ('u0001f60e', 8),
#  ('1000kb', 8),
#  ('669000', 8),
#  ('136000', 8),
#  ('1000rpm', 8),
#  ('rs50000', 8),
#  ('30000ft', 8),
#  ('>2000', 7),
#  ('144000', 7),
#  ('6800000', 7),
#  ('u0001f4d5to', 7),
#  ('2000acres', 7),
#  ('880000', 7),
#  ('9000000000', 7),
#  ('0xc0000096', 7),
#  ('30000inr', 7),
#  ('17000rs', 7),
#  ('2000cal', 7),
#  ('b7000', 7),
#  ('10000inrs', 7),
#  ('b6000', 7),
#  ('5000kms', 7),
#  ('4000m', 7),
#  ('1+sqrt23000', 7),
#  ('25000ft', 7),
#  ('9000inr', 7),
#  ('117000', 7),
#  ('000337', 7),
#  ('1400000', 7),
#  ('1000mbps', 7),
#  ('lenovoa7000', 7),
#  ('1000sqft', 7),
#  ('ucm22000', 7),
#  ('1000sq', 7),
#  ('250000km', 7),
#  ('2000m', 7),
#  ('84000', 7),
#  ('8000mah', 6),
#  ('aq5000', 6),
#  ('3000km', 6),
#  ('850000', 6),
#  ('1500000', 6),
#  ('2000ft', 6),
#  ('16000mah', 6),
#  ('u0001f644', 6),
#  ('502000', 6),
#  ('0xc0000022', 6),
#  ('57000', 6),
#  ('u0001f625', 6),
#  ('155000', 6),
#  ('5000m', 6),
#  ('u0001f4e1', 6),
#  ('15000inr', 6),
#  ('3000w', 6),
#  ('0x80004005', 6),
#  ('20000hz', 6),
#  ('f6000', 6),
#  ('90000inr', 6),
#  ('475000', 6),
#  ('44000', 6),
#  ('390000', 6),
#  ('360000', 6),
#  ('000000th', 6),
#  ('rs20000', 6),
#  ('1000x', 6),
#  ('146000', 6),
#  ('10000m', 6),
#  ('186000', 6),
#  ('n1000', 6),
#  ('1650000', 6),
#  ('u0001f49b', 6),
#  ('u0001f616', 6),
#  ('aed3000', 6),
#  ('20000sqft', 6),
#  ('1000notes', 6),
#  ('2000km', 6),
#  ('2000c', 6),
#  ('u0001f639', 6),
#  ('1000bits', 6),
#  ('cdma2000', 6),
#  ('00000000000000000000', 6),
#  ('windowsupdate_80070002', 6),
#  ('87000', 6),
#  ('109000000', 6),
#  ('100000kg', 6),
#  ('10000pit', 6),
#  ('20000inr', 6),
#  ('290000', 6),
#  ('u0001f407', 6),
#  ('10000000in', 6),
#  ('7350000', 6),
#  ('1000inr', 6),
#  ('0010001101', 6),
#  ('103000', 6),
#  ('3000m', 6),
#  ('0xc000000e', 6),
#  ('50000usd', 6),
#  ('3000gt', 6),
#  ('10001000', 6),
#  ('4000<', 6),
#  ('d5000', 6),
#  ('0x80070003', 6),
#  ('22000hz', 6),
#  ('6000a', 6),
#  ('u0001f436', 6),
#  ('1000ft+', 6),
#  ('6900000', 6),
#  ('40000rs', 6),
#  ('750000', 6),
#  ('60000rs', 6),
#  ('23000in', 5),
#  ('rs22000', 5),
#  ('2000th', 5),
#  ('u0001f600', 5),
#  ('320000', 5),
#  ('fs=8000', 5),
#  ('5000kn', 5),
#  ('0x0000005c', 5),
#  ('e6000', 5),
#  ('1700000000', 5),
#  ('7000i', 5),
#  ('1000ft', 5),
#  ('122000', 5),
#  ('112000', 5),
#  ('5000inr', 5),
#  ('298000', 5),
#  ('u0001f52b', 5),
#  ('u0001f603', 5),
#  ('16000rs', 5),
#  ('loss2000', 5),
#  ('30000000', 5),
#  ('n7000', 5),
#  ('280000', 5),
#  ('128000', 5),
#  ('mixturewasmade1000ml', 5),
#  ('rpm1000', 5),
#  ('40000km', 5),
#  ('175000', 5),
#  ('74000', 5),
#  ('2000ma', 5),
#  ('0001110101', 5),
#  ('d52000', 5),
#  ('#000000', 5),
#  ('d3000', 4),
#  ('u0001f60a', 4),
#  ('u0001f61a', 4),
#  ('u0001f3fe', 4),
#  ('xt=4+2cos200pit+pi3+3sin10000pit', 4),
#  ('10001', 4),
#  ('270000', 4),
#  ('1000crores', 3),
#  ('1000mb', 3),
#  ('i9000', 3),
#  ('invest10000', 3),
#  ('2000000', 2),
#  ('800b0001', 2),
#  ('rs4000', 2),
#  ('0000000000', 2),
#  ('>1000', 2),
#  ('0xc000007b', 2),
#  ('t1000', 2),
#  ('234000', 2),
#  ('1000views', 2),
#  ('1000tkb', 2),
#  ('3000ead', 2),
#  ('203000', 2),
#  ('000webhost', 2),
#  ('93000', 2),
#  ('m4000', 2),
#  ('68000', 2),
#  ('a3000', 2),
#  ('480000', 2),
#  ('462000', 2),
#  ('127000', 2),
#  ('0xc0000225', 1),
#  ('145000', 1),
#  ('9000in', 1),
#  ('50005', 1),
#  ('pa13000', 1),
#  ('below15000', 1),
#  ('1000note', 1),
#  ('470000', 1),
#  ('40000inr', 1),
#  ('<5000', 1),
#  ('950000', 1),
#  ('u0001f352', 1),
#  ('88000', 1),
#  ('u0001f601', 1),
#  ('50000rupees', 1),
#  ('bci2000', 1),
#  ('1000v', 1),
#  ('1000cc', 1),
#  ('39000ft', 1),
#  ('dv6000', 1),
#  ('xt=4+2cos200pit+pi3+3sin10000pigautami', 1),
#  ('192000', 1),
#  ('2150000', 1),
#  ('108000', 1),
#  ('00001', 1),
#  ('k5000', 1),
#  ('fsthoughts8000', 1),
#  ('0xc00000e9', 1),
#  ('240004', 1),
#  ('8000tl', 1),
#  ('c26000', 1),
#  ('407000', 1),
#  ('15000usd', 1),
#  ('10000000000', 1),
#  ('e3000', 1),
#  ('000s', 1),
#  ('2870000', 1),
#  ('152000', 1),
#  ('3000watt', 1),
#  ('inr25000', 1),
#  ('rs90000', 1),
#  ('3570000', 1),
#  ('51000', 1),
#  ('114000', 1),
#  ('52000rs', 1),
#  ('u0001f605', 1),
#  ('0c000007b', 1),
#  ('0x0c0007', 1),
#  ('3000gbp', 1),
#  ('0000021210', 1),
#  ('32000000', 1),
#  ('720000', 1),
#  ('condition@7000', 1),
#  ('510000', 1),
#  ('5000000', 1),
#  ('216000', 1),
#  ('g1216b1n000', 1),
#  ('100110000', 1),
#  ('9170000', 1),
#  ('eu1000i', 1),
#  ('541000', 1),
#  ('6000p', 1),
#  ('2000w', 1),
#  ('in2000', 1),
#  ('u0001f914', 1),
#  ('u0001f624', 1),
#  ('82000', 1),
#  ('00000', 1),
#  ('1<=n<=5000000', 1),
#  ('0x0000605', 1),
#  ('3000cc', 1),
#  ('35000rs', 1),
#  ('600x4000', 1),
#  ('rs25000', 1),
#  ('500000rs', 1),
#  ('0xc00007b', 1),
#  ('u0001f193', 1),
#  ('275000', 1),
#  ('63000', 1),
#  ('233000', 1),
#  ('577000', 1),
#  ('5000sqft', 1),
#  ('x3000', 1),
#  ('rs5000', 1),
#  ('5000hp', 1),
#  ('210000', 1),
#  ('u0001f629', 1),
#  ('inr20000', 1),
#  ('u0001f4a3', 1),
#  ('1000p', 1),
#  ('35000ft', 1),
#  ('100002', 1),
#  ('5000rmb', 1),
#  ('3000th', 1),
#  ('220000', 1),
#  ('5000tl', 1),
#  ('10002', 1),
#  ('usd2000', 1),
#  ('83000', 1),
#  ('3000rpm', 1),
#  ('q84000', 1),
#  ('under50000', 1),
#  ('0002', 1),
#  ('r2000', 1),
#  ('00000074', 1),
#  ('7000rpm', 1),
#  ('r1000', 1),
#  ('xt=4+2cos200pit+pi3+sin10000pit', 1),
#  ('207000', 1),
#  ('00000000', 1),
#  ('102000', 1),
#  ('1900000', 1),
#  ('0000001', 1),
#  ('35000rupees', 1)]

# %%
for q1, q2, is_duplicate in train_set[['question1', 'question2', 'is_duplicate']].values:
    if is_duplicate:
        tokens_q1 = text_tokenization(q1)
        tokens_q2 = text_tokenization(q2)
        if '$' in tokens_q1 or '$' in tokens_q2:
            print(q1)
            print(q2)
            print(tokens_q1)
            print(tokens_q2)
            print('\n\n\n')
# Out:
# What is the easiest way to become a billionaire($)?
# What is the best way to become a billionaire?
# ['what', 'is', 'the', 'easiest', 'way', 'to', 'become', 'a', 'billionaire', '$']
# ['what', 'is', 'the', 'best', 'way', 'to', 'become', 'a', 'billionaire']
#
#
#
#
# How comfortably can I live in Washington DC on a $80,000 salary?
# Can I live comfortably in DC on $80,000 - $114,000 salary?
# ['how', 'comfortably', 'can', 'i', 'live', 'in', 'washington', 'dc', 'on', 'a', '$', '80000', 'salary']
# ['can', 'i', 'live', 'comfortably', 'in', 'dc', 'on', '$', '80000', '$', '114000', 'salary']
#
#
#
#
# Why, or why not, should the minimum wage be raised to $15?
# Should the minimum wage be raised to $15/hr for all American workers?
# ['why', 'or', 'why', 'not', 'should', 'the', 'minimum', 'wage', 'be', 'raised', 'to', '$', '15']
# ['should', 'the', 'minimum', 'wage', 'be', 'raised', 'to', '$', '15', 'hr', 'for', 'all', 'american', 'workers']
#
#
#
#
# I want a real and effective way to make $ 500 per month with the knowledge that I have no money to invest?
# The real effective way to make $ 500 per month with the knowledge that I have no money to invest?
# ['i', 'want', 'a', 'real', 'and', 'effective', 'way', 'to', 'make', '$', '500', 'per', 'month', 'with', 'the', 'knowledge', 'that', 'i', 'have', 'no', 'money', 'to', 'invest']
# ['the', 'real', 'effective', 'way', 'to', 'make', '$', '500', 'per', 'month', 'with', 'the', 'knowledge', 'that', 'i', 'have', 'no', 'money', 'to', 'invest']
#
#
#
#
# When will oil prices go up to $60,$70 or back to normal?
# When will oil prices go up to $60-$70 or back to normal?
# ['when', 'will', 'oil', 'prices', 'go', 'up', 'to', '$', '60', '$', '70', 'or', 'back', 'to', 'normal']
# ['when', 'will', 'oil', 'prices', 'go', 'up', 'to', '$', '60', '$', '70', 'or', 'back', 'to', 'normal']
#
#
#
#
# How do I make an extra $ 500 a week?
# How can I make an extra $500 per week?
# ['how', 'do', 'i', 'make', 'an', 'extra', '$', '500', 'a', 'week']
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '500', 'per', 'week']
#
#
#
#
# When will oil prices be up to $60?
# Will oil prices go back up?
# ['when', 'will', 'oil', 'prices', 'be', 'up', 'to', '$', '60']
# ['will', 'oil', 'prices', 'go', 'back', 'up']
#
#
#
#
# What are the best earphones under 60$?
# What are some good earphones for under $60?
# ['what', 'are', 'the', 'best', 'earphones', 'under', '60', '$']
# ['what', 'are', 'some', 'good', 'earphones', 'for', 'under', '$', '60']
#
#
#
#
# How much can I spend on rent in Manhattan if my yearly salary is $1 million?
# How much can I spend on rent if I make $350k a year in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan', 'if', 'my', 'yearly', 'salary', 'is', '$', '1', 'million']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'if', 'i', 'make', '$', '350000', 'a', 'year', 'in', 'manhattan']
#
#
#
#
# On what evidence does Ted Cruz claim that the Iran nuclear deal will give billions of dollars to Iran?
# Why does the Iran nuclear deal give Iran $150 billion?
# ['on', 'what', 'evidence', 'does', 'ted', 'cruz', 'claim', 'that', 'the', 'iran', 'nuclear', 'deal', 'will', 'give', 'billions', 'of', 'dollars', 'to', 'iran']
# ['why', 'does', 'the', 'iran', 'nuclear', 'deal', 'give', 'iran', '$', '150', 'billion']
#
#
#
#
# Do you guys believe in teaching kids about money at early age? If yes, why? Is there consequences to teach kids about $ at early age? What are they.
# Do you guys believe in teaching kids about money at early age? If yes, why? Is there consequences to teach kids about $ at early age? What are they?
# ['do', 'you', 'guys', 'believe', 'in', 'teaching', 'kids', 'about', 'money', 'at', 'early', 'age', 'if', 'yes', 'why', 'is', 'there', 'consequences', 'to', 'teach', 'kids', 'about', '$', 'at', 'early', 'age', 'what', 'are', 'they']
# ['do', 'you', 'guys', 'believe', 'in', 'teaching', 'kids', 'about', 'money', 'at', 'early', 'age', 'if', 'yes', 'why', 'is', 'there', 'consequences', 'to', 'teach', 'kids', 'about', '$', 'at', 'early', 'age', 'what', 'are', 'they']
#
#
#
#
# What business can I start with £5000?
# What business can I start with $5000 capital in cash?
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '5000']
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '5000', 'capital', 'in', 'cash']
#
#
#
#
# If you had to entirely spend $10 billion in 30 days in order to be given $100 billion, how would you do it?
# If you had a billion dollars, what would you do with it?
# ['if', 'you', 'had', 'to', 'entirely', 'spend', '$', '10', 'billion', 'in', '30', 'days', 'in', 'order', 'to', 'be', 'given', '$', '100', 'billion', 'how', 'would', 'you', 'do', 'it']
# ['if', 'you', 'had', 'a', 'billion', 'dollars', 'what', 'would', 'you', 'do', 'with', 'it']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# What are ways I can make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['what', 'are', 'ways', 'i', 'can', 'make', 'money', 'online']
#
#
#
#
# Where should I invest $300k in Canada?
# Where should I invest $250k in Canada?
# ['where', 'should', 'i', 'invest', '$', '300000', 'in', 'canada']
# ['where', 'should', 'i', 'invest', '$', '250000', 'in', 'canada']
#
#
#
#
# How can I make 100 dollars a day?
# How do I make $100 a day?
# ['how', 'can', 'i', 'make', '100', 'dollars', 'a', 'day']
# ['how', 'do', 'i', 'make', '$', '100', 'a', 'day']
#
#
#
#
# What's the best way to make money with $2,000?
# What's a good way to make money with $2,000?
# ['what', 'is', 'the', 'best', 'way', 'to', 'make', 'money', 'with', '$', '2000']
# ['what', 'is', 'a', 'good', 'way', 'to', 'make', 'money', 'with', '$', '2000']
#
#
#
#
# Can a family live comfortable on $450,000 a year in New York City?
# Can a family have a luxurious life in New York City with a yearly income of $450,000?
# ['can', 'a', 'family', 'live', 'comfortable', 'on', '$', '450000', 'a', 'year', 'in', 'new', 'york', 'city']
# ['can', 'a', 'family', 'have', 'a', 'luxurious', 'life', 'in', 'new', 'york', 'city', 'with', 'a', 'yearly', 'income', 'of', '$', '450000']
#
#
#
#
# How do I make $500 a week?
# How do I make an extra $ 500 a week?
# ['how', 'do', 'i', 'make', '$', '500', 'a', 'week']
# ['how', 'do', 'i', 'make', 'an', 'extra', '$', '500', 'a', 'week']
#
#
#
#
# Which business should I start with 50000 Rupees in India?
# If you had 50000 INR (750$) , what business you would start?
# ['which', 'business', 'should', 'i', 'start', 'with', '50000', 'rupees', 'in', 'india']
# ['if', 'you', 'had', '50000', 'inr', '750', '$', 'what', 'business', 'you', 'would', 'start']
#
#
#
#
# Can I start investing in stock market with $100 only?
# Can I start investing in stocks with $100?
# ['can', 'i', 'start', 'investing', 'in', 'stock', 'market', 'with', '$', '100', 'only']
# ['can', 'i', 'start', 'investing', 'in', 'stocks', 'with', '$', '100']
#
#
#
#
# How much can I spend on rent making $1 million a year in Manhattan?
# How much can I spend on rent in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'making', '$', '1', 'million', 'a', 'year', 'in', 'manhattan']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan']
#
#
#
#
# What is the quickest way to make money?
# What is the quickest way to make $8,000?
# ['what', 'is', 'the', 'quickest', 'way', 'to', 'make', 'money']
# ['what', 'is', 'the', 'quickest', 'way', 'to', 'make', '$', '8000']
#
#
#
#
# How do I make $500 a week?
# How can I make an extra $500 per week?
# ['how', 'do', 'i', 'make', '$', '500', 'a', 'week']
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '500', 'per', 'week']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# Which is the best laptop I should buy under Rs.60000?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['which', 'is', 'the', 'best', 'laptop', 'i', 'should', 'buy', 'under', 'rs', '60000']
#
#
#
#
# How much is one million in rupees?
# How much is $1 million in Indian rupees?
# ['how', 'much', 'is', 'one', 'million', 'in', 'rupees']
# ['how', 'much', 'is', '$', '1', 'million', 'in', 'indian', 'rupees']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# Can I make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['can', 'i', 'make', 'money', 'online']
#
#
#
#
# What is the fastest way to make $30,000?
# What's the fastest way to make $30,000?
# ['what', 'is', 'the', 'fastest', 'way', 'to', 'make', '$', '30000']
# ['what', 'is', 'the', 'fastest', 'way', 'to', 'make', '$', '30000']
#
#
#
#
# Was Microsoft bamboozled into paying $1.2 Billion for Yammer?
# Did Microsoft pay too much for Yammer?
# ['was', 'microsoft', 'bamboozled', 'into', 'paying', '$', '1', '2', 'billion', 'for', 'yammer']
# ['did', 'microsoft', 'pay', 'too', 'much', 'for', 'yammer']
#
#
#
#
# What are the best in the ear headphones under 2000?
# What is the best in-ear headphones under $2K?
# ['what', 'are', 'the', 'best', 'in', 'the', 'ear', 'headphones', 'under', '2000']
# ['what', 'is', 'the', 'best', 'in', 'ear', 'headphones', 'under', '$', '2000']
#
#
#
#
# I wrote a letter, asking for donations from companies and philanthropist to help pay off $100,000 private student loan debt. Where should I send it?
# I wrote a letter, asking companies and philanthropists to help pay off $100,000 in private student loan debt. Where should I send it?
# ['i', 'wrote', 'a', 'letter', 'asking', 'for', 'donations', 'from', 'companies', 'and', 'philanthropist', 'to', 'help', 'pay', 'off', '$', '100000', 'private', 'student', 'loan', 'debt', 'where', 'should', 'i', 'send', 'it']
# ['i', 'wrote', 'a', 'letter', 'asking', 'companies', 'and', 'philanthropists', 'to', 'help', 'pay', 'off', '$', '100000', 'in', 'private', 'student', 'loan', 'debt', 'where', 'should', 'i', 'send', 'it']
#
#
#
#
# What are the best headphones that I can buy within Rs 3000/$45?
# Which is the best headphone under Rs 3000?
# ['what', 'are', 'the', 'best', 'headphones', 'that', 'i', 'can', 'buy', 'within', 'rs', '3000', '$', '45']
# ['which', 'is', 'the', 'best', 'headphone', 'under', 'rs', '3000']
#
#
#
#
# How can I make an extra $1000 a month?
# How can I make an extra $2000 this month?
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '1000', 'a', 'month']
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '2000', 'this', 'month']
#
#
#
#
# Did Hillary get $12 million from the King of Morocco?
# Is the news that Hillary Clinton wanted to speak at a meeting in Morocco in 2015 for a $12 million commitment from the king an example of pay to play?
# ['did', 'hillary', 'get', '$', '12', 'million', 'from', 'the', 'king', 'of', 'morocco']
# ['is', 'the', 'news', 'that', 'hillary', 'clinton', 'wanted', 'to', 'speak', 'at', 'a', 'meeting', 'in', 'morocco', 'in', '2015', 'for', 'a', '$', '12', 'million', 'commitment', 'from', 'the', 'king', 'an', 'example', 'of', 'pay', 'to', 'play']
#
#
#
#
# Can I make $US 100,000 a month betting on horses?
# Can I make 400,000 a month betting on horses?
# ['can', 'i', 'make', '$', 'us', '100000', 'a', 'month', 'betting', 'on', 'horses']
# ['can', 'i', 'make', '400000', 'a', 'month', 'betting', 'on', 'horses']
#
#
#
#
# When will oil prices go up to $60,$70 or back to normal?
# When will oil prices be up to $60?
# ['when', 'will', 'oil', 'prices', 'go', 'up', 'to', '$', '60', '$', '70', 'or', 'back', 'to', 'normal']
# ['when', 'will', 'oil', 'prices', 'be', 'up', 'to', '$', '60']
#
#
#
#
# Is a family considered wealthy having $1,000,000 in New York City?
# Is a family considered rich in New York City being worth $1 Million?
# ['is', 'a', 'family', 'considered', 'wealthy', 'having', '$', '1000', '000', 'in', 'new', 'york', 'city']
# ['is', 'a', 'family', 'considered', 'rich', 'in', 'new', 'york', 'city', 'being', 'worth', '$', '1', 'million']
#
#
#
#
# Why would China want to invest $42bn in Pakistan?
# Why is China investing in Pakistan?
# ['why', 'would', 'china', 'want', 'to', 'invest', '$', '42bn', 'in', 'pakistan']
# ['why', 'is', 'china', 'investing', 'in', 'pakistan']
#
#
#
#
# How can I make $300 a week online?
# How can I make $300 fast online in a week?
# ['how', 'can', 'i', 'make', '$', '300', 'a', 'week', 'online']
# ['how', 'can', 'i', 'make', '$', '300', 'fast', 'online', 'in', 'a', 'week']
#
#
#
#
# How can we start a business with $100?
# How do I start new business with $100?
# ['how', 'can', 'we', 'start', 'a', 'business', 'with', '$', '100']
# ['how', 'do', 'i', 'start', 'new', 'business', 'with', '$', '100']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# Which is the best laptop under 60k in india?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['which', 'is', 'the', 'best', 'laptop', 'under', '60000', 'in', 'india']
#
#
#
#
# What is the best way to invest $500k?
# What is the best way to invest $500K in 2016?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '500000']
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '500000', 'in', '2016']
#
#
#
#
# What is the best way to invest $100?
# What is the best way to invest 100$?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '100']
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '100', '$']
#
#
#
#
# What is the best way to invest $500?
# What is the best investment to make with $500?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '500']
# ['what', 'is', 'the', 'best', 'investment', 'to', 'make', 'with', '$', '500']
#
#
#
#
# I found an Instagram page that is selling the iPhone 6 for $300 and is accepting PayPal. Is this a scam? How can I get scammed in this situation?
# Found an Instagram page that is selling the iPhone 6 for $300 and is accepting PayPal. Is this a scam? How can I get scammed in this situation?
# ['i', 'found', 'an', 'instagram', 'page', 'that', 'is', 'selling', 'the', 'iphone', '6', 'for', '$', '300', 'and', 'is', 'accepting', 'paypal', 'is', 'this', 'a', 'scam', 'how', 'can', 'i', 'get', 'scammed', 'in', 'this', 'situation']
# ['found', 'an', 'instagram', 'page', 'that', 'is', 'selling', 'the', 'iphone', '6', 'for', '$', '300', 'and', 'is', 'accepting', 'paypal', 'is', 'this', 'a', 'scam', 'how', 'can', 'i', 'get', 'scammed', 'in', 'this', 'situation']
#
#
#
#
# How did Donald Trump earn $4.5 billion?
# How did Donald Trump get so rich?
# ['how', 'did', 'donald', 'trump', 'earn', '$', '4', '5', 'billion']
# ['how', 'did', 'donald', 'trump', 'get', 'so', 'rich']
#
#
#
#
# A hammer and a nail cost $1.10, and the hammer costs one dollar more than the nail. How much does the nail cost?
# A bat and ball cost $1.10. The bat costs one dollar more than the ball. How much does the ball cost?
# ['a', 'hammer', 'and', 'a', 'nail', 'cost', '$', '1', '10', 'and', 'the', 'hammer', 'costs', 'one', 'dollar', 'more', 'than', 'the', 'nail', 'how', 'much', 'does', 'the', 'nail', 'cost']
# ['a', 'bat', 'and', 'ball', 'cost', '$', '1', '10', 'the', 'bat', 'costs', 'one', 'dollar', 'more', 'than', 'the', 'ball', 'how', 'much', 'does', 'the', 'ball', 'cost']
#
#
#
#
# Why would China want to invest $42bn in Pakistan?
# Why has China become so obsessed with investing in Pakistan?
# ['why', 'would', 'china', 'want', 'to', 'invest', '$', '42bn', 'in', 'pakistan']
# ['why', 'has', 'china', 'become', 'so', 'obsessed', 'with', 'investing', 'in', 'pakistan']
#
#
#
#
# What is the outcome of a $15 minimum wage in the U.S.?
# What effect would increasing the minimum wage have on the US economy?
# ['what', 'is', 'the', 'outcome', 'of', 'a', '$', '15', 'minimum', 'wage', 'in', 'the', 'u', 's']
# ['what', 'effect', 'would', 'increasing', 'the', 'minimum', 'wage', 'have', 'on', 'the', 'us', 'economy']
#
#
#
#
# What would the impact of a $15.00 minimum wage be?
# Economics: What are the pros and cons of raising the minimum wage in the US?
# ['what', 'would', 'the', 'impact', 'of', 'a', '$', '15', '00', 'minimum', 'wage', 'be']
# ['economics', 'what', 'are', 'the', 'pros', 'and', 'cons', 'of', 'raising', 'the', 'minimum', 'wage', 'in', 'the', 'us']
#
#
#
#
# Can I make $US 100,000 a month betting on horses?
# Can I make 30,000 a month betting on horses?
# ['can', 'i', 'make', '$', 'us', '100000', 'a', 'month', 'betting', 'on', 'horses']
# ['can', 'i', 'make', '30000', 'a', 'month', 'betting', 'on', 'horses']
#
#
#
#
# What are the best laptops to buy within Rs.30000 or $485 and why?
# Which laptop is best to buy within the range of 30000rs?
# ['what', 'are', 'the', 'best', 'laptops', 'to', 'buy', 'within', 'rs', '30000', 'or', '$', '485', 'and', 'why']
# ['which', 'laptop', 'is', 'best', 'to', 'buy', 'within', 'the', 'range', 'of', '30000rs']
#
#
#
#
# What business can I start with $100?
# What lucrative business can I start with $100?
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '100']
# ['what', 'lucrative', 'business', 'can', 'i', 'start', 'with', '$', '100']
#
#
#
#
# What is a best gaming laptop below $700?
# What's the best gaming laptop under $700?
# ['what', 'is', 'a', 'best', 'gaming', 'laptop', 'below', '$', '700']
# ['what', 'is', 'the', 'best', 'gaming', 'laptop', 'under', '$', '700']
#
#
#
#
# How do I make $1000 extra dollars?
# How do I make $1000 as extra income/month apart from the regular job?
# ['how', 'do', 'i', 'make', '$', '1000', 'extra', 'dollars']
# ['how', 'do', 'i', 'make', '$', '1000', 'as', 'extra', 'income', 'month', 'apart', 'from', 'the', 'regular', 'job']
#
#
#
#
# Can I start investing in stocks with $100?
# How can I start investing in stocks with only $100, and what platforms would you recommend?
# ['can', 'i', 'start', 'investing', 'in', 'stocks', 'with', '$', '100']
# ['how', 'can', 'i', 'start', 'investing', 'in', 'stocks', 'with', 'only', '$', '100', 'and', 'what', 'platforms', 'would', 'you', 'recommend']
#
#
#
#
# What is the best graphics tablet I can get for around $100?
# What's the best graphics tablet under $100?
# ['what', 'is', 'the', 'best', 'graphics', 'tablet', 'i', 'can', 'get', 'for', 'around', '$', '100']
# ['what', 'is', 'the', 'best', 'graphics', 'tablet', 'under', '$', '100']
# What is the best laptop under 60k(900$ approx)?
# What is the best laptop under 60000 Indian Rupees?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', 'indian', 'rupees']
#
#
#
#
# What’s the best used car for under 7000?
# What's the best used car I can buy for max $7000?
# ['what', 'is', 'the', 'best', 'used', 'car', 'for', 'under', '7000']
# ['what', 'is', 'the', 'best', 'used', 'car', 'i', 'can', 'buy', 'for', 'max', '$', '7000']
#
#
#
#
# What's the best gaming laptop under $2000?
# Which one is the best gaming laptop under 2000$?
# ['what', 'is', 'the', 'best', 'gaming', 'laptop', 'under', '$', '2000']
# ['which', 'one', 'is', 'the', 'best', 'gaming', 'laptop', 'under', '2000', '$']
#
#
#
#
# What is the value of a 1935 1 dollar silver certificate?
# What's the value of a Series 1935 E $1 Silver Certificate?
# ['what', 'is', 'the', 'value', 'of', 'a', '1935', '1', 'dollar', 'silver', 'certificate']
# ['what', 'is', 'the', 'value', 'of', 'a', 'series', '1935', 'e', '$', '1', 'silver', 'certificate']
#
#
#
#
# Which is the best laptop to buy for rs. 60000?
# What is the best laptop under 60k(900$ approx)?
# ['which', 'is', 'the', 'best', 'laptop', 'to', 'buy', 'for', 'rs', '60000']
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
#
#
#
#
# What is the best tablet under $200?
# Which is the best tablet for media under 200$?
# ['what', 'is', 'the', 'best', 'tablet', 'under', '$', '200']
# ['which', 'is', 'the', 'best', 'tablet', 'for', 'media', 'under', '200', '$']
#
#
#
#
# I have a laptop and internet . How do I make money with just these items?
# I have a laptop, internet, and $35 in cash. How can I start making money with just these items?
# ['i', 'have', 'a', 'laptop', 'and', 'internet', 'how', 'do', 'i', 'make', 'money', 'with', 'just', 'these', 'items']
# ['i', 'have', 'a', 'laptop', 'internet', 'and', '$', '35', 'in', 'cash', 'how', 'can', 'i', 'start', 'making', 'money', 'with', 'just', 'these', 'items']
#
#
#
#
# What would the impact of a $15.00 minimum wage be?
# What is the economic impact of increasing the minimum wage?
# ['what', 'would', 'the', 'impact', 'of', 'a', '$', '15', '00', 'minimum', 'wage', 'be']
# ['what', 'is', 'the', 'economic', 'impact', 'of', 'increasing', 'the', 'minimum', 'wage']
#
#
#
#
# Can Pakistan's GDP hit 1 trillion by 2030?
# Pakistan's GDP (PPP) has just crossed the $1 trillion mark, what should the next realistic target be?
# ['can', 'pakistan', 'gdp', 'hit', '1', 'trillion', 'by', '2030']
# ['pakistan', 'gdp', 'ppp', 'has', 'just', 'crossed', 'the', '$', '1', 'trillion', 'mark', 'what', 'should', 'the', 'next', 'realistic', 'target', 'be']
#
#
#
#
# Why does a B-2 bomber cost 20x that of a typical stealth fighter?
# A single B-2 stealth bomber costs about $1 billion. How is this possible?
# ['why', 'does', 'a', 'b', '2', 'bomber', 'cost', '20x', 'that', 'of', 'a', 'typical', 'stealth', 'fighter']
# ['a', 'single', 'b', '2', 'stealth', 'bomber', 'costs', 'about', '$', '1', 'billion', 'how', 'is', 'this', 'possible']
#
#
#
#
# Which is the best laptop to purchase under INR 60K?
# What is the best laptop under 60k(900$ approx)?
# ['which', 'is', 'the', 'best', 'laptop', 'to', 'purchase', 'under', 'inr', '60000']
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
#
#
#
#
# Why does Hillary Clinton claim to be so feminist and yet pay your women staff less than men?
# How can Hillary Clinton advocate for equal pay, when the Clinton Foundation pays women an average of $80,000 less than men?
# ['why', 'does', 'hillary', 'clinton', 'claim', 'to', 'be', 'so', 'feminist', 'and', 'yet', 'pay', 'your', 'women', 'staff', 'less', 'than', 'men']
# ['how', 'can', 'hillary', 'clinton', 'advocate', 'for', 'equal', 'pay', 'when', 'the', 'clinton', 'foundation', 'pays', 'women', 'an', 'average', 'of', '$', '80000', 'less', 'than', 'men']
#
#
#
#
# What business should I start with a $100k investment?
# What is the best business to start with 5 lakhs?
# ['what', 'business', 'should', 'i', 'start', 'with', 'a', '$', '100000', 'investment']
# ['what', 'is', 'the', 'best', 'business', 'to', 'start', 'with', '5', 'lakhs']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# Which is the best laptop below rs60000?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['which', 'is', 'the', 'best', 'laptop', 'below', 'rs60000']
#
#
#
#
# How can I make every day $10 online?
# How can I make 10 dollars a day online?
# ['how', 'can', 'i', 'make', 'every', 'day', '$', '10', 'online']
# ['how', 'can', 'i', 'make', '10', 'dollars', 'a', 'day', 'online']
#
#
#
#
# What business can I start with INR 50000 rs?
# If you had 50000 INR (750$) , what business you would start?
# ['what', 'business', 'can', 'i', 'start', 'with', 'inr', '50000', 'rs']
# ['if', 'you', 'had', '50000', 'inr', '750', '$', 'what', 'business', 'you', 'would', 'start']
#
#
#
#
# What is the best laptop within 60k available in India?
# What is the best laptop under 60k(900$ approx)?
# ['what', 'is', 'the', 'best', 'laptop', 'within', '60000', 'available', 'in', 'india']
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
#
#
#
#
# How can I realistically make money online?
# Am not starting big? How can I make $1000 per month online?
# ['how', 'can', 'i', 'realistically', 'make', 'money', 'online']
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
#
#
#
#
# How can I turn $600 into $6000?
# What are some ways I can turn $600 into $6000?
# ['how', 'can', 'i', 'turn', '$', '600', 'into', '$', '6000']
# ['what', 'are', 'some', 'ways', 'i', 'can', 'turn', '$', '600', 'into', '$', '6000']
#
#
#
#
# Best acoustic guitars under $300?  Best under $500?
# What is the best acoustic guitar under $500?
# ['best', 'acoustic', 'guitars', 'under', '$', '300', 'best', 'under', '$', '500']
# ['what', 'is', 'the', 'best', 'acoustic', 'guitar', 'under', '$', '500']
#
#
#
#
# Can I ask a billionaire or a millionaire to lend me at least US$100,000?
# How can I ask a billionaire to spare me at least half a million dollars?
# ['can', 'i', 'ask', 'a', 'billionaire', 'or', 'a', 'millionaire', 'to', 'lend', 'me', 'at', 'least', 'us', '$', '100000']
# ['how', 'can', 'i', 'ask', 'a', 'billionaire', 'to', 'spare', 'me', 'at', 'least', 'half', 'a', 'million', 'dollars']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# Which is the best laptop available in India in a budget of 60k?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['which', 'is', 'the', 'best', 'laptop', 'available', 'in', 'india', 'in', 'a', 'budget', 'of', '60000']
#
#
#
#
# What would the impact of a $15.00 minimum wage be?
# What are your thoughts about the minimum wage increase?
# ['what', 'would', 'the', 'impact', 'of', 'a', '$', '15', '00', 'minimum', 'wage', 'be']
# ['what', 'are', 'your', 'thoughts', 'about', 'the', 'minimum', 'wage', 'increase']
#
#
#
#
# What are the best laptops to buy within Rs.30000 or $485 and why?
# Which is the best laptop model to buy within 30k?
# ['what', 'are', 'the', 'best', 'laptops', 'to', 'buy', 'within', 'rs', '30000', 'or', '$', '485', 'and', 'why']
# ['which', 'is', 'the', 'best', 'laptop', 'model', 'to', 'buy', 'within', '30000']
#
#
#
#
# Would the founder/CEO of 5 employee commercial RE firm be doing pretty well if they brokered 25 deals their 1st year totaling $55 million?
# Would the founder/CEO of 5 employee commercial RE firm be doing pretty well if they brokered 25 deals their 1st year totaling $50 million in sales?
# ['would', 'the', 'founder', 'ceo', 'of', '5', 'employee', 'commercial', 're', 'firm', 'be', 'doing', 'pretty', 'well', 'if', 'they', 'brokered', '25', 'deals', 'their', '1st', 'year', 'totaling', '$', '55', 'million']
# ['would', 'the', 'founder', 'ceo', 'of', '5', 'employee', 'commercial', 're', 'firm', 'be', 'doing', 'pretty', 'well', 'if', 'they', 'brokered', '25', 'deals', 'their', '1st', 'year', 'totaling', '$', '50', 'million', 'in', 'sales']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# Which is the best laptop under INR 60k?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['which', 'is', 'the', 'best', 'laptop', 'under', 'inr', '60000']
#
#
#
#
# What is the best way to invest $300,000?
# What's the best way to invest $300,000?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '300000']
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '300000']
#
#
#
#
# What business would/could you start right now with $100?
# How can we start a business with $100?
# ['what', 'business', 'would', 'could', 'you', 'start', 'right', 'now', 'with', '$', '100']
# ['how', 'can', 'we', 'start', 'a', 'business', 'with', '$', '100']
#
#
#
#
# What can I do to make $2000 in one week?
# How do I make $2000 a week?
# ['what', 'can', 'i', 'do', 'to', 'make', '$', '2000', 'in', 'one', 'week']
# ['how', 'do', 'i', 'make', '$', '2000', 'a', 'week']
#
#
#
#
# How can you make 1 billion dollars in a year with no money?
# How do I make $1 billion in a year?
# ['how', 'can', 'you', 'make', '1', 'billion', 'dollars', 'in', 'a', 'year', 'with', 'no', 'money']
# ['how', 'do', 'i', 'make', '$', '1', 'billion', 'in', 'a', 'year']
# What business can I start up with $10,000?
# What business can I start with $10,000?
# ['what', 'business', 'can', 'i', 'start', 'up', 'with', '$', '10000']
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '10000']
#
#
#
#
# If the integers a,b are coprime, then does it follow that for any positive integers $a^l$ and $b^m$ are coprime as well?
# If the integers a,b are coprime, then does it follow that for any positive integers, [math]a^l[/math] and [math]b^m[/math] are coprime as well?
# ['if', 'the', 'integers', 'a', 'b', 'are', 'coprime', 'then', 'does', 'it', 'follow', 'that', 'for', 'any', 'positive', 'integers', '$', 'al', '$', 'and', '$', 'bm', '$', 'are', 'coprime', 'as', 'well']
# ['if', 'the', 'integers', 'a', 'b', 'are', 'coprime', 'then', 'does', 'it', 'follow', 'that', 'for', 'any', 'positive', 'integers', 'al', 'and', 'bm', 'are', 'coprime', 'as', 'well']
#
#
#
#
# How can I make $200 a day?
# How do I make $200 a day?
# ['how', 'can', 'i', 'make', '$', '200', 'a', 'day']
# ['how', 'do', 'i', 'make', '$', '200', 'a', 'day']
#
#
#
#
# Would the founder/CEO of a new/small realestate firm that did 25 broker deals this year totaling $55 million be making over 300k? What is his salary?
# Would the founder/CEO of 5 employee commercial RE firm be doing pretty well if they brokered 25 deals their 1st year totaling $50 million in sales?
# ['would', 'the', 'founder', 'ceo', 'of', 'a', 'new', 'small', 'realestate', 'firm', 'that', 'did', '25', 'broker', 'deals', 'this', 'year', 'totaling', '$', '55', 'million', 'be', 'making', 'over', '300000', 'what', 'is', 'his', 'salary']
# ['would', 'the', 'founder', 'ceo', 'of', '5', 'employee', 'commercial', 're', 'firm', 'be', 'doing', 'pretty', 'well', 'if', 'they', 'brokered', '25', 'deals', 'their', '1st', 'year', 'totaling', '$', '50', 'million', 'in', 'sales']
#
#
#
#
# How do I invest 1000$ in the stock market?
# How do I invest $1000 in the stock market?
# ['how', 'do', 'i', 'invest', '1000', '$', 'in', 'the', 'stock', 'market']
# ['how', 'do', 'i', 'invest', '$', '1000', 'in', 'the', 'stock', 'market']
#
#
#
#
# What should I do with $10000?
# What should I do with my $10000?
# ['what', 'should', 'i', 'do', 'with', '$', '10000']
# ['what', 'should', 'i', 'do', 'with', 'my', '$', '10000']
#
#
#
#
# How can I make an extra $2000 this month?
# What can I do to make an extra $1000?
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '2000', 'this', 'month']
# ['what', 'can', 'i', 'do', 'to', 'make', 'an', 'extra', '$', '1000']
#
#
#
#
# How can I make 1000$ per day online?
# How do I make $1000 a day online?
# ['how', 'can', 'i', 'make', '1000', '$', 'per', 'day', 'online']
# ['how', 'do', 'i', 'make', '$', '1000', 'a', 'day', 'online']
#
#
#
#
# I saw a shirt for $97. I borrowed $50 from mom and $50 from dad. I bought the shirt with $3 of change. I gave $1 to mom, $1 to dad, and kept $1 for myself. Now I owe my mom $49 and my dad $49. $49+ $49=$98+my $1=$99. Where did the other $1 go?
# I borrowed $50 from mum and $50 from dad to buy a bag costing $97. After the purchase, I had $3 left. I returned $1 to dad and $1 to mum, and reserved $1 for myself. I now owe $49+$49=$98 plus the $1 I reserved for myself, which is $99. Where is the missing $1?
# ['i', 'saw', 'a', 'shirt', 'for', '$', '97', 'i', 'borrowed', '$', '50', 'from', 'mom', 'and', '$', '50', 'from', 'dad', 'i', 'bought', 'the', 'shirt', 'with', '$', '3', 'of', 'change', 'i', 'gave', '$', '1', 'to', 'mom', '$', '1', 'to', 'dad', 'and', 'kept', '$', '1', 'for', 'myself', 'now', 'i', 'owe', 'my', 'mom', '$', '49', 'and', 'my', 'dad', '$', '49', '$', '49', '$', '49=', '$', '98+my', '$', '1=', '$', '99', 'where', 'did', 'the', 'other', '$', '1', 'go']
# ['i', 'borrowed', '$', '50', 'from', 'mum', 'and', '$', '50', 'from', 'dad', 'to', 'buy', 'a', 'bag', 'costing', '$', '97', 'after', 'the', 'purchase', 'i', 'had', '$', '3', 'left', 'i', 'returned', '$', '1', 'to', 'dad', 'and', '$', '1', 'to', 'mum', 'and', 'reserved', '$', '1', 'for', 'myself', 'i', 'now', 'owe', '$', '49', '$', '49=', '$', '98', 'plus', 'the', '$', '1', 'i', 'reserved', 'for', 'myself', 'which', 'is', '$', '99', 'where', 'is', 'the', 'missing', '$', '1']
#
#
#
#
# How much can I spend on rent making $1 million a year in Manhattan?
# How much can I spend on rent making $144k a year in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'making', '$', '1', 'million', 'a', 'year', 'in', 'manhattan']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'making', '$', '144000', 'a', 'year', 'in', 'manhattan']
#
#
#
#
# Would the founder/CEO of a new/small realestate firm that did 25 broker deals this year totaling $55 million be making over 300k? What is his salary?
# Would the founder/CEO of 5 employee commercial RE firm be doing pretty well if they brokered 25 deals their 1st year totaling $55 million?
# ['would', 'the', 'founder', 'ceo', 'of', 'a', 'new', 'small', 'realestate', 'firm', 'that', 'did', '25', 'broker', 'deals', 'this', 'year', 'totaling', '$', '55', 'million', 'be', 'making', 'over', '300000', 'what', 'is', 'his', 'salary']
# ['would', 'the', 'founder', 'ceo', 'of', '5', 'employee', 'commercial', 're', 'firm', 'be', 'doing', 'pretty', 'well', 'if', 'they', 'brokered', '25', 'deals', 'their', '1st', 'year', 'totaling', '$', '55', 'million']
#
#
#
#
# How do I make a million dollars in 24hours?
# Can you give me a way to make $1 million in a single day?
# ['how', 'do', 'i', 'make', 'a', 'million', 'dollars', 'in', '24hours']
# ['can', 'you', 'give', 'me', 'a', 'way', 'to', 'make', '$', '1', 'million', 'in', 'a', 'single', 'day']
#
#
#
#
# How do I start new business with $100?
# What lucrative business can I start with $100?
# ['how', 'do', 'i', 'start', 'new', 'business', 'with', '$', '100']
# ['what', 'lucrative', 'business', 'can', 'i', 'start', 'with', '$', '100']
#
#
#
#
# What business should I start with a $100k investment?
# What is the best business to start with a capital of 5 lakhs?
# ['what', 'business', 'should', 'i', 'start', 'with', 'a', '$', '100000', 'investment']
# ['what', 'is', 'the', 'best', 'business', 'to', 'start', 'with', 'a', 'capital', 'of', '5', 'lakhs']
#
#
#
#
# What do I do with $1,000,000?
# What should I do with $1,000,000?
# ['what', 'do', 'i', 'do', 'with', '$', '1000', '000']
# ['what', 'should', 'i', 'do', 'with', '$', '1000', '000']
#
#
#
#
# Anybody wants know to know how you can make an extra $1000 a month?
# How do I make $1000 as extra income/month apart from the regular job?
# ['anybody', 'wants', 'know', 'to', 'know', 'how', 'you', 'can', 'make', 'an', 'extra', '$', '1000', 'a', 'month']
# ['how', 'do', 'i', 'make', '$', '1000', 'as', 'extra', 'income', 'month', 'apart', 'from', 'the', 'regular', 'job']
#
#
#
#
# Which laptop should I buy in a budget of Rs. 60000 i.e about $1000?
# What is the best gaming laptop I can buy under 60000 in India?
# ['which', 'laptop', 'should', 'i', 'buy', 'in', 'a', 'budget', 'of', 'rs', '60000', 'i', 'e', 'about', '$', '1000']
# ['what', 'is', 'the', 'best', 'gaming', 'laptop', 'i', 'can', 'buy', 'under', '60000', 'in', 'india']
#
#
#
#
# Is Yahoo a good deal for Verizon at $5 billion?
# Is Yahoo worth $5 billion?
# ['is', 'yahoo', 'a', 'good', 'deal', 'for', 'verizon', 'at', '$', '5', 'billion']
# ['is', 'yahoo', 'worth', '$', '5', 'billion']
#
#
#
#
# How do you invest $1000?
# What is the best way to invest $1000??
# ['how', 'do', 'you', 'invest', '$', '1000']
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '1000']
#
#
#
#
# Which is the best gaming laptop under $500?
# Can someone get a good gaming laptop under $500?
# ['which', 'is', 'the', 'best', 'gaming', 'laptop', 'under', '$', '500']
# ['can', 'someone', 'get', 'a', 'good', 'gaming', 'laptop', 'under', '$', '500']
#
#
#
#
# What would you do if you had $100 million dollars?
# What can you do/build with 100 million dollars?
# ['what', 'would', 'you', 'do', 'if', 'you', 'had', '$', '100', 'million', 'dollars']
# ['what', 'can', 'you', 'do', 'build', 'with', '100', 'million', 'dollars']
#
#
#
#
# How can I earn 300$ per month online?
# What are some of the easiest way to ethically make $300 a month Online?
# ['how', 'can', 'i', 'earn', '300', '$', 'per', 'month', 'online']
# ['what', 'are', 'some', 'of', 'the', 'easiest', 'way', 'to', 'ethically', 'make', '$', '300', 'a', 'month', 'online']
#
#
#
#
# What is the best way to invest $200,000?
# What would be the best way to invest $200,000?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '200000']
# ['what', 'would', 'be', 'the', 'best', 'way', 'to', 'invest', '$', '200000']
# What is the best Used car for under $7000?
# What's the best used car I can buy for max $7000?
# ['what', 'is', 'the', 'best', 'used', 'car', 'for', 'under', '$', '7000']
# ['what', 'is', 'the', 'best', 'used', 'car', 'i', 'can', 'buy', 'for', 'max', '$', '7000']
#
#
#
#
# How could I use $200 to make substantially more?
# How can I use my $200 to make more money?
# ['how', 'could', 'i', 'use', '$', '200', 'to', 'make', 'substantially', 'more']
# ['how', 'can', 'i', 'use', 'my', '$', '200', 'to', 'make', 'more', 'money']
#
#
#
#
# Is it worth to buy yahoo in $4.8 bn?
# Is Yahoo worth $5 billion?
# ['is', 'it', 'worth', 'to', 'buy', 'yahoo', 'in', '$', '4', '8', 'bn']
# ['is', 'yahoo', 'worth', '$', '5', 'billion']
#
#
#
#
# How do you invest $1000?
# How do I invest 1000$?
# ['how', 'do', 'you', 'invest', '$', '1000']
# ['how', 'do', 'i', 'invest', '1000', '$']
#
#
#
#
# What is the quickest way to make $8,000?
# What are the quickest ways to make money?
# ['what', 'is', 'the', 'quickest', 'way', 'to', 'make', '$', '8000']
# ['what', 'are', 'the', 'quickest', 'ways', 'to', 'make', 'money']
#
#
#
#
# How do I make $500 a week?
# How do you make 500 dollars in a week?
# ['how', 'do', 'i', 'make', '$', '500', 'a', 'week']
# ['how', 'do', 'you', 'make', '500', 'dollars', 'in', 'a', 'week']
#
#
#
#
# How do I make $5 dollars a day online?
# How do I earn 5 dollars a day online?
# ['how', 'do', 'i', 'make', '$', '5', 'dollars', 'a', 'day', 'online']
# ['how', 'do', 'i', 'earn', '5', 'dollars', 'a', 'day', 'online']
#
#
#
#
# What is the best way to invest $100 a month to maximize returns?
# What is the best way to invest €100 a month?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '100', 'a', 'month', 'to', 'maximize', 'returns']
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '100', 'a', 'month']
#
#
#
#
# What business should I start with a $100k investment?
# What are some business ideas with 5 lakh investment?
# ['what', 'business', 'should', 'i', 'start', 'with', 'a', '$', '100000', 'investment']
# ['what', 'are', 'some', 'business', 'ideas', 'with', '5', 'lakh', 'investment']
#
#
#
#
# When will oil prices go up to $60,$70 or back to normal?
# Will oil prices go back up?
# ['when', 'will', 'oil', 'prices', 'go', 'up', 'to', '$', '60', '$', '70', 'or', 'back', 'to', 'normal']
# ['will', 'oil', 'prices', 'go', 'back', 'up']
#
#
#
#
# Anybody wants know to know how you can make an extra $1000 a month?
# What can I do to make an extra $1000?
# ['anybody', 'wants', 'know', 'to', 'know', 'how', 'you', 'can', 'make', 'an', 'extra', '$', '1000', 'a', 'month']
# ['what', 'can', 'i', 'do', 'to', 'make', 'an', 'extra', '$', '1000']
#
#
#
#
# Would you press a button that kills a random person and gives you $1 million, if no one ever knew about your crime?
# Would you push a button for one million dollars, if you knew one random person in the world would die when you push it?
# ['would', 'you', 'press', 'a', 'button', 'that', 'kills', 'a', 'random', 'person', 'and', 'gives', 'you', '$', '1', 'million', 'if', 'no', 'one', 'ever', 'knew', 'about', 'your', 'crime']
# ['would', 'you', 'push', 'a', 'button', 'for', 'one', 'million', 'dollars', 'if', 'you', 'knew', 'one', 'random', 'person', 'in', 'the', 'world', 'would', 'die', 'when', 'you', 'push', 'it']
#
#
#
#
# Would the founder/CEO of a new/small commercial real estate firm that did 25 broker deals this year totaling $55 million be making over 500K a year?
# Would the founder/CEO of 5 employee commercial RE firm be doing pretty well if they brokered 25 deals their 1st year totaling $50 million in sales?
# ['would', 'the', 'founder', 'ceo', 'of', 'a', 'new', 'small', 'commercial', 'real', 'estate', 'firm', 'that', 'did', '25', 'broker', 'deals', 'this', 'year', 'totaling', '$', '55', 'million', 'be', 'making', 'over', '500000', 'a', 'year']
# ['would', 'the', 'founder', 'ceo', 'of', '5', 'employee', 'commercial', 're', 'firm', 'be', 'doing', 'pretty', 'well', 'if', 'they', 'brokered', '25', 'deals', 'their', '1st', 'year', 'totaling', '$', '50', 'million', 'in', 'sales']
#
#
#
#
# Why was Hulk Hogan awarded such a huge amount in the trial against Gawker?
# How did Hulk Hogan manage to win so much money ($140 million) in his lawsuit against Gawker?
# ['why', 'was', 'hulk', 'hogan', 'awarded', 'such', 'a', 'huge', 'amount', 'in', 'the', 'trial', 'against', 'gawker']
# ['how', 'did', 'hulk', 'hogan', 'manage', 'to', 'win', 'so', 'much', 'money', '$', '140', 'million', 'in', 'his', 'lawsuit', 'against', 'gawker']
#
#
#
#
# What is the best laptop that is under $750?
# What's the best laptop for under $750?
# ['what', 'is', 'the', 'best', 'laptop', 'that', 'is', 'under', '$', '750']
# ['what', 'is', 'the', 'best', 'laptop', 'for', 'under', '$', '750']
#
#
#
#
# Is it possible to a data scientist to earn $50 per hour on freelancing?
# Is it possible for a data scientist to earn $50 per hour on freelancing? How?
# ['is', 'it', 'possible', 'to', 'a', 'data', 'scientist', 'to', 'earn', '$', '50', 'per', 'hour', 'on', 'freelancing']
# ['is', 'it', 'possible', 'for', 'a', 'data', 'scientist', 'to', 'earn', '$', '50', 'per', 'hour', 'on', 'freelancing', 'how']
#
#
#
#
# What is the best way to invest $1000??
# How do I invest 1000$?
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '1000']
# ['how', 'do', 'i', 'invest', '1000', '$']
#
#
#
#
# How do you make $20 a day?
# How do you make 20 dollars in one day?
# ['how', 'do', 'you', 'make', '$', '20', 'a', 'day']
# ['how', 'do', 'you', 'make', '20', 'dollars', 'in', 'one', 'day']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# What are the best laptops for under 60k rs?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['what', 'are', 'the', 'best', 'laptops', 'for', 'under', '60000', 'rs']
#
#
#
#
# What are some business ideas that I can make +100 000€ in 1 year with 20 000€ of investment? (No online business)
# What business can I start with 20 000€ to make at least 100 000€ net worth or more?
# ['what', 'are', 'some', 'business', 'ideas', 'that', 'i', 'can', 'make', '+100', '000', '$', 'in', '1', 'year', 'with', '20', '000', '$', 'of', 'investment', 'no', 'online', 'business']
# ['what', 'business', 'can', 'i', 'start', 'with', '20', '000', '$', 'to', 'make', 'at', 'least', '100', '000', '$', 'net', 'worth', 'or', 'more']
#
#
#
#
# What can I do to earn $100 per day?
# How can I earn $100 per day?
# ['what', 'can', 'i', 'do', 'to', 'earn', '$', '100', 'per', 'day']
# ['how', 'can', 'i', 'earn', '$', '100', 'per', 'day']
#
#
#
#
# What is the best laptop under 60k(900$ approx)?
# What is the best laptop under Rs.60000 in India?
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
# ['what', 'is', 'the', 'best', 'laptop', 'under', 'rs', '60000', 'in', 'india']
#
#
#
#
# How do I make $500 a week?
# How I can earn $500 per week?
# ['how', 'do', 'i', 'make', '$', '500', 'a', 'week']
# ['how', 'i', 'can', 'earn', '$', '500', 'per', 'week']
#
#
#
#
# What business can I start with $500?
# What business can I start with $500-$600?
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '500']
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '500', '$', '600']
#
#
#
#
# What business would/could you start right now with $100?
# How do I start new business with $100?
# ['what', 'business', 'would', 'could', 'you', 'start', 'right', 'now', 'with', '$', '100']
# ['how', 'do', 'i', 'start', 'new', 'business', 'with', '$', '100']
#
#
#
#
# How I can earn $500 per week?
# How can I make an extra $500 per week?
# ['how', 'i', 'can', 'earn', '$', '500', 'per', 'week']
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '500', 'per', 'week']
#
#
#
#
# How should I invest 1000?
# What is the best way to invest $1000??
# ['how', 'should', 'i', 'invest', '1000']
# ['what', 'is', 'the', 'best', 'way', 'to', 'invest', '$', '1000']
#
#
#
#
# How did ISRO conduct a Mars mission with a much lower budget than NASA?
# How did India succeed in its Mars Mission with a budget of $75 million which is less than the cost of other Mars missions and even the budget of the movie Gravity?
# ['how', 'did', 'isro', 'conduct', 'a', 'mars', 'mission', 'with', 'a', 'much', 'lower', 'budget', 'than', 'nasa']
# ['how', 'did', 'india', 'succeed', 'in', 'its', 'mars', 'mission', 'with', 'a', 'budget', 'of', '$', '75', 'million', 'which', 'is', 'less', 'than', 'the', 'cost', 'of', 'other', 'mars', 'missions', 'and', 'even', 'the', 'budget', 'of', 'the', 'movie', 'gravity']
# Is Uber overvalued?
# At a $40B valuation, is Uber overvalued? Why or why not?
# ['is', 'uber', 'overvalued']
# ['at', 'a', '$', '40b', 'valuation', 'is', 'uber', 'overvalued', 'why', 'or', 'why', 'not']
#
#
#
#
# How can I make an extra $1000 a month?
# How do I make $1000 extra dollars?
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '1000', 'a', 'month']
# ['how', 'do', 'i', 'make', '$', '1000', 'extra', 'dollars']
#
#
#
#
# What are the best studio monitors for under $450 per pair?
# What is the best pair of studio monitors under $450?
# ['what', 'are', 'the', 'best', 'studio', 'monitors', 'for', 'under', '$', '450', 'per', 'pair']
# ['what', 'is', 'the', 'best', 'pair', 'of', 'studio', 'monitors', 'under', '$', '450']
#
#
#
#
# How can I make an extra $2000 this month?
# How do I make $1000 as extra income/month apart from the regular job?
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '2000', 'this', 'month']
# ['how', 'do', 'i', 'make', '$', '1000', 'as', 'extra', 'income', 'month', 'apart', 'from', 'the', 'regular', 'job']
#
#
#
#
# How much can I spend on rent making $144k a year in Manhattan?
# How much can I spend on rent in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'making', '$', '144000', 'a', 'year', 'in', 'manhattan']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan']
#
#
#
#
# What is best way to invest $10,000?
# What is the best investment I can make with $10,000?
# ['what', 'is', 'best', 'way', 'to', 'invest', '$', '10000']
# ['what', 'is', 'the', 'best', 'investment', 'i', 'can', 'make', 'with', '$', '10000']
#
#
#
#
# Which laptop should I buy under 60000?
# What is the best laptop under 60k(900$ approx)?
# ['which', 'laptop', 'should', 'i', 'buy', 'under', '60000']
# ['what', 'is', 'the', 'best', 'laptop', 'under', '60000', '900', '$', 'approx']
#
#
#
#
# When will oil prices go up to $60-$70 or back to normal?
# When will oil prices be up to $60?
# ['when', 'will', 'oil', 'prices', 'go', 'up', 'to', '$', '60', '$', '70', 'or', 'back', 'to', 'normal']
# ['when', 'will', 'oil', 'prices', 'be', 'up', 'to', '$', '60']
#
#
#
#
# Which is the best mobile below 10k?
# Which is the best mobile below 10k INR ($150)?
# ['which', 'is', 'the', 'best', 'mobile', 'below', '10000']
# ['which', 'is', 'the', 'best', 'mobile', 'below', '10000', 'inr', '$', '150']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# How do you make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['how', 'do', 'you', 'make', 'money', 'online']
#
#
#
#
# Can I make 800,000 a month betting on horses?
# Can I make $US 100,000 a month betting on horses?
# ['can', 'i', 'make', '800000', 'a', 'month', 'betting', 'on', 'horses']
# ['can', 'i', 'make', '$', 'us', '100000', 'a', 'month', 'betting', 'on', 'horses']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# How do you make easy money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['how', 'do', 'you', 'make', 'easy', 'money', 'online']
#
#
#
#
# Should minimum wage be increased to $15.00?
# Should the minimum wage be raised to $15/hr for all American workers?
# ['should', 'minimum', 'wage', 'be', 'increased', 'to', '$', '15', '00']
# ['should', 'the', 'minimum', 'wage', 'be', 'raised', 'to', '$', '15', 'hr', 'for', 'all', 'american', 'workers']
#
#
#
#
# How can we start a business with $100?
# What lucrative business can I start with $100?
# ['how', 'can', 'we', 'start', 'a', 'business', 'with', '$', '100']
# ['what', 'lucrative', 'business', 'can', 'i', 'start', 'with', '$', '100']
#
#
#
#
# What business should I start with a $100k investment?
# Which business can I start with a budget below 5 lakhs?
# ['what', 'business', 'should', 'i', 'start', 'with', 'a', '$', '100000', 'investment']
# ['which', 'business', 'can', 'i', 'start', 'with', 'a', 'budget', 'below', '5', 'lakhs']
#
#
#
#
# What is the best thing you can do with 100$?
# What's the best thing you can do with $100?
# ['what', 'is', 'the', 'best', 'thing', 'you', 'can', 'do', 'with', '100', '$']
# ['what', 'is', 'the', 'best', 'thing', 'you', 'can', 'do', 'with', '$', '100']
#
#
#
#
# What is the best Android smartphone for under $400?
# What is the best Android smartphone under $400?
# ['what', 'is', 'the', 'best', 'android', 'smartphone', 'for', 'under', '$', '400']
# ['what', 'is', 'the', 'best', 'android', 'smartphone', 'under', '$', '400']
#
#
#
#
# What is the easiest way to become a billionaire($)?
# How can I become a billionaire?
# ['what', 'is', 'the', 'easiest', 'way', 'to', 'become', 'a', 'billionaire', '$']
# ['how', 'can', 'i', 'become', 'a', 'billionaire']
#
#
#
#
# Why don't good stocks ever reach low prices ($1-$5) during plunges like they did in the second half of the 20th century?
# ...
# ['would', 'the', 'founder', 'ceo', 'of', 'a', 'new', 'small', 'realestate', 'firm', 'that', 'did', '25', 'broker', 'deals', 'this', 'year', 'totaling', '$', '55', 'million', 'be', 'making', 'over', '300000', 'what', 'is', 'his', 'salary']
# ['would', 'the', 'founder', 'ceo', 'of', 'a', 'new', 'small', 'commercial', 'real', 'estate', 'firm', 'that', 'did', '25', 'broker', 'deals', 'this', 'year', 'totaling', '$', '55', 'million', 'be', 'making', 'over', '500000', 'a', 'year']
#
#
#
#
# What business would/could you start right now with $100?
# What lucrative business can I start with $100?
# ['what', 'business', 'would', 'could', 'you', 'start', 'right', 'now', 'with', '$', '100']
# ['what', 'lucrative', 'business', 'can', 'i', 'start', 'with', '$', '100']
#
#
#
#
# If you had $1billion to find a cure for autism, how would you spend it?
# If you had one billion dollars to find a solution for autism, how would you spend it?
# ['if', 'you', 'had', '$', '1billion', 'to', 'find', 'a', 'cure', 'for', 'autism', 'how', 'would', 'you', 'spend', 'it']
# ['if', 'you', 'had', 'one', 'billion', 'dollars', 'to', 'find', 'a', 'solution', 'for', 'autism', 'how', 'would', 'you', 'spend', 'it']
#
#
#
#
# Which is best laptop to buy under 30k?
# What are the best laptops to buy within Rs.30000 or $485 and why?
# ['which', 'is', 'best', 'laptop', 'to', 'buy', 'under', '30000']
# ['what', 'are', 'the', 'best', 'laptops', 'to', 'buy', 'within', 'rs', '30000', 'or', '$', '485', 'and', 'why']
#
#
#
#
# How is buying land on the moon a good investment? Why do people buy land on the moon?
# At $20 an acre, isn't buying moon plots a solid investment?
# ['how', 'is', 'buying', 'land', 'on', 'the', 'moon', 'a', 'good', 'investment', 'why', 'do', 'people', 'buy', 'land', 'on', 'the', 'moon']
# ['at', '$', '20', 'an', 'acre', 'is', 'not', 'buying', 'moon', 'plots', 'a', 'solid', 'investment']
#
#
#
#
# How do I make $1000 extra dollars?
# How can I make my first 1000 dollars?
# ['how', 'do', 'i', 'make', '$', '1000', 'extra', 'dollars']
# ['how', 'can', 'i', 'make', 'my', 'first', '1000', 'dollars']
#
#
#
#
# Is 80,000 pounds enough to live in london?
# Is £80,000 a year a good enough salary to live in London?
# ['is', '80000', 'pounds', 'enough', 'to', 'live', 'in', 'london']
# ['is', '$', '80000', 'a', 'year', 'a', 'good', 'enough', 'salary', 'to', 'live', 'in', 'london']
#
#
#
#
# How can I get the word out about my GoFundMe? If I get 1000 people to donate $25 each I would have enough money to easily create my first film.
# How can I get people to donate on GoFundMe?
# ['how', 'can', 'i', 'get', 'the', 'word', 'out', 'about', 'my', 'gofundme', 'if', 'i', 'get', '1000', 'people', 'to', 'donate', '$', '25', 'each', 'i', 'would', 'have', 'enough', 'money', 'to', 'easily', 'create', 'my', 'first', 'film']
# ['how', 'can', 'i', 'get', 'people', 'to', 'donate', 'on', 'gofundme']
#
#
#
#
# What would you do first if you won $100,000,000?
# What would you do if you won $100,000,000?
# ['what', 'would', 'you', 'do', 'first', 'if', 'you', 'won', '$', '100000', '000']
# ['what', 'would', 'you', 'do', 'if', 'you', 'won', '$', '100000', '000']
# How can I make every day $10 online?
# How can I earn 10$ per day online?
# ['how', 'can', 'i', 'make', 'every', 'day', '$', '10', 'online']
# ['how', 'can', 'i', 'earn', '10', '$', 'per', 'day', 'online']
#
#
#
#
# How much can I spend on rent in Manhattan if my yearly salary is $1 million?
# How much can I spend on rent in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan', 'if', 'my', 'yearly', 'salary', 'is', '$', '1', 'million']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan']
#
#
#
#
# What is the best gaming laptop under 2000$?
# What's the best gaming laptop around $2000?
# ['what', 'is', 'the', 'best', 'gaming', 'laptop', 'under', '2000', '$']
# ['what', 'is', 'the', 'best', 'gaming', 'laptop', 'around', '$', '2000']
#
#
#
#
# What are the best headphones under $100?
# Which are the best headphones for under $100?
# ['what', 'are', 'the', 'best', 'headphones', 'under', '$', '100']
# ['which', 'are', 'the', 'best', 'headphones', 'for', 'under', '$', '100']
#
#
#
#
# What is best way to invest $10,000?
# How should I invest $10,000?
# ['what', 'is', 'best', 'way', 'to', 'invest', '$', '10000']
# ['how', 'should', 'i', 'invest', '$', '10000']
#
#
#
#
# What is the best Used car for under $7000?
# What’s the best used car for under 7000?
# ['what', 'is', 'the', 'best', 'used', 'car', 'for', 'under', '$', '7000']
# ['what', 'is', 'the', 'best', 'used', 'car', 'for', 'under', '7000']
#
#
#
#
# I have $5000 to invest which is the best stocks to buy?
# What are the best stocks to invest in with 5000$?
# ['i', 'have', '$', '5000', 'to', 'invest', 'which', 'is', 'the', 'best', 'stocks', 'to', 'buy']
# ['what', 'are', 'the', 'best', 'stocks', 'to', 'invest', 'in', 'with', '5000', '$']
#
#
#
#
# What is the best business to start with $100,000?
# What would be the best business to start with $100k?
# ['what', 'is', 'the', 'best', 'business', 'to', 'start', 'with', '$', '100000']
# ['what', 'would', 'be', 'the', 'best', 'business', 'to', 'start', 'with', '$', '100000']
#
#
#
#
# How do you invest $1000?
# How should I invest 1000?
# ['how', 'do', 'you', 'invest', '$', '1000']
# ['how', 'should', 'i', 'invest', '1000']
#
#
#
#
# How do I make $5,000/month online?
# How do I make $5,000 or more a month online?
# ['how', 'do', 'i', 'make', '$', '5000', 'month', 'online']
# ['how', 'do', 'i', 'make', '$', '5000', 'or', 'more', 'a', 'month', 'online']
#
#
#
#
# I have a $100, where should I invest?
# I want to invest $100, where can I invest it?
# ['i', 'have', 'a', '$', '100', 'where', 'should', 'i', 'invest']
# ['i', 'want', 'to', 'invest', '$', '100', 'where', 'can', 'i', 'invest', 'it']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# What is a way to make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['what', 'is', 'a', 'way', 'to', 'make', 'money', 'online']
#
#
#
#
# What are some good ways of investing a small amount of money? ..lets say 500$.
# Which is the best way to invest small amount of money?
# ['what', 'are', 'some', 'good', 'ways', 'of', 'investing', 'a', 'small', 'amount', 'of', 'money', 'lets', 'say', '500', '$']
# ['which', 'is', 'the', 'best', 'way', 'to', 'invest', 'small', 'amount', 'of', 'money']
#
#
#
#
# How much can I spend on rent in Manhattan if my yearly salary is $1 million?
# How much can I spend on rent making $1 million a year in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan', 'if', 'my', 'yearly', 'salary', 'is', '$', '1', 'million']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'making', '$', '1', 'million', 'a', 'year', 'in', 'manhattan']
#
#
#
#
# What are the best tablets under 100?
# What's the best graphics tablet under $100?
# ['what', 'are', 'the', 'best', 'tablets', 'under', '100']
# ['what', 'is', 'the', 'best', 'graphics', 'tablet', 'under', '$', '100']
#
#
#
#
# Can I use an Uber promo code in another country?
# I got 10$ Uber credits by using promo code although I set my country as India (local currency is INR). Can I use it here?
# ['can', 'i', 'use', 'an', 'uber', 'promo', 'code', 'in', 'another', 'country']
# ['i', 'got', '10', '$', 'uber', 'credits', 'by', 'using', 'promo', 'code', 'although', 'i', 'set', 'my', 'country', 'as', 'india', 'local', 'currency', 'is', 'inr', 'can', 'i', 'use', 'it', 'here']
#
#
#
#
# What are some good over ear headphones under 2000?
# What is the best in-ear headphones under $2K?
# ['what', 'are', 'some', 'good', 'over', 'ear', 'headphones', 'under', '2000']
# ['what', 'is', 'the', 'best', 'in', 'ear', 'headphones', 'under', '$', '2000']
#
#
#
#
# How can I make $20 per day online?
# What is the easiest way to make $20 per day online?
# ['how', 'can', 'i', 'make', '$', '20', 'per', 'day', 'online']
# ['what', 'is', 'the', 'easiest', 'way', 'to', 'make', '$', '20', 'per', 'day', 'online']
#
#
#
#
# How does Microsoft benefit from LinkedIn acquisition?
# Why did Microsoft buy LinkedIn for $26.2 billion in an all-cash deal?
# ['how', 'does', 'microsoft', 'benefit', 'from', 'linkedin', 'acquisition']
# ['why', 'did', 'microsoft', 'buy', 'linkedin', 'for', '$', '26', '2', 'billion', 'in', 'an', 'all', 'cash', 'deal']
#
#
#
#
# Would the founder/CEO of a new/small commercial real estate firm that did 25 broker deals this year totaling $55 million be making over 500K a year?
# Would the founder/CEO of 5 employee commercial RE firm be doing pretty well if they brokered 25 deals their 1st year totaling $55 million?
# ['would', 'the', 'founder', 'ceo', 'of', 'a', 'new', 'small', 'commercial', 'real', 'estate', 'firm', 'that', 'did', '25', 'broker', 'deals', 'this', 'year', 'totaling', '$', '55', 'million', 'be', 'making', 'over', '500000', 'a', 'year']
# ['would', 'the', 'founder', 'ceo', 'of', '5', 'employee', 'commercial', 're', 'firm', 'be', 'doing', 'pretty', 'well', 'if', 'they', 'brokered', '25', 'deals', 'their', '1st', 'year', 'totaling', '$', '55', 'million']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# How do I really make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['how', 'do', 'i', 'really', 'make', 'money', 'online']
#
#
#
#
# Would you push a button for one million dollars, if you knew one random person in the world would die when you push it?
# If you could press a button and get $1,000,000,000 but you'd kill a million people, and everyone knew that you did, would you do it?
# ['would', 'you', 'push', 'a', 'button', 'for', 'one', 'million', 'dollars', 'if', 'you', 'knew', 'one', 'random', 'person', 'in', 'the', 'world', 'would', 'die', 'when', 'you', 'push', 'it']
# ['if', 'you', 'could', 'press', 'a', 'button', 'and', 'get', '$', '1000', '000000', 'but', 'you', 'would', 'kill', 'a', 'million', 'people', 'and', 'everyone', 'knew', 'that', 'you', 'did', 'would', 'you', 'do', 'it']
#
#
#
#
# If you are The Quoran with millions of views and poor and they exchange $/view but you forget all your knowledge and become,a farmer,do you accept it?
# If you're a Quoran with millions of views & poor & they offer $/view but you become ordinary person forgetting all your knowledge would you accept it?
# ['if', 'you', 'are', 'the', 'quoran', 'with', 'millions', 'of', 'views', 'and', 'poor', 'and', 'they', 'exchange', '$', 'view', 'but', 'you', 'forget', 'all', 'your', 'knowledge', 'and', 'become', 'a', 'farmer', 'do', 'you', 'accept', 'it']
# ['if', 'you', 'are', 'a', 'quoran', 'with', 'millions', 'of', 'views', 'and', 'poor', 'and', 'they', 'offer', '$', 'view', 'but', 'you', 'become', 'ordinary', 'person', 'forgetting', 'all', 'your', 'knowledge', 'would', 'you', 'accept', 'it']
#
#
#
#
# How do I make 1000 dollars/day online?
# How can I make 1000$ per day online?
# ['how', 'do', 'i', 'make', '1000', 'dollars', 'day', 'online']
# ['how', 'can', 'i', 'make', '1000', '$', 'per', 'day', 'online']
#
#
#
#
# Anybody wants know to know how you can make an extra $1000 a month?
# How can I make an extra $2000 this month?
# ['anybody', 'wants', 'know', 'to', 'know', 'how', 'you', 'can', 'make', 'an', 'extra', '$', '1000', 'a', 'month']
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '2000', 'this', 'month']
#
#
#
#
# Can Fast and Furious 7 gross $1 billion worldwide?
# Will Furious 7 be the first movie in the franchise to gross a billion dollars?
# ['can', 'fast', 'and', 'furious', '7', 'gross', '$', '1', 'billion', 'worldwide']
# ['will', 'furious', '7', 'be', 'the', 'first', 'movie', 'in', 'the', 'franchise', 'to', 'gross', 'a', 'billion', 'dollars']
#
#
#
#
# What business can I start with $100?
# How do I start new business with $100?
# ['what', 'business', 'can', 'i', 'start', 'with', '$', '100']
# ['how', 'do', 'i', 'start', 'new', 'business', 'with', '$', '100']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# How do we make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['how', 'do', 'we', 'make', 'money', 'online']
# Where can I get an explainer video for $100?
# Where can I get a quality explainer video done for $100?
# ['where', 'can', 'i', 'get', 'an', 'explainer', 'video', 'for', '$', '100']
# ['where', 'can', 'i', 'get', 'a', 'quality', 'explainer', 'video', 'done', 'for', '$', '100']
#
#
#
#
# How can I make an extra $1000 a month?
# What can I do to make an extra $1000?
# ['how', 'can', 'i', 'make', 'an', 'extra', '$', '1000', 'a', 'month']
# ['what', 'can', 'i', 'do', 'to', 'make', 'an', 'extra', '$', '1000']
#
#
#
#
# What is the best quadcopter for under $200?
# What's the best drone that you can buy for under $200?
# ['what', 'is', 'the', 'best', 'quadcopter', 'for', 'under', '$', '200']
# ['what', 'is', 'the', 'best', 'drone', 'that', 'you', 'can', 'buy', 'for', 'under', '$', '200']
#
#
#
#
# Am not starting big? How can I make $1000 per month online?
# How can one make money online?
# ['am', 'not', 'starting', 'big', 'how', 'can', 'i', 'make', '$', '1000', 'per', 'month', 'online']
# ['how', 'can', 'one', 'make', 'money', 'online']
#
#
#
#
# How much can I spend on rent in Manhattan if my yearly salary is $1 million?
# How much can I spend on rent making $144k a year in Manhattan?
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'in', 'manhattan', 'if', 'my', 'yearly', 'salary', 'is', '$', '1', 'million']
# ['how', 'much', 'can', 'i', 'spend', 'on', 'rent', 'making', '$', '144000', 'a', 'year', 'in', 'manhattan']
#
#
#
#
# Should Andrew Jackson be on the US $20 bill?
# Does Andrew Jackson deserve to be on the $20 bill?
# ['should', 'andrew', 'jackson', 'be', 'on', 'the', 'us', '$', '20', 'bill']
# ['does', 'andrew', 'jackson', 'deserve', 'to', 'be', 'on', 'the', '$', '20', 'bill']
#
#
#
#
# Why is Abraham Lincoln on the penny and the $5 bill?
# Why is Abraham Lincoln on the $5 dollar bill and our pennies?
# ['why', 'is', 'abraham', 'lincoln', 'on', 'the', 'penny', 'and', 'the', '$', '5', 'bill']
# ['why', 'is', 'abraham', 'lincoln', 'on', 'the', '$', '5', 'dollar', 'bill', 'and', 'our', 'pennies']
#
#
#
#
# How should I invest 1000?
# How do I invest 1000$?
# ['how', 'should', 'i', 'invest', '1000']
# ['how', 'do', 'i', 'invest', '1000', '$']
#
#
#
#
# How can I make $100 as a teen online quick?
# What is the fastest way to make $100 online?
# ['how', 'can', 'i', 'make', '$', '100', 'as', 'a', 'teen', 'online', 'quick']
# ['what', 'is', 'the', 'fastest', 'way', 'to', 'make', '$', '100', 'online']
#
#
#
#
# What is the future value three years from now of $1000 invested in an account with a stated annual interest rate of 8%? if compounded semi-annually
# What is the future value three years from now of $1,000 invested in an account with a stated annual interest rate of 8% if compounded monthly?
# ['what', 'is', 'the', 'future', 'value', 'three', 'years', 'from', 'now', 'of', '$', '1000', 'invested', 'in', 'an', 'account', 'with', 'a', 'stated', 'annual', 'interest', 'rate', 'of', '8%', 'if', 'compounded', 'semi', 'annually']
# ['what', 'is', 'the', 'future', 'value', 'three', 'years', 'from', 'now', 'of', '$', '1000', 'invested', 'in', 'an', 'account', 'with', 'a', 'stated', 'annual', 'interest', 'rate', 'of', '8%', 'if', 'compounded', 'monthly']
#
#
#
#
# I have 5,000 USD where do I invest it to yield 5-10% per month?
# I have $10,000 USD that I want to invest, what can I do to yield 5-10% per month?
# ['i', 'have', '5000', 'usd', 'where', 'do', 'i', 'invest', 'it', 'to', 'yield', '5', '10%', 'per', 'month']
# ['i', 'have', '$', '10000', 'usd', 'that', 'i', 'want', 'to', 'invest', 'what', 'can', 'i', 'do', 'to', 'yield', '5', '10%', 'per', 'month']
#
#
#
#
# Is £40,000 a good starting salary if you are living in London?
# Is 40 thousand pounds a good salary in London?
# ['is', '$', '40000', 'a', 'good', 'starting', 'salary', 'if', 'you', 'are', 'living', 'in', 'london']
# ['is', '40', 'thousand', 'pounds', 'a', 'good', 'salary', 'in', 'london']
#
#
#
#
# Were the Clintons paid by the Clinton Foundation?
# Was Chelsea Clinton really paid $700,000 a year working for the Clinton Foundation?
# ['were', 'the', 'clintons', 'paid', 'by', 'the', 'clinton', 'foundation']
# ['was', 'chelsea', 'clinton', 'really', 'paid', '$', '700000', 'a', 'year', 'working', 'for', 'the', 'clinton', 'foundation']
